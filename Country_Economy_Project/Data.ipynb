# %% [markdown]
# # National Power Index Data
# - 국력 분석 데이터셋

# %%
import pandas as pd

# %% [markdown]
# ## 1 Data Sources
#
# - World Bank
# - Exports_USD

# %% [markdown]
# ## 2 Economy Data
#
# - GDP
# - GDP per capita
# - Trade

# %%
gdp = pd.read_csv("data/Country_Gdp.csv", skiprows=4)
gdp.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  2.420569e+10  2.495889e+10  2.707323e+10  3.176914e+10
# 2  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 3  NY.GDP.MKTP.CD  1.190481e+10  1.270772e+10  1.363059e+10  1.446891e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2017          2018          2019  \
# 0           NaN           NaN  ...  3.092428e+09  3.276188e+09  3.346623e+09
# 1  3.027955e+10  3.380618e+10  ...  9.780765e+11  1.020956e+12  1.018715e+12
# 2           NaN           NaN  ...  1.875346e+10  1.805322e+10  1.879944e+10
# 3  1.580356e+10  1.692088e+10  ...  6.940513e+11  7.778403e+11  1.026996e+12
# 4           NaN           NaN  ...  8.437694e+10  8.951279e+10  8.073443e+10
#
#            2020          2021          2022          2023          2024  2025  \
# 0  2.471419e+09  2.880903e+09  3.324034e+09  3.834730e+09  4.265651e+09   NaN
# 1  9.386076e+11  1.114145e+12  1.228968e+12  1.179359e+12  1.242694e+12   NaN
# 2  1.995593e+10  1.426000e+10  1.449724e+10  1.715223e+10           NaN   NaN
# 3  9.637847e+11  1.026651e+12  1.063649e+12  9.382384e+11  7.363850e+11   NaN
# 4  5.885246e+10  7.955954e+10  1.312122e+11  1.071677e+11  1.009989e+11   NaN
#
#    Unnamed: 70
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 71 columns]

# %%
exports = pd.read_csv("data/Exports_USD.csv", skiprows=4)
gdp.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  2.420569e+10  2.495889e+10  2.707323e+10  3.176914e+10
# 2  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 3  NY.GDP.MKTP.CD  1.190481e+10  1.270772e+10  1.363059e+10  1.446891e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2017          2018          2019  \
# 0           NaN           NaN  ...  3.092428e+09  3.276188e+09  3.346623e+09
# 1  3.027955e+10  3.380618e+10  ...  9.780765e+11  1.020956e+12  1.018715e+12
# 2           NaN           NaN  ...  1.875346e+10  1.805322e+10  1.879944e+10
# 3  1.580356e+10  1.692088e+10  ...  6.940513e+11  7.778403e+11  1.026996e+12
# 4           NaN           NaN  ...  8.437694e+10  8.951279e+10  8.073443e+10
#
#            2020          2021          2022          2023          2024  2025  \
# 0  2.471419e+09  2.880903e+09  3.324034e+09  3.834730e+09  4.265651e+09   NaN
# 1  9.386076e+11  1.114145e+12  1.228968e+12  1.179359e+12  1.242694e+12   NaN
# 2  1.995593e+10  1.426000e+10  1.449724e+10  1.715223e+10           NaN   NaN
# 3  9.637847e+11  1.026651e+12  1.063649e+12  9.382384e+11  7.363850e+11   NaN
# 4  5.885246e+10  7.955954e+10  1.312122e+11  1.071677e+11  1.009989e+11   NaN
#
#    Unnamed: 70
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 71 columns]

# %% [markdown]
# ## 3 Military Data
#
# - Military spending per gdp
# - Military spending per usd

# %%
military_usd = pd.read_csv("data/Military_USD.csv", skiprows=4)
gdp.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  2.420569e+10  2.495889e+10  2.707323e+10  3.176914e+10
# 2  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 3  NY.GDP.MKTP.CD  1.190481e+10  1.270772e+10  1.363059e+10  1.446891e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2017          2018          2019  \
# 0           NaN           NaN  ...  3.092428e+09  3.276188e+09  3.346623e+09
# 1  3.027955e+10  3.380618e+10  ...  9.780765e+11  1.020956e+12  1.018715e+12
# 2           NaN           NaN  ...  1.875346e+10  1.805322e+10  1.879944e+10
# 3  1.580356e+10  1.692088e+10  ...  6.940513e+11  7.778403e+11  1.026996e+12
# 4           NaN           NaN  ...  8.437694e+10  8.951279e+10  8.073443e+10
#
#            2020          2021          2022          2023          2024  2025  \
# 0  2.471419e+09  2.880903e+09  3.324034e+09  3.834730e+09  4.265651e+09   NaN
# 1  9.386076e+11  1.114145e+12  1.228968e+12  1.179359e+12  1.242694e+12   NaN
# 2  1.995593e+10  1.426000e+10  1.449724e+10  1.715223e+10           NaN   NaN
# 3  9.637847e+11  1.026651e+12  1.063649e+12  9.382384e+11  7.363850e+11   NaN
# 4  5.885246e+10  7.955954e+10  1.312122e+11  1.071677e+11  1.009989e+11   NaN
#
#    Unnamed: 70
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 71 columns]

# %%
military_per_gdp = pd.read_csv("data/Military_Per_GDP.csv", skiprows=4)
gdp.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  2.420569e+10  2.495889e+10  2.707323e+10  3.176914e+10
# 2  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 3  NY.GDP.MKTP.CD  1.190481e+10  1.270772e+10  1.363059e+10  1.446891e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2017          2018          2019  \
# 0           NaN           NaN  ...  3.092428e+09  3.276188e+09  3.346623e+09
# 1  3.027955e+10  3.380618e+10  ...  9.780765e+11  1.020956e+12  1.018715e+12
# 2           NaN           NaN  ...  1.875346e+10  1.805322e+10  1.879944e+10
# 3  1.580356e+10  1.692088e+10  ...  6.940513e+11  7.778403e+11  1.026996e+12
# 4           NaN           NaN  ...  8.437694e+10  8.951279e+10  8.073443e+10
#
#            2020          2021          2022          2023          2024  2025  \
# 0  2.471419e+09  2.880903e+09  3.324034e+09  3.834730e+09  4.265651e+09   NaN
# 1  9.386076e+11  1.114145e+12  1.228968e+12  1.179359e+12  1.242694e+12   NaN
# 2  1.995593e+10  1.426000e+10  1.449724e+10  1.715223e+10           NaN   NaN
# 3  9.637847e+11  1.026651e+12  1.063649e+12  9.382384e+11  7.363850e+11   NaN
# 4  5.885246e+10  7.955954e+10  1.312122e+11  1.071677e+11  1.009989e+11   NaN
#
#    Unnamed: 70
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 71 columns]

# %% [markdown]
# ## 4 Population Data
#
# - Population

# %%
population = pd.read_csv("data/Population.csv", skiprows=4)
gdp.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  2.420569e+10  2.495889e+10  2.707323e+10  3.176914e+10
# 2  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 3  NY.GDP.MKTP.CD  1.190481e+10  1.270772e+10  1.363059e+10  1.446891e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2017          2018          2019  \
# 0           NaN           NaN  ...  3.092428e+09  3.276188e+09  3.346623e+09
# 1  3.027955e+10  3.380618e+10  ...  9.780765e+11  1.020956e+12  1.018715e+12
# 2           NaN           NaN  ...  1.875346e+10  1.805322e+10  1.879944e+10
# 3  1.580356e+10  1.692088e+10  ...  6.940513e+11  7.778403e+11  1.026996e+12
# 4           NaN           NaN  ...  8.437694e+10  8.951279e+10  8.073443e+10
#
#            2020          2021          2022          2023          2024  2025  \
# 0  2.471419e+09  2.880903e+09  3.324034e+09  3.834730e+09  4.265651e+09   NaN
# 1  9.386076e+11  1.114145e+12  1.228968e+12  1.179359e+12  1.242694e+12   NaN
# 2  1.995593e+10  1.426000e+10  1.449724e+10  1.715223e+10           NaN   NaN
# 3  9.637847e+11  1.026651e+12  1.063649e+12  9.382384e+11  7.363850e+11   NaN
# 4  5.885246e+10  7.955954e+10  1.312122e+11  1.071677e+11  1.009989e+11   NaN
#
#    Unnamed: 70
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 71 columns]

# %% [markdown]
# ## 5 Technology Data
#
# - R&D spending
# - Patents
# - High_Tech_Exports

# %%
rd = pd.read_csv("data/R&D_Spending.csv", skiprows=4)
gdp.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  2.420569e+10  2.495889e+10  2.707323e+10  3.176914e+10
# 2  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 3  NY.GDP.MKTP.CD  1.190481e+10  1.270772e+10  1.363059e+10  1.446891e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2017          2018          2019  \
# 0           NaN           NaN  ...  3.092428e+09  3.276188e+09  3.346623e+09
# 1  3.027955e+10  3.380618e+10  ...  9.780765e+11  1.020956e+12  1.018715e+12
# 2           NaN           NaN  ...  1.875346e+10  1.805322e+10  1.879944e+10
# 3  1.580356e+10  1.692088e+10  ...  6.940513e+11  7.778403e+11  1.026996e+12
# 4           NaN           NaN  ...  8.437694e+10  8.951279e+10  8.073443e+10
#
#            2020          2021          2022          2023          2024  2025  \
# 0  2.471419e+09  2.880903e+09  3.324034e+09  3.834730e+09  4.265651e+09   NaN
# 1  9.386076e+11  1.114145e+12  1.228968e+12  1.179359e+12  1.242694e+12   NaN
# 2  1.995593e+10  1.426000e+10  1.449724e+10  1.715223e+10           NaN   NaN
# 3  9.637847e+11  1.026651e+12  1.063649e+12  9.382384e+11  7.363850e+11   NaN
# 4  5.885246e+10  7.955954e+10  1.312122e+11  1.071677e+11  1.009989e+11   NaN
#
#    Unnamed: 70
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 71 columns]

# %%
patent = pd.read_csv("data/Patent_residents.csv", skiprows=4)
gdp.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  2.420569e+10  2.495889e+10  2.707323e+10  3.176914e+10
# 2  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 3  NY.GDP.MKTP.CD  1.190481e+10  1.270772e+10  1.363059e+10  1.446891e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2017          2018          2019  \
# 0           NaN           NaN  ...  3.092428e+09  3.276188e+09  3.346623e+09
# 1  3.027955e+10  3.380618e+10  ...  9.780765e+11  1.020956e+12  1.018715e+12
# 2           NaN           NaN  ...  1.875346e+10  1.805322e+10  1.879944e+10
# 3  1.580356e+10  1.692088e+10  ...  6.940513e+11  7.778403e+11  1.026996e+12
# 4           NaN           NaN  ...  8.437694e+10  8.951279e+10  8.073443e+10
#
#            2020          2021          2022          2023          2024  2025  \
# 0  2.471419e+09  2.880903e+09  3.324034e+09  3.834730e+09  4.265651e+09   NaN
# 1  9.386076e+11  1.114145e+12  1.228968e+12  1.179359e+12  1.242694e+12   NaN
# 2  1.995593e+10  1.426000e+10  1.449724e+10  1.715223e+10           NaN   NaN
# 3  9.637847e+11  1.026651e+12  1.063649e+12  9.382384e+11  7.363850e+11   NaN
# 4  5.885246e+10  7.955954e+10  1.312122e+11  1.071677e+11  1.009989e+11   NaN
#
#    Unnamed: 70
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 71 columns]

# %%
hightech = pd.read_csv("data/High_Tech_Exports.csv", skiprows=4)
gdp.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  2.420569e+10  2.495889e+10  2.707323e+10  3.176914e+10
# 2  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 3  NY.GDP.MKTP.CD  1.190481e+10  1.270772e+10  1.363059e+10  1.446891e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2017          2018          2019  \
# 0           NaN           NaN  ...  3.092428e+09  3.276188e+09  3.346623e+09
# 1  3.027955e+10  3.380618e+10  ...  9.780765e+11  1.020956e+12  1.018715e+12
# 2           NaN           NaN  ...  1.875346e+10  1.805322e+10  1.879944e+10
# 3  1.580356e+10  1.692088e+10  ...  6.940513e+11  7.778403e+11  1.026996e+12
# 4           NaN           NaN  ...  8.437694e+10  8.951279e+10  8.073443e+10
#
#            2020          2021          2022          2023          2024  2025  \
# 0  2.471419e+09  2.880903e+09  3.324034e+09  3.834730e+09  4.265651e+09   NaN
# 1  9.386076e+11  1.114145e+12  1.228968e+12  1.179359e+12  1.242694e+12   NaN
# 2  1.995593e+10  1.426000e+10  1.449724e+10  1.715223e+10           NaN   NaN
# 3  9.637847e+11  1.026651e+12  1.063649e+12  9.382384e+11  7.363850e+11   NaN
# 4  5.885246e+10  7.955954e+10  1.312122e+11  1.071677e+11  1.009989e+11   NaN
#
#    Unnamed: 70
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 71 columns]

# %% [markdown]
# ## 6 Data Cleaning

# %%
def make_long(df, value_name):
    df_long = df.melt(
        id_vars=["Country Name", "Country Code", "Indicator Name", "Indicator Code"],
        var_name="year",
        value_name=value_name
    )
    
    df_long = df_long[["Country Name", "Country Code", "year", value_name]]
    df_long = df_long.rename(columns={
        "Country Name": "country",
        "Country Code": "code"
    })
    
    df_long["year"] = pd.to_numeric(df_long["year"], errors="coerce")
    df_long = df_long.dropna(subset=["year"])
    df_long["year"] = df_long["year"].astype(int)
    
    return df_long

# %% [markdown]
# ### 각 파일을 세로형으로

# %%
gdp_long = make_long(gdp, "gdp")
exports_long = make_long(exports, "exports_usd")
hightech_long = make_long(hightech, "hightech_exports")
military_usd_long = make_long(military_usd, "military_usd")
military_per_gdp_long = make_long(military_per_gdp, "military_per_gdp")
patent_long = make_long(patent, "patent_residents")
population_long = make_long(population, "population")
rd_long = make_long(rd, "rd_spending")

# %% [markdown]
# ### 나라와 연도 기준으로 합치기

# %%
df = gdp_long.merge(exports_long, on=["country", "code", "year"], how="outer")
df = df.merge(hightech_long, on=["country", "code", "year"], how="outer")
df = df.merge(military_usd_long, on=["country", "code", "year"], how="outer")
df = df.merge(military_per_gdp_long, on=["country", "code", "year"], how="outer")
df = df.merge(patent_long, on=["country", "code", "year"], how="outer")
df = df.merge(population_long, on=["country", "code", "year"], how="outer")
df = df.merge(rd_long, on=["country", "code", "year"], how="outer")

# %% [markdown]
# ### 결과 확인

# %%
print(df.head())
print(df.shape)
print(df.columns)
# Out:
#        country code  year  gdp   exports_usd  hightech_exports  military_usd  \
# 0  Afghanistan  AFG  1960  NaN  2.222223e+07               NaN           NaN
# 1  Afghanistan  AFG  1961  NaN  2.444446e+07               NaN           NaN
# 2  Afghanistan  AFG  1962  NaN  2.666668e+07               NaN           NaN
# 3  Afghanistan  AFG  1963  NaN  6.888892e+07               NaN           NaN
# 4  Afghanistan  AFG  1964  NaN  7.111114e+07               NaN           NaN
#
#    military_per_gdp  patent_residents  population  rd_spending
# 0               NaN               NaN   9035043.0          NaN
# 1               NaN               NaN   9214083.0          NaN
# 2               NaN               NaN   9404406.0          NaN
# 3               NaN               NaN   9604487.0          NaN
# 4               NaN               NaN   9814318.0          NaN
# (17556, 11)
# Index(['country', 'code', 'year', 'gdp', 'exports_usd', 'hightech_exports',
#        'military_usd', 'military_per_gdp', 'patent_residents', 'population',
#        'rd_spending'],
#       dtype='object')

# %% [markdown]
# ## 7 Final Dataset
