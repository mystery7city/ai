# %% [markdown]
# # National Power Index Data
# - 국력 분석 데이터셋

# %% [markdown]
# ## 1 Data Sources
#
# - World Bank

# %% [markdown]
# ## 2 Economy Data
#
# - GDP
# - GDP per capita
# - Trade

# %% [markdown]
# ## 3 Military Data
#
# - Military spending
# - Personnel

# %% [markdown]
# ## 4 Population Data
#
# - Population
# - Workforce

# %% [markdown]
# ## 5 Technology Data
#
# - R&D spending
# - Patents

# %% [markdown]
# ## 6 Data Cleaning

# %% [markdown]
# ## 7 Final Dataset
