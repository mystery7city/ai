# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:70% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:22pt;}
div.text_cell_render.rendered_html{font-size:18pt;}
div.text_cell_render ul li{font-size:22pt; line-height:30px;}
div.output {font-size:22pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:22pt;}
div.prompt {min-width:40px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:22pt;padding:5px;}
table.dataframe{font-size:22px;}
</style>
"""))
# Out:
# <style>
# div.container{width:70% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:22pt;}
# div.text_cell_render.rendered_html{font-size:18pt;}
# div.text_cell_render ul li{font-size:22pt; line-height:30px;}
# div.output {font-size:22pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:22pt;}
# div.prompt {min-width:40px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:22pt;padding:5px;}
# table.dataframe{font-size:22px;}
# </style>

# %%
import numpy as np
from tensorflow.keras.models import Sequential # 모델 객체 생성ㄴ
from tensorflow.keras.layers import Input, Dense # 모델 Layer 쌓을 때 필요
import matplotlib.pyplot as plt

# %%
# data set
x_data = np.array([[0, 0],
                   [0, 1],
                   [1, 0], 
                   [1, 1]])
y_data = np.array([[0], [1], [1], [0]])
# 2. 모델구성
model = Sequential()
# model.add(Input(shape=2))
model.add(Dense(units=10, # 출력 갯수
               input_dim=2, # input_shape = (2,) # 입력 갯수
               activation='relu'))
model.add(Dense(units=20, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
print(model.summary())

# 3. 모델 학습과정 설정

model.compile(loss = 'binary_crossentropy',
              optimizer='adam',
              metrics=['binary_accuracy']) # 2진분류
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 10)                30
#
#  dense_21 (Dense)            (None, 20)                220
#
#  dense_22 (Dense)            (None, 10)                210
#
#  dense_23 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 471
# Trainable params: 471
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# 4. 학습
hist = model.fit(x_data, y_data, epochs=300, verbose=2)
# Out:
# Epoch 1/300
# 1/1 - 0s - loss: 0.7437 - binary_accuracy: 0.5000 - 433ms/epoch - 433ms/step
# Epoch 2/300
# 1/1 - 0s - loss: 0.7417 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 3/300
# 1/1 - 0s - loss: 0.7395 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 4/300
# 1/1 - 0s - loss: 0.7375 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 5/300
# 1/1 - 0s - loss: 0.7354 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 6/300
# 1/1 - 0s - loss: 0.7335 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 7/300
# 1/1 - 0s - loss: 0.7315 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 8/300
# 1/1 - 0s - loss: 0.7295 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 9/300
# 1/1 - 0s - loss: 0.7275 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 10/300
# 1/1 - 0s - loss: 0.7255 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 11/300
# 1/1 - 0s - loss: 0.7235 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 12/300
# 1/1 - 0s - loss: 0.7216 - binary_accuracy: 0.2500 - 4ms/epoch - 4ms/step
# Epoch 13/300
# 1/1 - 0s - loss: 0.7197 - binary_accuracy: 0.2500 - 1ms/epoch - 1ms/step
# Epoch 14/300
# 1/1 - 0s - loss: 0.7178 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 15/300
# 1/1 - 0s - loss: 0.7159 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 16/300
# 1/1 - 0s - loss: 0.7141 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 17/300
# 1/1 - 0s - loss: 0.7123 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 18/300
# 1/1 - 0s - loss: 0.7105 - binary_accuracy: 0.2500 - 997us/epoch - 997us/step
# Epoch 19/300
# 1/1 - 0s - loss: 0.7088 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 20/300
# 1/1 - 0s - loss: 0.7071 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 21/300
# 1/1 - 0s - loss: 0.7055 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 22/300
# 1/1 - 0s - loss: 0.7038 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 23/300
# 1/1 - 0s - loss: 0.7023 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 24/300
# 1/1 - 0s - loss: 0.7007 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 25/300
# 1/1 - 0s - loss: 0.6991 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 26/300
# 1/1 - 0s - loss: 0.6976 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 27/300
# 1/1 - 0s - loss: 0.6961 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 28/300
# 1/1 - 0s - loss: 0.6947 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 29/300
# 1/1 - 0s - loss: 0.6932 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 30/300
# 1/1 - 0s - loss: 0.6917 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 31/300
# 1/1 - 0s - loss: 0.6903 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 32/300
# 1/1 - 0s - loss: 0.6891 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 33/300
# 1/1 - 0s - loss: 0.6879 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 34/300
# 1/1 - 0s - loss: 0.6868 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 35/300
# 1/1 - 0s - loss: 0.6856 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 36/300
# 1/1 - 0s - loss: 0.6845 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 37/300
# 1/1 - 0s - loss: 0.6834 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 38/300
# 1/1 - 0s - loss: 0.6822 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 39/300
# 1/1 - 0s - loss: 0.6811 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 40/300
# 1/1 - 0s - loss: 0.6800 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 41/300
# 1/1 - 0s - loss: 0.6789 - binary_accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 42/300
# 1/1 - 0s - loss: 0.6778 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 43/300
# 1/1 - 0s - loss: 0.6767 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 44/300
# 1/1 - 0s - loss: 0.6756 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 45/300
# 1/1 - 0s - loss: 0.6746 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 46/300
# 1/1 - 0s - loss: 0.6738 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 47/300
# 1/1 - 0s - loss: 0.6731 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 48/300
# 1/1 - 0s - loss: 0.6724 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 49/300
# 1/1 - 0s - loss: 0.6717 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 50/300
# 1/1 - 0s - loss: 0.6710 - binary_accuracy: 0.7500 - 12ms/epoch - 12ms/step
# Epoch 51/300
# 1/1 - 0s - loss: 0.6703 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 52/300
# 1/1 - 0s - loss: 0.6696 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 53/300
# 1/1 - 0s - loss: 0.6688 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 54/300
# 1/1 - 0s - loss: 0.6680 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 55/300
# 1/1 - 0s - loss: 0.6673 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 56/300
# 1/1 - 0s - loss: 0.6665 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 57/300
# 1/1 - 0s - loss: 0.6657 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 58/300
# 1/1 - 0s - loss: 0.6649 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 59/300
# 1/1 - 0s - loss: 0.6641 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 60/300
# 1/1 - 0s - loss: 0.6633 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 61/300
# 1/1 - 0s - loss: 0.6625 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 62/300
# 1/1 - 0s - loss: 0.6617 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 63/300
# 1/1 - 0s - loss: 0.6610 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 64/300
# 1/1 - 0s - loss: 0.6602 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 65/300
# 1/1 - 0s - loss: 0.6595 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 66/300
# 1/1 - 0s - loss: 0.6587 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 67/300
# 1/1 - 0s - loss: 0.6580 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 68/300
# 1/1 - 0s - loss: 0.6572 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 69/300
# 1/1 - 0s - loss: 0.6564 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 70/300
# 1/1 - 0s - loss: 0.6555 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 71/300
# 1/1 - 0s - loss: 0.6547 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 72/300
# 1/1 - 0s - loss: 0.6539 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 73/300
# 1/1 - 0s - loss: 0.6531 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 74/300
# 1/1 - 0s - loss: 0.6523 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 75/300
# 1/1 - 0s - loss: 0.6514 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 76/300
# 1/1 - 0s - loss: 0.6506 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 77/300
# 1/1 - 0s - loss: 0.6497 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 78/300
# 1/1 - 0s - loss: 0.6489 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 79/300
# 1/1 - 0s - loss: 0.6479 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 80/300
# 1/1 - 0s - loss: 0.6471 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 81/300
# 1/1 - 0s - loss: 0.6462 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 82/300
# 1/1 - 0s - loss: 0.6453 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 83/300
# 1/1 - 0s - loss: 0.6445 - binary_accuracy: 0.7500 - 996us/epoch - 996us/step
# Epoch 84/300
# 1/1 - 0s - loss: 0.6437 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 85/300
# 1/1 - 0s - loss: 0.6427 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 86/300
# 1/1 - 0s - loss: 0.6417 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 87/300
# 1/1 - 0s - loss: 0.6407 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 88/300
# 1/1 - 0s - loss: 0.6396 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 89/300
# 1/1 - 0s - loss: 0.6385 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 90/300
# 1/1 - 0s - loss: 0.6374 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 91/300
# 1/1 - 0s - loss: 0.6363 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 92/300
# 1/1 - 0s - loss: 0.6351 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 93/300
# 1/1 - 0s - loss: 0.6340 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 94/300
# 1/1 - 0s - loss: 0.6329 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 95/300
# 1/1 - 0s - loss: 0.6317 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 96/300
# 1/1 - 0s - loss: 0.6305 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 97/300
# 1/1 - 0s - loss: 0.6293 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 98/300
# 1/1 - 0s - loss: 0.6282 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 99/300
# 1/1 - 0s - loss: 0.6271 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 100/300
# 1/1 - 0s - loss: 0.6259 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 101/300
# 1/1 - 0s - loss: 0.6247 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 102/300
# 1/1 - 0s - loss: 0.6235 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 103/300
# 1/1 - 0s - loss: 0.6222 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 104/300
# 1/1 - 0s - loss: 0.6209 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 105/300
# 1/1 - 0s - loss: 0.6197 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 106/300
# 1/1 - 0s - loss: 0.6185 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 107/300
# 1/1 - 0s - loss: 0.6172 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 108/300
# 1/1 - 0s - loss: 0.6159 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 109/300
# 1/1 - 0s - loss: 0.6147 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 110/300
# 1/1 - 0s - loss: 0.6134 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 111/300
# 1/1 - 0s - loss: 0.6121 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 112/300
# 1/1 - 0s - loss: 0.6109 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 113/300
# 1/1 - 0s - loss: 0.6095 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 114/300
# 1/1 - 0s - loss: 0.6081 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 115/300
# 1/1 - 0s - loss: 0.6068 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 116/300
# 1/1 - 0s - loss: 0.6055 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 117/300
# 1/1 - 0s - loss: 0.6042 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 118/300
# 1/1 - 0s - loss: 0.6027 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 119/300
# 1/1 - 0s - loss: 0.6013 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 120/300
# 1/1 - 0s - loss: 0.5999 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 121/300
# 1/1 - 0s - loss: 0.5985 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 122/300
# 1/1 - 0s - loss: 0.5971 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 123/300
# 1/1 - 0s - loss: 0.5956 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 124/300
# 1/1 - 0s - loss: 0.5942 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 125/300
# 1/1 - 0s - loss: 0.5927 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 126/300
# 1/1 - 0s - loss: 0.5912 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 127/300
# 1/1 - 0s - loss: 0.5896 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 128/300
# 1/1 - 0s - loss: 0.5881 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 129/300
# 1/1 - 0s - loss: 0.5865 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 130/300
# 1/1 - 0s - loss: 0.5849 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 131/300
# 1/1 - 0s - loss: 0.5832 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 132/300
# 1/1 - 0s - loss: 0.5814 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 133/300
# 1/1 - 0s - loss: 0.5797 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 134/300
# 1/1 - 0s - loss: 0.5779 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 135/300
# 1/1 - 0s - loss: 0.5760 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 136/300
# 1/1 - 0s - loss: 0.5741 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 137/300
# 1/1 - 0s - loss: 0.5722 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 138/300
# 1/1 - 0s - loss: 0.5702 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 139/300
# 1/1 - 0s - loss: 0.5681 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 140/300
# 1/1 - 0s - loss: 0.5660 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 141/300
# 1/1 - 0s - loss: 0.5644 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 142/300
# 1/1 - 0s - loss: 0.5626 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 143/300
# 1/1 - 0s - loss: 0.5610 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 144/300
# 1/1 - 0s - loss: 0.5592 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 145/300
# 1/1 - 0s - loss: 0.5572 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 146/300
# 1/1 - 0s - loss: 0.5553 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 147/300
# 1/1 - 0s - loss: 0.5533 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 148/300
# 1/1 - 0s - loss: 0.5513 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 149/300
# 1/1 - 0s - loss: 0.5493 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 150/300
# 1/1 - 0s - loss: 0.5472 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 151/300
# 1/1 - 0s - loss: 0.5452 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 152/300
# 1/1 - 0s - loss: 0.5434 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 153/300
# 1/1 - 0s - loss: 0.5414 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 154/300
# 1/1 - 0s - loss: 0.5392 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 155/300
# 1/1 - 0s - loss: 0.5371 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 156/300
# 1/1 - 0s - loss: 0.5353 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 157/300
# 1/1 - 0s - loss: 0.5333 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 158/300
# 1/1 - 0s - loss: 0.5314 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 159/300
# 1/1 - 0s - loss: 0.5293 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 160/300
# 1/1 - 0s - loss: 0.5271 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 161/300
# 1/1 - 0s - loss: 0.5250 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 162/300
# 1/1 - 0s - loss: 0.5229 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 163/300
# 1/1 - 0s - loss: 0.5209 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 164/300
# 1/1 - 0s - loss: 0.5188 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 165/300
# 1/1 - 0s - loss: 0.5167 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 166/300
# 1/1 - 0s - loss: 0.5146 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 167/300
# 1/1 - 0s - loss: 0.5126 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 168/300
# 1/1 - 0s - loss: 0.5106 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 169/300
# 1/1 - 0s - loss: 0.5085 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 170/300
# 1/1 - 0s - loss: 0.5063 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 171/300
# 1/1 - 0s - loss: 0.5041 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 172/300
# 1/1 - 0s - loss: 0.5022 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 173/300
# 1/1 - 0s - loss: 0.5002 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 174/300
# 1/1 - 0s - loss: 0.4981 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 175/300
# 1/1 - 0s - loss: 0.4960 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 176/300
# 1/1 - 0s - loss: 0.4938 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 177/300
# 1/1 - 0s - loss: 0.4919 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 178/300
# 1/1 - 0s - loss: 0.4897 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 179/300
# 1/1 - 0s - loss: 0.4875 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 180/300
# 1/1 - 0s - loss: 0.4854 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 181/300
# 1/1 - 0s - loss: 0.4834 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 182/300
# 1/1 - 0s - loss: 0.4813 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 183/300
# 1/1 - 0s - loss: 0.4792 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 184/300
# 1/1 - 0s - loss: 0.4771 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 185/300
# 1/1 - 0s - loss: 0.4750 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 186/300
# 1/1 - 0s - loss: 0.4728 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 187/300
# 1/1 - 0s - loss: 0.4707 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 188/300
# 1/1 - 0s - loss: 0.4687 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 189/300
# 1/1 - 0s - loss: 0.4668 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 190/300
# 1/1 - 0s - loss: 0.4646 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 191/300
# 1/1 - 0s - loss: 0.4625 - binary_accuracy: 1.0000 - 997us/epoch - 997us/step
# Epoch 192/300
# 1/1 - 0s - loss: 0.4605 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 193/300
# 1/1 - 0s - loss: 0.4587 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 194/300
# 1/1 - 0s - loss: 0.4564 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 195/300
# 1/1 - 0s - loss: 0.4542 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 196/300
# 1/1 - 0s - loss: 0.4520 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 197/300
# 1/1 - 0s - loss: 0.4503 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 198/300
# 1/1 - 0s - loss: 0.4482 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 199/300
# 1/1 - 0s - loss: 0.4460 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 200/300
# 1/1 - 0s - loss: 0.4440 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 201/300
# 1/1 - 0s - loss: 0.4420 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 202/300
# 1/1 - 0s - loss: 0.4399 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 203/300
# 1/1 - 0s - loss: 0.4379 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 204/300
# 1/1 - 0s - loss: 0.4360 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 205/300
# 1/1 - 0s - loss: 0.4338 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 206/300
# 1/1 - 0s - loss: 0.4318 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 207/300
# 1/1 - 0s - loss: 0.4299 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 208/300
# 1/1 - 0s - loss: 0.4280 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 209/300
# 1/1 - 0s - loss: 0.4260 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 210/300
# 1/1 - 0s - loss: 0.4239 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 211/300
# 1/1 - 0s - loss: 0.4220 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 212/300
# 1/1 - 0s - loss: 0.4200 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 213/300
# 1/1 - 0s - loss: 0.4183 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 214/300
# 1/1 - 0s - loss: 0.4163 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 215/300
# 1/1 - 0s - loss: 0.4143 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 216/300
# 1/1 - 0s - loss: 0.4124 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 217/300
# 1/1 - 0s - loss: 0.4104 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 218/300
# 1/1 - 0s - loss: 0.4085 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 219/300
# 1/1 - 0s - loss: 0.4065 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 220/300
# 1/1 - 0s - loss: 0.4046 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 221/300
# 1/1 - 0s - loss: 0.4027 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 222/300
# 1/1 - 0s - loss: 0.4007 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 223/300
# 1/1 - 0s - loss: 0.3988 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 224/300
# 1/1 - 0s - loss: 0.3969 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 225/300
# 1/1 - 0s - loss: 0.3950 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 226/300
# 1/1 - 0s - loss: 0.3930 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 227/300
# 1/1 - 0s - loss: 0.3912 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 228/300
# 1/1 - 0s - loss: 0.3894 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 229/300
# 1/1 - 0s - loss: 0.3877 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 230/300
# 1/1 - 0s - loss: 0.3856 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 231/300
# 1/1 - 0s - loss: 0.3838 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 232/300
# 1/1 - 0s - loss: 0.3820 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 233/300
# 1/1 - 0s - loss: 0.3802 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 234/300
# 1/1 - 0s - loss: 0.3784 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 235/300
# 1/1 - 0s - loss: 0.3767 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 236/300
# 1/1 - 0s - loss: 0.3749 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 237/300
# 1/1 - 0s - loss: 0.3732 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 238/300
# 1/1 - 0s - loss: 0.3714 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 239/300
# 1/1 - 0s - loss: 0.3696 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 240/300
# 1/1 - 0s - loss: 0.3679 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 241/300
# 1/1 - 0s - loss: 0.3660 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 242/300
# 1/1 - 0s - loss: 0.3643 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 243/300
# 1/1 - 0s - loss: 0.3625 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 244/300
# 1/1 - 0s - loss: 0.3609 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 245/300
# 1/1 - 0s - loss: 0.3591 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 246/300
# 1/1 - 0s - loss: 0.3575 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 247/300
# 1/1 - 0s - loss: 0.3558 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 248/300
# 1/1 - 0s - loss: 0.3541 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 249/300
# 1/1 - 0s - loss: 0.3524 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 250/300
# 1/1 - 0s - loss: 0.3507 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 251/300
# 1/1 - 0s - loss: 0.3491 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 252/300
# 1/1 - 0s - loss: 0.3474 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 253/300
# 1/1 - 0s - loss: 0.3461 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 254/300
# 1/1 - 0s - loss: 0.3444 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 255/300
# 1/1 - 0s - loss: 0.3427 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 256/300
# 1/1 - 0s - loss: 0.3412 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 257/300
# 1/1 - 0s - loss: 0.3397 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 258/300
# 1/1 - 0s - loss: 0.3381 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 259/300
# 1/1 - 0s - loss: 0.3367 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 260/300
# 1/1 - 0s - loss: 0.3349 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 261/300
# 1/1 - 0s - loss: 0.3333 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 262/300
# 1/1 - 0s - loss: 0.3318 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 263/300
# 1/1 - 0s - loss: 0.3303 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 264/300
# 1/1 - 0s - loss: 0.3287 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 265/300
# 1/1 - 0s - loss: 0.3271 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 266/300
# 1/1 - 0s - loss: 0.3259 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 267/300
# 1/1 - 0s - loss: 0.3241 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 268/300
# 1/1 - 0s - loss: 0.3226 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 269/300
# 1/1 - 0s - loss: 0.3212 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 270/300
# 1/1 - 0s - loss: 0.3198 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 271/300
# 1/1 - 0s - loss: 0.3183 - binary_accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 272/300
# 1/1 - 0s - loss: 0.3172 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 273/300
# 1/1 - 0s - loss: 0.3153 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 274/300
# 1/1 - 0s - loss: 0.3139 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 275/300
# 1/1 - 0s - loss: 0.3124 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 276/300
# 1/1 - 0s - loss: 0.3110 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 277/300
# 1/1 - 0s - loss: 0.3095 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 278/300
# 1/1 - 0s - loss: 0.3081 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 279/300
# 1/1 - 0s - loss: 0.3066 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 280/300
# 1/1 - 0s - loss: 0.3051 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 281/300
# 1/1 - 0s - loss: 0.3037 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 282/300
# 1/1 - 0s - loss: 0.3023 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 283/300
# 1/1 - 0s - loss: 0.3010 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 284/300
# 1/1 - 0s - loss: 0.2996 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 285/300
# 1/1 - 0s - loss: 0.2984 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 286/300
# 1/1 - 0s - loss: 0.2967 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 287/300
# 1/1 - 0s - loss: 0.2954 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 288/300
# 1/1 - 0s - loss: 0.2941 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 289/300
# 1/1 - 0s - loss: 0.2930 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 290/300
# 1/1 - 0s - loss: 0.2914 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 291/300
# 1/1 - 0s - loss: 0.2901 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 292/300
# 1/1 - 0s - loss: 0.2887 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 293/300
# 1/1 - 0s - loss: 0.2874 - binary_accuracy: 1.0000 - 998us/epoch - 998us/step
# Epoch 294/300
# 1/1 - 0s - loss: 0.2860 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 295/300
# 1/1 - 0s - loss: 0.2847 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 296/300
# 1/1 - 0s - loss: 0.2836 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 297/300
# 1/1 - 0s - loss: 0.2821 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 298/300
# 1/1 - 0s - loss: 0.2808 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 299/300
# 1/1 - 0s - loss: 0.2800 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 300/300
# 1/1 - 0s - loss: 0.2784 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
