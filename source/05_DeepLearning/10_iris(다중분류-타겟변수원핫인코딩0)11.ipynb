# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:80% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:24pt;}
div.text_cell_render.rendered_html{font-size:20pt;}
div.text_cell_render ul li, code{font-size:22pt; line-height:30px;}
div.output {font-size:24pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:24pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:24pt;padding:5px;}
table.dataframe{font-size:24px;}
</style>
"""))
# Out:
# <style>
# div.container{width:80% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:24pt;}
# div.text_cell_render.rendered_html{font-size:20pt;}
# div.text_cell_render ul li, code{font-size:22pt; line-height:30px;}
# div.output {font-size:24pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:24pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:24pt;padding:5px;}
# table.dataframe{font-size:24px;}
# </style>

# %%
import os # 모델 저장할 폴더가 있는지 여부와 폴더 생성
import numpy as np
import pandas as pd # get_dummies(원핫인코딩), crosstab
import seaborn as sns # iris 데이터(데이터프레임) 가져오기
from sklearn import datasets # iris 데이터(X, y) 가져오기
from sklearn.preprocessing import LabelEncoder # 라벨인코더
from tensorflow.keras.utils import to_categorical # 원핫인코딩 
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, save_model, load_model
from tensorflow.keras.layers import Input, Dense, Dropout, LeakyReLU
from tensorflow.keras import metrics # compile
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt

# %% [markdown]
# - 데이터 셋 생성(seaborn) & 전처리
#     X, y(setosa,versicolor,virginica라벨인코딩-원핫코딩)분리 -> train과 test셋 분리(8:2)
# - 모델 구성(입력4 -> 출력3, layer5: 4->64->128->50->30->3)
# - 모델 학습과정 설정
# - 모델 학습(Earlystopping, ModelCheckpoint추가)
# - 모델평가(시각화, 현재모델과 저장된 최고의 모델 평가, 교차표==혼동행렬)
# - 모델예측/저장

# %% [markdown]
# # 1. 데이터 셋 생성(seaborn) & 전처리

# %%
iris = sns.load_dataset('iris')
iris.loc[::50]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 50            7.0          3.2           4.7          1.4  versicolor
# 100           6.3          3.3           6.0          2.5   virginica

# %%
# 문자변수 원핫인코딩 방법1
encoder = LabelEncoder()
iris['y'] = encoder.fit_transform(iris['species'])
display(iris.loc[::50])
# utils.to_categorical(iris['species'])[:5]
# to_categorical을 하려면 숫자필드로 라벨인코딩먼저
to_categorical(iris['y'])[::50]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  y
# 0             5.1          3.5           1.4          0.2      setosa  0
# 50            7.0          3.2           4.7          1.4  versicolor  1
# 100           6.3          3.3           6.0          2.5   virginica  2
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]], dtype=float32)

# %%
# 문자변수 원핫인코딩 방법2
pd.get_dummies(iris.species)[::50]
# Out:
#      setosa  versicolor  virginica
# 0         1           0          0
# 50        0           1          0
# 100       0           0          1

# %%
# 1. 데이터 생성 및 전처리
iris = sns.load_dataset('iris')
# 독립변수와 종속변수 분리
iris_X = iris.iloc[:, :-1].to_numpy()
iris_y = iris.iloc[:, -1]
iris_Y = pd.get_dummies(iris_y).values
# 훈련셋 : 테스트셋 = 8 : 2
X_train, X_test, Y_train, Y_test = train_test_split(iris_X, iris_Y,
                                                   test_size=0.2,
                                                   stratify=iris_Y, # 층화추출
                                                   random_state=4) 
X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((120, 4), (120, 3), (30, 4), (30, 3))

# %%
# 층화 추출했는지 확인 
pd.Series(np.argmax(Y_train, axis=1)).value_counts()
# Out:
# 0    40
# 1    40
# 2    40
# dtype: int64

# %%
pd.Series(np.argmax(Y_test, axis=1)).value_counts()
# Out:
# 1    10
# 2    10
# 0    10
# dtype: int64

# %% [markdown]
# # 2. 모델 구성
# (입력4 -> 출력3, layer5: 4->64->128->50->30->3)

# %%
model = Sequential()
model.add(Dense(units=64, input_dim=4, activation='relu'))
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=30, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(units=3, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                320
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 50)                6450
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense_3 (Dense)             (None, 30)                1530
#
#  dropout_2 (Dropout)         (None, 30)                0
#
#  dense_4 (Dense)             (None, 3)                 93
#
# =================================================================
# Total params: 16,713
# Trainable params: 16,713
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. 모델 학습과정 설정

# %%
model.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# %% [markdown]
# # 4. 모델 학습
# (Earlystopping, ModelCheckpoint추가)

# %%
model_save_folder = './model/'
import os
if not os.path.exists(model_save_folder): # 폴더 없으면 폴더 생성
    os.mkdir(model_save_folder)
file = model_save_folder \
        + 'iris-{epoch:03d}-loss{val_loss:.4f}-acc{val_accuracy:.4f}.h5'
# 콜백객체
checkpoint = ModelCheckpoint(
                    filepath=file,
                    monitor='val_accuracy', # 모니터링 지표:loss, val_loss, accuracy
                    save_best_only=True,    # 모니터링 지표가 개선된 경우만 저장
                    mode = 'max',
                    verbose=1) # 로그 출력 여부
earlystopping = EarlyStopping(patience=40)# monitor='val_loss' 기본값
hist=model.fit(X_train,Y_train,batch_size=40,
               epochs=200,
               validation_split=0.2,
               callbacks=[checkpoint,earlystopping])
# Out:
# Epoch 1/200
# 1/3 [=========>....................] - ETA: 1s - loss: 1.4463 - accuracy: 0.3250
# Epoch 1: val_accuracy improved from -inf to 0.45833, saving model to ./model\iris-001-loss1.1797-acc0.4583.h5
# 3/3 [==============================] - 1s 119ms/step - loss: 1.3266 - accuracy: 0.4062 - val_loss: 1.1797 - val_accuracy: 0.4583
# Epoch 2/200
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0875 - accuracy: 0.5000
# Epoch 2: val_accuracy improved from 0.45833 to 0.58333, saving model to ./model\iris-002-loss1.0145-acc0.5833.h5
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1297 - accuracy: 0.4792 - val_loss: 1.0145 - val_accuracy: 0.5833
# Epoch 3/200
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0139 - accuracy: 0.5250
# Epoch 3: val_accuracy did not improve from 0.58333
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9824 - accuracy: 0.5521 - val_loss: 0.9349 - val_accuracy: 0.5833
# Epoch 4/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.9829 - accuracy: 0.5000
# Epoch 4: val_accuracy improved from 0.58333 to 0.91667, saving model to ./model\iris-004-loss0.8277-acc0.9167.h5
# 3/3 [==============================] - 0s 30ms/step - loss: 0.9281 - accuracy: 0.6250 - val_loss: 0.8277 - val_accuracy: 0.9167
# Epoch 5/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.8795 - accuracy: 0.6000
# Epoch 5: val_accuracy did not improve from 0.91667
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8565 - accuracy: 0.6354 - val_loss: 0.7404 - val_accuracy: 0.7917
# Epoch 6/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.8062 - accuracy: 0.6000
# Epoch 6: val_accuracy did not improve from 0.91667
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7906 - accuracy: 0.6771 - val_loss: 0.6687 - val_accuracy: 0.7500
# Epoch 7/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7326 - accuracy: 0.6750
# Epoch 7: val_accuracy did not improve from 0.91667
# 3/3 [==============================] - 0s 20ms/step - loss: 0.7196 - accuracy: 0.6667 - val_loss: 0.5987 - val_accuracy: 0.7917
# Epoch 8/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6745 - accuracy: 0.6500
# Epoch 8: val_accuracy did not improve from 0.91667
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6841 - accuracy: 0.6562 - val_loss: 0.5327 - val_accuracy: 0.7917
# Epoch 9/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6511 - accuracy: 0.6750
# Epoch 9: val_accuracy did not improve from 0.91667
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6423 - accuracy: 0.7292 - val_loss: 0.4866 - val_accuracy: 0.7500
# Epoch 10/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.5833 - accuracy: 0.7000
# Epoch 10: val_accuracy did not improve from 0.91667
# 3/3 [==============================] - 0s 14ms/step - loss: 0.5668 - accuracy: 0.7292 - val_loss: 0.4497 - val_accuracy: 0.7500
# Epoch 11/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.5832 - accuracy: 0.7000
# Epoch 11: val_accuracy did not improve from 0.91667
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6044 - accuracy: 0.6875 - val_loss: 0.4191 - val_accuracy: 0.7917
# Epoch 12/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.5683 - accuracy: 0.6750
# Epoch 12: val_accuracy improved from 0.91667 to 1.00000, saving model to ./model\iris-012-loss0.4088-acc1.0000.h5
# 3/3 [==============================] - 0s 29ms/step - loss: 0.5307 - accuracy: 0.7396 - val_loss: 0.4088 - val_accuracy: 1.0000
# Epoch 13/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.5087 - accuracy: 0.8250
# Epoch 13: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4819 - accuracy: 0.8333 - val_loss: 0.4269 - val_accuracy: 0.8333
# Epoch 14/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4889 - accuracy: 0.8000
# Epoch 14: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5001 - accuracy: 0.8125 - val_loss: 0.3858 - val_accuracy: 0.9583
# Epoch 15/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6266 - accuracy: 0.7250
# Epoch 15: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.5098 - accuracy: 0.7812 - val_loss: 0.3321 - val_accuracy: 1.0000
# Epoch 16/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4999 - accuracy: 0.7250
# Epoch 16: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4881 - accuracy: 0.7604 - val_loss: 0.3080 - val_accuracy: 1.0000
# Epoch 17/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3552 - accuracy: 0.8500
# Epoch 17: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4050 - accuracy: 0.8333 - val_loss: 0.2853 - val_accuracy: 1.0000
# Epoch 18/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3868 - accuracy: 0.9250
# Epoch 18: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3831 - accuracy: 0.8750 - val_loss: 0.2998 - val_accuracy: 0.9583
# Epoch 19/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4227 - accuracy: 0.8250
# Epoch 19: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4045 - accuracy: 0.8125 - val_loss: 0.2454 - val_accuracy: 1.0000
# Epoch 20/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4445 - accuracy: 0.7250
# Epoch 20: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3751 - accuracy: 0.8125 - val_loss: 0.1984 - val_accuracy: 1.0000
# Epoch 21/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3436 - accuracy: 0.8500
# Epoch 21: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.3425 - accuracy: 0.8646 - val_loss: 0.1791 - val_accuracy: 1.0000
# Epoch 22/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3743 - accuracy: 0.8750
# Epoch 22: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3706 - accuracy: 0.8438 - val_loss: 0.1923 - val_accuracy: 1.0000
# Epoch 23/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3333 - accuracy: 0.8750
# Epoch 23: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3283 - accuracy: 0.8854 - val_loss: 0.2470 - val_accuracy: 0.9167
# Epoch 24/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3726 - accuracy: 0.8500
# Epoch 24: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2669 - accuracy: 0.9167 - val_loss: 0.1443 - val_accuracy: 1.0000
# Epoch 25/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2351 - accuracy: 0.9250
# Epoch 25: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2665 - accuracy: 0.8958 - val_loss: 0.1424 - val_accuracy: 0.9167
# Epoch 26/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3827 - accuracy: 0.8250
# Epoch 26: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3529 - accuracy: 0.8438 - val_loss: 0.1252 - val_accuracy: 1.0000
# Epoch 27/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1595 - accuracy: 0.9750
# Epoch 27: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2840 - accuracy: 0.8958 - val_loss: 0.1322 - val_accuracy: 1.0000
# Epoch 28/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3824 - accuracy: 0.8750
# Epoch 28: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.3285 - accuracy: 0.8958 - val_loss: 0.1379 - val_accuracy: 1.0000
# Epoch 29/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3247 - accuracy: 0.8750
# Epoch 29: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2365 - accuracy: 0.9271 - val_loss: 0.1013 - val_accuracy: 1.0000
# Epoch 30/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2348 - accuracy: 0.8750
# Epoch 30: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2545 - accuracy: 0.8646 - val_loss: 0.0964 - val_accuracy: 1.0000
# Epoch 31/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2724 - accuracy: 0.8500
# Epoch 31: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2181 - accuracy: 0.9062 - val_loss: 0.1108 - val_accuracy: 1.0000
# Epoch 32/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2885 - accuracy: 0.9000
# Epoch 32: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2274 - accuracy: 0.9479 - val_loss: 0.0909 - val_accuracy: 1.0000
# Epoch 33/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1770 - accuracy: 0.9250
# Epoch 33: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2313 - accuracy: 0.9167 - val_loss: 0.0805 - val_accuracy: 1.0000
# Epoch 34/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1800 - accuracy: 0.9750
# Epoch 34: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2626 - accuracy: 0.9062 - val_loss: 0.0802 - val_accuracy: 1.0000
# Epoch 35/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2528 - accuracy: 0.8750
# Epoch 35: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1927 - accuracy: 0.9271 - val_loss: 0.0702 - val_accuracy: 1.0000
# Epoch 36/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1839 - accuracy: 0.9250
# Epoch 36: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1801 - accuracy: 0.9375 - val_loss: 0.0652 - val_accuracy: 1.0000
# Epoch 37/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2432 - accuracy: 0.9000
# Epoch 37: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2002 - accuracy: 0.9167 - val_loss: 0.0739 - val_accuracy: 1.0000
# Epoch 38/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1818 - accuracy: 0.9500
# Epoch 38: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2236 - accuracy: 0.9062 - val_loss: 0.0762 - val_accuracy: 1.0000
# Epoch 39/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1113 - accuracy: 0.9500
# Epoch 39: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1689 - accuracy: 0.9271 - val_loss: 0.0485 - val_accuracy: 1.0000
# Epoch 40/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1005 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2052 - accuracy: 0.9271 - val_loss: 0.0476 - val_accuracy: 1.0000
# Epoch 41/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2833 - accuracy: 0.9000
# Epoch 41: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1981 - accuracy: 0.9271 - val_loss: 0.0478 - val_accuracy: 1.0000
# Epoch 42/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3320 - accuracy: 0.9000
# Epoch 42: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2136 - accuracy: 0.9375 - val_loss: 0.0768 - val_accuracy: 1.0000
# Epoch 43/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1949 - accuracy: 0.8750
# Epoch 43: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1503 - accuracy: 0.9375 - val_loss: 0.0614 - val_accuracy: 1.0000
# Epoch 44/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2197 - accuracy: 0.9000
# Epoch 44: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2147 - accuracy: 0.9271 - val_loss: 0.0386 - val_accuracy: 1.0000
# Epoch 45/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1771 - accuracy: 0.9000
# Epoch 45: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1801 - accuracy: 0.8958 - val_loss: 0.0361 - val_accuracy: 1.0000
# Epoch 46/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2185 - accuracy: 0.8500
# Epoch 46: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1546 - accuracy: 0.9167 - val_loss: 0.0353 - val_accuracy: 1.0000
# Epoch 47/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0852 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1328 - accuracy: 0.9792 - val_loss: 0.0637 - val_accuracy: 1.0000
# Epoch 48/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1576 - accuracy: 0.9250
# Epoch 48: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1625 - accuracy: 0.9375 - val_loss: 0.0588 - val_accuracy: 1.0000
# Epoch 49/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1513 - accuracy: 0.9250
# Epoch 49: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1453 - accuracy: 0.9583 - val_loss: 0.0367 - val_accuracy: 1.0000
# Epoch 50/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1945 - accuracy: 0.9250
# Epoch 50: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1957 - accuracy: 0.9062 - val_loss: 0.0338 - val_accuracy: 1.0000
# Epoch 51/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1216 - accuracy: 0.9750
# Epoch 51: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1377 - accuracy: 0.9583 - val_loss: 0.0334 - val_accuracy: 1.0000
# Epoch 52/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2102 - accuracy: 0.9500
# Epoch 52: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1599 - accuracy: 0.9479 - val_loss: 0.0427 - val_accuracy: 1.0000
# Epoch 53/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2367 - accuracy: 0.8750
# Epoch 53: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2011 - accuracy: 0.9167 - val_loss: 0.0462 - val_accuracy: 1.0000
# Epoch 54/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0948 - accuracy: 0.9750
# Epoch 54: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1446 - accuracy: 0.9583 - val_loss: 0.0267 - val_accuracy: 1.0000
# Epoch 55/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2385 - accuracy: 0.9500
# Epoch 55: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1800 - accuracy: 0.9479 - val_loss: 0.0269 - val_accuracy: 1.0000
# Epoch 56/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1600 - accuracy: 0.9250
# Epoch 56: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2202 - accuracy: 0.9167 - val_loss: 0.0287 - val_accuracy: 1.0000
# Epoch 57/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1520 - accuracy: 0.9500
# Epoch 57: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1293 - accuracy: 0.9583 - val_loss: 0.1348 - val_accuracy: 0.9583
# Epoch 58/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1251 - accuracy: 0.9500
# Epoch 58: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2434 - accuracy: 0.9062 - val_loss: 0.0851 - val_accuracy: 0.9583
# Epoch 59/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2816 - accuracy: 0.8250
# Epoch 59: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1964 - accuracy: 0.8854 - val_loss: 0.0253 - val_accuracy: 1.0000
# Epoch 60/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1284 - accuracy: 0.9250
# Epoch 60: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1350 - accuracy: 0.9479 - val_loss: 0.0351 - val_accuracy: 1.0000
# Epoch 61/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0629 - accuracy: 1.0000
# Epoch 61: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2112 - accuracy: 0.9271 - val_loss: 0.0249 - val_accuracy: 1.0000
# Epoch 62/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1436 - accuracy: 0.9500
# Epoch 62: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1522 - accuracy: 0.9375 - val_loss: 0.0889 - val_accuracy: 0.9583
# Epoch 63/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1478 - accuracy: 0.9500
# Epoch 63: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1964 - accuracy: 0.9271 - val_loss: 0.1131 - val_accuracy: 0.9583
# Epoch 64/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2157 - accuracy: 0.9250
# Epoch 64: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1678 - accuracy: 0.9375 - val_loss: 0.0275 - val_accuracy: 1.0000
# Epoch 65/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1716 - accuracy: 0.9250
# Epoch 65: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2184 - accuracy: 0.8958 - val_loss: 0.0304 - val_accuracy: 1.0000
# Epoch 66/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2399 - accuracy: 0.8750
# Epoch 66: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1691 - accuracy: 0.9375 - val_loss: 0.0362 - val_accuracy: 1.0000
# Epoch 67/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1657 - accuracy: 0.9750
# Epoch 67: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1382 - accuracy: 0.9688 - val_loss: 0.0565 - val_accuracy: 1.0000
# Epoch 68/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1304 - accuracy: 0.9500
# Epoch 68: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1280 - accuracy: 0.9479 - val_loss: 0.0353 - val_accuracy: 1.0000
# Epoch 69/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0969 - accuracy: 0.9750
# Epoch 69: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1186 - accuracy: 0.9688 - val_loss: 0.0238 - val_accuracy: 1.0000
# Epoch 70/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1119 - accuracy: 0.9750
# Epoch 70: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1282 - accuracy: 0.9375 - val_loss: 0.0228 - val_accuracy: 1.0000
# Epoch 71/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2106 - accuracy: 0.9250
# Epoch 71: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1379 - accuracy: 0.9479 - val_loss: 0.0296 - val_accuracy: 1.0000
# Epoch 72/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2189 - accuracy: 0.9250
# Epoch 72: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1292 - accuracy: 0.9688 - val_loss: 0.0476 - val_accuracy: 1.0000
# Epoch 73/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1385 - accuracy: 0.9250
# Epoch 73: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1407 - accuracy: 0.9271 - val_loss: 0.0321 - val_accuracy: 1.0000
# Epoch 74/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0659 - accuracy: 1.0000
# Epoch 74: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1140 - accuracy: 0.9688 - val_loss: 0.0268 - val_accuracy: 1.0000
# Epoch 75/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1424 - accuracy: 0.9750
# Epoch 75: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1367 - accuracy: 0.9688 - val_loss: 0.0385 - val_accuracy: 1.0000
# Epoch 76/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1247 - accuracy: 0.9750
# Epoch 76: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1184 - accuracy: 0.9583 - val_loss: 0.0403 - val_accuracy: 1.0000
# Epoch 77/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1333 - accuracy: 0.9250
# Epoch 77: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1149 - accuracy: 0.9375 - val_loss: 0.0232 - val_accuracy: 1.0000
# Epoch 78/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1461 - accuracy: 0.9500
# Epoch 78: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1466 - accuracy: 0.9479 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 79/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0732 - accuracy: 0.9750
# Epoch 79: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0992 - accuracy: 0.9792 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 80/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2058 - accuracy: 0.9500
# Epoch 80: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1654 - accuracy: 0.9479 - val_loss: 0.0189 - val_accuracy: 1.0000
# Epoch 81/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1192 - accuracy: 0.9500
# Epoch 81: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1345 - accuracy: 0.9375 - val_loss: 0.0377 - val_accuracy: 1.0000
# Epoch 82/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0788 - accuracy: 0.9750
# Epoch 82: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1047 - accuracy: 0.9583 - val_loss: 0.0386 - val_accuracy: 1.0000
# Epoch 83/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0885 - accuracy: 0.9750
# Epoch 83: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0829 - accuracy: 0.9792 - val_loss: 0.0197 - val_accuracy: 1.0000
# Epoch 84/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0485 - accuracy: 1.0000
# Epoch 84: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1039 - accuracy: 0.9688 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 85/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0669 - accuracy: 1.0000
# Epoch 85: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1134 - accuracy: 0.9583 - val_loss: 0.0236 - val_accuracy: 1.0000
# Epoch 86/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2000 - accuracy: 0.9250
# Epoch 86: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1443 - accuracy: 0.9375 - val_loss: 0.0368 - val_accuracy: 1.0000
# Epoch 87/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0742 - accuracy: 0.9750
# Epoch 87: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0794 - accuracy: 0.9792 - val_loss: 0.0306 - val_accuracy: 1.0000
# Epoch 88/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1416 - accuracy: 0.9250
# Epoch 88: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0935 - accuracy: 0.9479 - val_loss: 0.0241 - val_accuracy: 1.0000
# Epoch 89/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1788 - accuracy: 0.9250
# Epoch 89: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1520 - accuracy: 0.9375 - val_loss: 0.0246 - val_accuracy: 1.0000
# Epoch 90/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0675 - accuracy: 1.0000
# Epoch 90: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0853 - accuracy: 0.9792 - val_loss: 0.0203 - val_accuracy: 1.0000
# Epoch 91/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0479 - accuracy: 1.0000
# Epoch 91: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1022 - accuracy: 0.9688 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 92/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1343 - accuracy: 0.9750
# Epoch 92: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0916 - accuracy: 0.9792 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 93/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1360 - accuracy: 0.9750
# Epoch 93: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1090 - accuracy: 0.9792 - val_loss: 0.0270 - val_accuracy: 1.0000
# Epoch 94/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1614 - accuracy: 0.9250
# Epoch 94: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0812 - accuracy: 0.9688 - val_loss: 0.0608 - val_accuracy: 0.9583
# Epoch 95/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1017 - accuracy: 0.9500
# Epoch 95: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1495 - accuracy: 0.9271 - val_loss: 0.0339 - val_accuracy: 1.0000
# Epoch 96/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1310 - accuracy: 0.9250
# Epoch 96: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1357 - accuracy: 0.9479 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 97/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1726 - accuracy: 0.9250
# Epoch 97: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1204 - accuracy: 0.9583 - val_loss: 0.0107 - val_accuracy: 1.0000
# Epoch 98/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1280 - accuracy: 0.9500
# Epoch 98: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1325 - accuracy: 0.9479 - val_loss: 0.0198 - val_accuracy: 1.0000
# Epoch 99/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0649 - accuracy: 1.0000
# Epoch 99: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1110 - accuracy: 0.9792 - val_loss: 0.0289 - val_accuracy: 1.0000
# Epoch 100/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0689 - accuracy: 0.9750
# Epoch 100: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0719 - accuracy: 0.9792 - val_loss: 0.0260 - val_accuracy: 1.0000
# Epoch 101/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0775 - accuracy: 0.9750
# Epoch 101: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0857 - accuracy: 0.9792 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 102/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0885 - accuracy: 0.9500
# Epoch 102: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1155 - accuracy: 0.9375 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 103/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0258 - accuracy: 1.0000
# Epoch 103: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0753 - accuracy: 0.9792 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 104/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0480 - accuracy: 0.9750
# Epoch 104: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1756 - accuracy: 0.9375 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 105/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1213 - accuracy: 0.9500
# Epoch 105: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1141 - accuracy: 0.9688 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 106/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1320 - accuracy: 0.9500
# Epoch 106: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0960 - accuracy: 0.9688 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 107/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1891 - accuracy: 0.9750
# Epoch 107: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1109 - accuracy: 0.9792 - val_loss: 0.0265 - val_accuracy: 1.0000
# Epoch 108/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1926 - accuracy: 0.9250
# Epoch 108: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1149 - accuracy: 0.9583 - val_loss: 0.0371 - val_accuracy: 1.0000
# Epoch 109/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0293 - accuracy: 1.0000
# Epoch 109: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1131 - accuracy: 0.9583 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 110/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0823 - accuracy: 0.9750
# Epoch 110: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0654 - accuracy: 0.9792 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 111/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1360 - accuracy: 0.9750
# Epoch 111: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0850 - accuracy: 0.9896 - val_loss: 0.0141 - val_accuracy: 1.0000
# Epoch 112/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0892 - accuracy: 0.9750
# Epoch 112: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0628 - accuracy: 0.9896 - val_loss: 0.0157 - val_accuracy: 1.0000
# Epoch 113/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1425 - accuracy: 0.9500
# Epoch 113: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1045 - accuracy: 0.9583 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 114/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0405 - accuracy: 1.0000
# Epoch 114: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0926 - accuracy: 0.9688 - val_loss: 0.0140 - val_accuracy: 1.0000
# Epoch 115/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0696 - accuracy: 0.9500
# Epoch 115: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0814 - accuracy: 0.9688 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 116/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0756 - accuracy: 0.9500
# Epoch 116: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1013 - accuracy: 0.9583 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 117/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2026 - accuracy: 0.9250
# Epoch 117: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1023 - accuracy: 0.9688 - val_loss: 0.0160 - val_accuracy: 1.0000
# Epoch 118/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0280 - accuracy: 1.0000
# Epoch 118: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0402 - accuracy: 0.9896 - val_loss: 0.0294 - val_accuracy: 1.0000
# Epoch 119/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1448 - accuracy: 0.9500
# Epoch 119: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0869 - accuracy: 0.9688 - val_loss: 0.0258 - val_accuracy: 1.0000
# Epoch 120/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0725 - accuracy: 0.9750
# Epoch 120: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1055 - accuracy: 0.9583 - val_loss: 0.0303 - val_accuracy: 1.0000
# Epoch 121/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0555 - accuracy: 1.0000
# Epoch 121: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1119 - accuracy: 0.9583 - val_loss: 0.0123 - val_accuracy: 1.0000
# Epoch 122/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0329 - accuracy: 1.0000
# Epoch 122: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0808 - accuracy: 0.9688 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 123/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0525 - accuracy: 1.0000
# Epoch 123: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0907 - accuracy: 0.9792 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 124/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0794 - accuracy: 0.9750
# Epoch 124: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1136 - accuracy: 0.9792 - val_loss: 0.0256 - val_accuracy: 1.0000
# Epoch 125/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1198 - accuracy: 0.9750
# Epoch 125: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0815 - accuracy: 0.9792 - val_loss: 0.0257 - val_accuracy: 1.0000
# Epoch 126/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1370 - accuracy: 0.9250
# Epoch 126: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0854 - accuracy: 0.9688 - val_loss: 0.0102 - val_accuracy: 1.0000
# Epoch 127/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2067 - accuracy: 0.9250
# Epoch 127: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1085 - accuracy: 0.9688 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 128/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0882 - accuracy: 0.9500
# Epoch 128: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0974 - accuracy: 0.9583 - val_loss: 0.0190 - val_accuracy: 1.0000
# Epoch 129/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1884 - accuracy: 0.9250
# Epoch 129: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1294 - accuracy: 0.9375 - val_loss: 0.0414 - val_accuracy: 0.9583
# Epoch 130/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0302 - accuracy: 1.0000
# Epoch 130: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0839 - accuracy: 0.9792 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 131/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0934 - accuracy: 0.9750
# Epoch 131: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0698 - accuracy: 0.9792 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 132/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0562 - accuracy: 0.9750
# Epoch 132: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0780 - accuracy: 0.9792 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 133/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0440 - accuracy: 1.0000
# Epoch 133: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0834 - accuracy: 0.9792 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 134/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1872 - accuracy: 0.9500
# Epoch 134: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1053 - accuracy: 0.9792 - val_loss: 0.0462 - val_accuracy: 0.9583
# Epoch 135/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1377 - accuracy: 0.9500
# Epoch 135: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0924 - accuracy: 0.9583 - val_loss: 0.0173 - val_accuracy: 1.0000
# Epoch 136/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0440 - accuracy: 0.9750
# Epoch 136: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0727 - accuracy: 0.9688 - val_loss: 0.0147 - val_accuracy: 1.0000
# Epoch 137/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0229 - accuracy: 1.0000
# Epoch 137: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0781 - accuracy: 0.9792 - val_loss: 0.0184 - val_accuracy: 1.0000
# Epoch 138/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0740 - accuracy: 0.9750
# Epoch 138: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0767 - accuracy: 0.9688 - val_loss: 0.0321 - val_accuracy: 1.0000
# Epoch 139/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1068 - accuracy: 0.9750
# Epoch 139: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0608 - accuracy: 0.9896 - val_loss: 0.0145 - val_accuracy: 1.0000
# Epoch 140/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0409 - accuracy: 1.0000
# Epoch 140: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0731 - accuracy: 0.9792 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 141/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1450 - accuracy: 0.9500
# Epoch 141: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0849 - accuracy: 0.9688 - val_loss: 0.0171 - val_accuracy: 1.0000
# Epoch 142/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0526 - accuracy: 0.9750
# Epoch 142: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0848 - accuracy: 0.9792 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 143/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0596 - accuracy: 1.0000
# Epoch 143: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0991 - accuracy: 0.9583 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 144/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0402 - accuracy: 0.9750
# Epoch 144: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0729 - accuracy: 0.9792 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 145/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1775 - accuracy: 0.9500
# Epoch 145: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0872 - accuracy: 0.9792 - val_loss: 0.0300 - val_accuracy: 1.0000
# Epoch 146/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0296 - accuracy: 1.0000
# Epoch 146: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0888 - accuracy: 0.9688 - val_loss: 0.0229 - val_accuracy: 1.0000
# Epoch 147/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0276 - accuracy: 1.0000
# Epoch 147: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0624 - accuracy: 0.9896 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 148/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0412 - accuracy: 1.0000
# Epoch 148: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0736 - accuracy: 0.9896 - val_loss: 0.0130 - val_accuracy: 1.0000
# Epoch 149/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1254 - accuracy: 0.9750
# Epoch 149: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0701 - accuracy: 0.9896 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 150/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0495 - accuracy: 1.0000
# Epoch 150: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0725 - accuracy: 0.9896 - val_loss: 0.0262 - val_accuracy: 1.0000
# Epoch 151/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0901 - accuracy: 0.9750
# Epoch 151: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0653 - accuracy: 0.9792 - val_loss: 0.0232 - val_accuracy: 1.0000
# Epoch 152/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0257 - accuracy: 1.0000
# Epoch 152: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0601 - accuracy: 0.9896 - val_loss: 0.0243 - val_accuracy: 1.0000
# Epoch 153/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2138 - accuracy: 0.9250
# Epoch 153: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1005 - accuracy: 0.9688 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 154/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1425 - accuracy: 0.9500
# Epoch 154: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0842 - accuracy: 0.9792 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 155/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0774 - accuracy: 0.9500
# Epoch 155: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1112 - accuracy: 0.9583 - val_loss: 0.0119 - val_accuracy: 1.0000
# Epoch 156/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0297 - accuracy: 1.0000
# Epoch 156: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0616 - accuracy: 0.9896 - val_loss: 0.0439 - val_accuracy: 0.9583
# Epoch 157/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0287 - accuracy: 1.0000
# Epoch 157: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1044 - accuracy: 0.9479 - val_loss: 0.0267 - val_accuracy: 1.0000
# Epoch 158/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1060 - accuracy: 0.9750
# Epoch 158: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0632 - accuracy: 0.9792 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 159/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1305 - accuracy: 0.9250
# Epoch 159: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1346 - accuracy: 0.9375 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 160/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1749 - accuracy: 0.9500
# Epoch 160: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0967 - accuracy: 0.9792 - val_loss: 0.0259 - val_accuracy: 1.0000
# Epoch 161/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0470 - accuracy: 1.0000
# Epoch 161: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1160 - accuracy: 0.9479 - val_loss: 0.0481 - val_accuracy: 0.9583
# Epoch 162/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1256 - accuracy: 0.9500
# Epoch 162: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0943 - accuracy: 0.9583 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 163/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0307 - accuracy: 1.0000
# Epoch 163: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0963 - accuracy: 0.9896 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 164/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0567 - accuracy: 1.0000
# Epoch 164: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0879 - accuracy: 0.9896 - val_loss: 0.0145 - val_accuracy: 1.0000
# Epoch 165/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0551 - accuracy: 0.9500
# Epoch 165: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0698 - accuracy: 0.9688 - val_loss: 0.0312 - val_accuracy: 1.0000
# Epoch 166/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1118 - accuracy: 0.9750
# Epoch 166: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0913 - accuracy: 0.9792 - val_loss: 0.0192 - val_accuracy: 1.0000
# Epoch 167/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0662 - accuracy: 0.9750
# Epoch 167: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0592 - accuracy: 0.9792 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 168/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0205 - accuracy: 1.0000
# Epoch 168: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0803 - accuracy: 0.9896 - val_loss: 0.0185 - val_accuracy: 1.0000
# Epoch 169/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0540 - accuracy: 0.9750
# Epoch 169: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0745 - accuracy: 0.9792 - val_loss: 0.0237 - val_accuracy: 1.0000
# Epoch 170/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0805 - accuracy: 0.9750
# Epoch 170: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0468 - accuracy: 0.9896 - val_loss: 0.0271 - val_accuracy: 1.0000
# Epoch 171/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0424 - accuracy: 1.0000
# Epoch 171: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0869 - accuracy: 0.9792 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 172/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0578 - accuracy: 0.9750
# Epoch 172: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0458 - accuracy: 0.9792 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 173/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0273 - accuracy: 1.0000
# Epoch 173: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0695 - accuracy: 0.9792 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 174/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0330 - accuracy: 0.9750
# Epoch 174: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0458 - accuracy: 0.9792 - val_loss: 0.0196 - val_accuracy: 1.0000
# Epoch 175/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1038 - accuracy: 0.9750
# Epoch 175: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0579 - accuracy: 0.9896 - val_loss: 0.0295 - val_accuracy: 1.0000
# Epoch 176/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0739 - accuracy: 0.9750
# Epoch 176: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0578 - accuracy: 0.9896 - val_loss: 0.0203 - val_accuracy: 1.0000
# Epoch 177/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0530 - accuracy: 0.9750
# Epoch 177: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0552 - accuracy: 0.9792 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 178/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0363 - accuracy: 1.0000
# Epoch 178: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0969 - accuracy: 0.9792 - val_loss: 0.0157 - val_accuracy: 1.0000
# Epoch 179/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0761 - accuracy: 0.9750
# Epoch 179: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1214 - accuracy: 0.9688 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 180/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1307 - accuracy: 0.9500
# Epoch 180: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0676 - accuracy: 0.9792 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 181/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0342 - accuracy: 1.0000
# Epoch 181: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0581 - accuracy: 0.9792 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 182/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1198 - accuracy: 0.9750
# Epoch 182: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0839 - accuracy: 0.9688 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 183/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0167 - accuracy: 1.0000
# Epoch 183: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0513 - accuracy: 0.9896 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 184/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0275 - accuracy: 1.0000
# Epoch 184: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0907 - accuracy: 0.9896 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 185/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0492 - accuracy: 0.9750
# Epoch 185: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0684 - accuracy: 0.9688 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 186/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0154 - accuracy: 1.0000
# Epoch 186: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0729 - accuracy: 0.9896 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 187/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0174 - accuracy: 1.0000
# Epoch 187: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0798 - accuracy: 0.9792 - val_loss: 0.0170 - val_accuracy: 1.0000
# Epoch 188/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0169 - accuracy: 1.0000
# Epoch 188: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0421 - accuracy: 0.9792 - val_loss: 0.0282 - val_accuracy: 1.0000
# Epoch 189/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0907 - accuracy: 0.9500
# Epoch 189: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0861 - accuracy: 0.9583 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 190/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0587 - accuracy: 0.9750
# Epoch 190: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0758 - accuracy: 0.9792 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 191/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0877 - accuracy: 0.9750
# Epoch 191: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0521 - accuracy: 0.9896 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 192/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1662 - accuracy: 0.9750
# Epoch 192: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0836 - accuracy: 0.9792 - val_loss: 0.0120 - val_accuracy: 1.0000
# Epoch 193/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0261 - accuracy: 1.0000
# Epoch 193: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0365 - accuracy: 0.9896 - val_loss: 0.0230 - val_accuracy: 1.0000
# Epoch 194/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1562 - accuracy: 0.9750
# Epoch 194: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1118 - accuracy: 0.9583 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 195/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1146 - accuracy: 0.9750
# Epoch 195: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0823 - accuracy: 0.9792 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 196/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0216 - accuracy: 1.0000
# Epoch 196: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1163 - accuracy: 0.9688 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 197/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0336 - accuracy: 1.0000
# Epoch 197: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0682 - accuracy: 0.9792 - val_loss: 0.0515 - val_accuracy: 0.9583
# Epoch 198/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 198: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1758 - accuracy: 0.9271 - val_loss: 0.0534 - val_accuracy: 0.9583
# Epoch 199/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0576 - accuracy: 0.9750
# Epoch 199: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0840 - accuracy: 0.9792 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 200/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1264 - accuracy: 0.9750
# Epoch 200: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1874 - accuracy: 0.9167 - val_loss: 0.0135 - val_accuracy: 1.0000

# %% [markdown]
# # 5. 모델 평가
# (시각화, 현재모델과 저장된 최고의 모델 평가, 교차표==혼동행렬)

# %%
# 학습과정 표시하기
import matplotlib.pyplot as plt
fig, loss_ax = plt.subplots(figsize=(10,6))
loss_ax.plot(hist.history['loss'], 'y', label='train_loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val_loss')
acc_ax = loss_ax.twinx() # loss_ax와 x축을 공유하는 acc_ax 생성
acc_ax.plot(hist.history['accuracy'], 'g', label='train_accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'b', label='val_accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')
loss_ax.legend(bbox_to_anchor=(0.955, 0.7))
acc_ax.legend(loc='center right')
plt.show()

# %%
# 모델 평가
loss_and_acc =model.evaluate(X_test, Y_test, verbose=0)
print(f'loss:{loss_and_acc[0]:.4f}, accuracy:{loss_and_acc[1]:.4f}')
# Out:
# loss:0.2554, accuracy:0.9333

# %%
model1 = load_model('model/iris-007-loss0.7205-acc1.0000.h5')
loss_and_acc1 =model1.evaluate(X_test, Y_test, verbose=0)
print(f'loss:{loss_and_acc1[0]:.4f}, accuracy:{loss_and_acc1[1]:.4f}')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 model1 = load_model('model/iris-007-loss0.7205-acc1.0000.h5')
#       2 loss_and_acc1 =model1.evaluate(X_test, Y_test, verbose=0)
#       3 print(f'loss:{loss_and_acc1[0]:.4f}, accuracy:{loss_and_acc1[1]:.4f}')
#
# File ~\anaconda3\envs\ml-dl-nlp\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\ml-dl-nlp\lib\site-packages\keras\saving\save.py:226, in load_model(filepath, custom_objects, compile, options)
#     224 if isinstance(filepath_str, str):
#     225     if not tf.io.gfile.exists(filepath_str):
# --> 226         raise IOError(
#     227             f"No file or directory found at {filepath_str}"
#     228         )
#     230     if tf.io.gfile.isdir(filepath_str):
#     231         return saved_model_load.load(
#     232             filepath_str, compile, options
#     233         )
#
# OSError: No file or directory found at model/iris-007-loss0.7205-acc1.0000.h5

# %%
model2 = load_model('model/iris-005-loss0.7852-acc1.0000.h5')
loss_and_acc2 =model2.evaluate(X_test, Y_test, verbose=0)
print(f'loss:{loss_and_acc2[0]:.4f}, accuracy:{loss_and_acc2[1]:.4f}')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 model2 = load_model('model/iris-005-loss0.7852-acc1.0000.h5')
#       2 loss_and_acc2 =model2.evaluate(X_test, Y_test, verbose=0)
#       3 print(f'loss:{loss_and_acc2[0]:.4f}, accuracy:{loss_and_acc2[1]:.4f}')
#
# File ~\anaconda3\envs\ml-dl-nlp\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\ml-dl-nlp\lib\site-packages\keras\saving\save.py:226, in load_model(filepath, custom_objects, compile, options)
#     224 if isinstance(filepath_str, str):
#     225     if not tf.io.gfile.exists(filepath_str):
# --> 226         raise IOError(
#     227             f"No file or directory found at {filepath_str}"
#     228         )
#     230     if tf.io.gfile.isdir(filepath_str):
#     231         return saved_model_load.load(
#     232             filepath_str, compile, options
#     233         )
#
# OSError: No file or directory found at model/iris-005-loss0.7852-acc1.0000.h5
