# %% [markdown]
# # RAGAS Evaluation Notebook (Clean)
#
# This notebook evaluates **baseline vs experiment** RAG pipelines using RAGAS and saves **summary/detail** outputs per run.

# %%
# %pip install datasets

# %%
# %pip install ragas

# %%
# import sys, subprocess, textwrap

# def sh(cmd):
#     print(">", cmd)
#     r = subprocess.run(cmd, shell=True, capture_output=True, text=True)
#     print(r.stdout)
#     if r.stderr.strip():
#         print("[stderr]")
#         print(r.stderr)

# print("python:", sys.executable)
# print("version:", sys.version)

# # 현재 패키지 상태 확인
# sh("python -c \"import numpy; print('numpy', numpy.__version__)\"")
# sh("python -c \"import pyarrow; print('pyarrow', pyarrow.__version__)\"")
# sh("python -c \"import datasets; print('datasets', datasets.__version__)\"")

# %%
# import sys, subprocess

# def pip(cmd):
#     print(">", cmd)
#     r = subprocess.run([sys.executable, "-m", "pip"] + cmd.split(), capture_output=True, text=True)
#     print(r.stdout)
#     if r.stderr.strip():
#         print("[stderr]")
#         print(r.stderr)

# # 1) 제거
# pip("uninstall -y pyarrow datasets numpy")

# # 2) 재설치: numpy<2 + 최신 pyarrow + datasets(너가 쓰던 버전)
# pip("install numpy<2 pyarrow>=14 datasets==2.19.2")

# %%
# ---- RAGAS metrics: version-tolerant loader ----
def build_metrics():
    # A안: embeddings 의존 가능성이 큰 AnswerRelevancy는 빼고 "완주"부터
    # 1) 함수형 metric
    try:
        from ragas.metrics import context_precision, context_recall, faithfulness
        return [context_precision, context_recall, faithfulness]
    except Exception:
        pass

    # 2) 클래스형 metric
    try:
        from ragas.metrics import ContextPrecision, ContextRecall, Faithfulness
        return [ContextPrecision(), ContextRecall(), Faithfulness()]
    except Exception:
        pass

    # 3) fallback 탐색
    import ragas.metrics as m
    wanted = ["ContextPrecision", "ContextRecall", "Faithfulness"]
    found = []
    for name in wanted:
        if hasattr(m, name):
            found.append(getattr(m, name)())
    if found:
        return found

    raise ImportError(
        "RAGAS metrics import failed for A-plan (without AnswerRelevancy). "
        "Paste `pip show ragas` and `python -c \"import ragas; print(ragas.__version__)\"`."
    )

METRICS = build_metrics()
print("✅ METRICS:", [getattr(x, '__name__', x.__class__.__name__) for x in METRICS])
# Out:
# ✅ METRICS: ['ContextPrecision', 'ContextRecall', 'Faithfulness']
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9156\1708373533.py:6: DeprecationWarning: Importing context_precision from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_precision
#   from ragas.metrics import context_precision, context_recall, faithfulness
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9156\1708373533.py:6: DeprecationWarning: Importing context_recall from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_recall
#   from ragas.metrics import context_precision, context_recall, faithfulness
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9156\1708373533.py:6: DeprecationWarning: Importing faithfulness from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import faithfulness
#   from ragas.metrics import context_precision, context_recall, faithfulness

# %%
import ragas
print("ragas version:", getattr(ragas, "__version__", "unknown"))
# Out:
# ragas version: 0.4.3

# %%
from ragas.metrics import context_precision, context_recall, faithfulness, answer_relevancy

METRICS = [context_precision, context_recall, faithfulness, answer_relevancy]
print("✅ METRICS:", [getattr(m, "__name__", m.__class__.__name__) for m in METRICS])
# Out:
# ✅ METRICS: ['ContextPrecision', 'ContextRecall', 'Faithfulness', 'AnswerRelevancy']
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9156\3044559028.py:1: DeprecationWarning: Importing context_precision from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_precision
#   from ragas.metrics import context_precision, context_recall, faithfulness, answer_relevancy
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9156\3044559028.py:1: DeprecationWarning: Importing context_recall from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_recall
#   from ragas.metrics import context_precision, context_recall, faithfulness, answer_relevancy
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9156\3044559028.py:1: DeprecationWarning: Importing faithfulness from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import faithfulness
#   from ragas.metrics import context_precision, context_recall, faithfulness, answer_relevancy
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9156\3044559028.py:1: DeprecationWarning: Importing answer_relevancy from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import answer_relevancy
#   from ragas.metrics import context_precision, context_recall, faithfulness, answer_relevancy

# %% [markdown]
# ## 0) Environment & Paths

# %%
# ============================================================
# PATH CONFIG (only this cell is modified)
# ============================================================
import json
import pandas as pd
import sys, importlib
from pathlib import Path
from dotenv import load_dotenv

# ✅ 프로젝트 루트 (새 경로)
PROJECT_ROOT = Path(r"C:\ai\source\chatbot_app")

# ✅ 모듈 경로 (원래 쓰던 구조 그대로)
MODULE_DIR = PROJECT_ROOT / "modules"

# ✅ 환경변수
ENV_PATH = PROJECT_ROOT / ".env"

# ✅ 결과 저장 루트
RUNS_DIR = PROJECT_ROOT / "results" / "ragas_runs"

# ⭕️ 여기서 어떤 테스트셋 쓸지 네가 직접 선택
# TESTSET_PATH = PROJECT_ROOT / "ragas_testset_single.jsonl"
# TESTSET_PATH = PROJECT_ROOT / "ragas_testset_v1_from_docx.jsonl"
TESTSET_PATH = PROJECT_ROOT / "ragas_testset_10_selected.jsonl"

# ------------------------------------------------------------
# setup
# ------------------------------------------------------------
sys.path.insert(0, str(PROJECT_ROOT))
sys.path.insert(0, str(MODULE_DIR))
importlib.invalidate_caches()

if ENV_PATH.exists():
    load_dotenv(ENV_PATH)

RUNS_DIR.mkdir(parents=True, exist_ok=True)

print("PROJECT_ROOT:", PROJECT_ROOT)
print("TESTSET_PATH:", TESTSET_PATH)
print("exists:", TESTSET_PATH.exists())
# Out:
# PROJECT_ROOT: C:\ai\source\chatbot_app
# TESTSET_PATH: C:\ai\source\chatbot_app\ragas_testset_10_selected.jsonl
# exists: True

# %% [markdown]
# ## 1) Load testset (JSONL)

# %%
TESTSET_JSONL = PROJECT_ROOT / "ragas_testset_10_selected.jsonl"  # change if needed
assert TESTSET_JSONL.exists(), f"❌ JSONL not found: {TESTSET_JSONL}"

rows = []
with open(TESTSET_JSONL, "r", encoding="utf-8") as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        rows.append(json.loads(line))

print("✅ rows:", len(rows))
print("✅ keys example:", rows[0].keys())
pd.DataFrame(rows[:3])
# Out:
# ✅ rows: 10
# ✅ keys example: dict_keys(['question_id', 'question', 'ground_truth', 'contexts', 'meta'])
#   question_id                                           question  \
# 0        q010               조정에서 합의했는데 집주인이 안 지켜요. 이거 강제할 수 있나요?
# 1        q016  임대인이 보증금을 안 돌려줘서 제가 일부러 전입신고를 유지하고 있는데, 다른 집으로...
# 2        q002              계약서에 1년이라고 써 있으면, 1년 지나면 무조건 나가야 하나요?
#
#                                         ground_truth  \
# 0  네, 강제할 수 있습니다.\n주택임대차보호법 제27조에 따르면,\n 제26조제4항 ...
# 1  다른 집으로 전입신고를 하면,\n 기존 주택에 대한 대항력을 상실하게 되어 임차인으...
# 2  아니요. 계약서에 1년이라고 적혀 있어도, 1년이 지나면 무조건 나가야 하는 것은 ...
#
#                                             contexts  \
# 0  [주택임대차보호법 제27조 제1항, 주택임대차보호법 시행령 제34조, 주택임대차보호...
# 1                                 [주택임대차보호법 제3조 제1항]
# 2                                 [주택임대차보호법 제4조 제1항]
#
#                                                 meta
# 0  {'source': 'RAGAS 학습용 질문.docx', 'version': 'v1...
# 1  {'source': 'RAGAS 학습용 질문.docx', 'version': 'v1...
# 2  {'source': 'RAGAS 학습용 질문.docx', 'version': 'v1...

# %% [markdown]
# ## 2) Define baseline & experiment configs
#
# - Keep **base_cfg** stable.
# - Only put **changed knobs** in `exp_cfg = replace(base_cfg, ...)`.

# %%
from dataclasses import replace
from rag_module import RAGConfig

# =========================
# Base config (edit as needed)
# =========================
base_cfg = RAGConfig(
    # ---- LLM ----
    normalize_model="solar-pro2",
    generation_model="gpt-4o-mini",
    temperature=0.1,
    normalize_temperature=0.0,

    # ---- Embedding ----
    embedding_backend="upstage",
    embedding_model="solar-embedding-1-large-passage",

    # ---- Dense Retrieval ----
    k_law=5,
    k_rule=5,
    k_case=3,
    search_multiplier=2,

    # ---- BM25 / Sparse ----
    enable_bm25=True,

    # ---- Rerank ----
    enable_rerank=True,
    rerank_threshold=0.2,
    rerank_max_documents=20,

    # ---- Output trimming ----
    bm25_max_doc_chars=2400,
    rerank_doc_max_chars=2400,
)

# =========================
# Experiment config (only diffs here)
# =========================
exp_cfg = replace(base_cfg,
    rerank_threshold=0.24,
    rerank_max_documents=20,
)
base_cfg, exp_cfg
# Out:
# (RAGConfig(normalize_model='solar-pro2', generation_model='gpt-4o-mini', temperature=0.1, normalize_temperature=0.0, embedding_backend='upstage', embedding_model='solar-embedding-1-large-passage', k_law=5, k_rule=5, k_case=3, search_multiplier=2, enable_bm25=True, sparse_mode='auto', sparse_k_law=None, sparse_k_rule=None, sparse_k_case=None, bm25_algorithm='okapi', bm25_k1=1.5, bm25_b=0.75, bm25_use_kiwi=True, bm25_max_doc_chars=2400, enable_bm25_title=True, bm25_title_field='title', bm25_title_max_chars=512, hybrid_sparse_title_ratio=0.35, hybrid_fusion='rrf', hybrid_dense_weight=0.6, hybrid_sparse_weight=0.4, rrf_k=60, enable_rerank=True, rerank_threshold=0.2, rerank_model='rerank-multilingual-v3.0', rerank_max_documents=20, rerank_doc_max_chars=2400, case_candidate_k=40, case_expand_top_n=None, case_context_top_k=50, dedupe_key_fields=('chunk_id', 'id')),
#  RAGConfig(normalize_model='solar-pro2', generation_model='gpt-4o-mini', temperature=0.1, normalize_temperature=0.0, embedding_backend='upstage', embedding_model='solar-embedding-1-large-passage', k_law=5, k_rule=5, k_case=3, search_multiplier=2, enable_bm25=True, sparse_mode='auto', sparse_k_law=None, sparse_k_rule=None, sparse_k_case=None, bm25_algorithm='okapi', bm25_k1=1.5, bm25_b=0.75, bm25_use_kiwi=True, bm25_max_doc_chars=2400, enable_bm25_title=True, bm25_title_field='title', bm25_title_max_chars=512, hybrid_sparse_title_ratio=0.35, hybrid_fusion='rrf', hybrid_dense_weight=0.6, hybrid_sparse_weight=0.4, rrf_k=60, enable_rerank=True, rerank_threshold=0.24, rerank_model='rerank-multilingual-v3.0', rerank_max_documents=20, rerank_doc_max_chars=2400, case_candidate_k=40, case_expand_top_n=None, case_context_top_k=50, dedupe_key_fields=('chunk_id', 'id')))

# %% [markdown]
# ## 3) Build pipelines

# %%
from rag_module import create_pipeline

base_pipe = create_pipeline(config=base_cfg)
exp_pipe  = create_pipeline(config=exp_cfg)

print("✅ pipelines ready")
# Out:
# 2026-02-02 17:15:26,428 - rag_module - INFO - 🔗 Pinecone 3중 인덱스 연결 중...
# 2026-02-02 17:15:26,430 - rag_module - INFO - ✅ [Law / Rule / Case] 3개 인덱스 로드 완료!
# 2026-02-02 17:15:26,850 - rag_module - INFO - ✅ Kiwi 토크나이저 사용 (BM25)
# 2026-02-02 17:15:28,238 - rag_module - INFO - 🔗 Pinecone 3중 인덱스 연결 중...
# 2026-02-02 17:15:28,240 - rag_module - INFO - ✅ [Law / Rule / Case] 3개 인덱스 로드 완료!
# 2026-02-02 17:15:28,610 - rag_module - INFO - ✅ Kiwi 토크나이저 사용 (BM25)
# ✅ pipelines ready

# %% [markdown]
# ## 4) (Optional) Quick trace sanity check

# %%
# If your rag_module exposes a trace / debug method, call it here.
# Otherwise you can skip this cell.

# Example (adjust to your actual API):
# ans, trace = base_pipe.answer_with_trace("테스트 질문 ...")
# display(trace)

print("ℹ️ Skip or customize depending on your pipeline API.")
# Out:
# ℹ️ Skip or customize depending on your pipeline API.

# %% [markdown]
# ## 5) Build RAGAS samples from your pipeline outputs
#
# This converts each testset row into the RAGAS format:
# - `question`
# - `answer`
# - `contexts` (list[str])
# - `ground_truth`

# %%
def shrink_contexts(ctxs, max_chars=2400, max_contexts=30):
    out = []
    for c in (ctxs or []):
        if c is None:
            continue
        s = str(c).strip()
        if not s:
            continue
        out.append(s[:max_chars])
        if len(out) >= max_contexts:
            break
    return out

def row_get_ground_truth(r: dict):
    return r.get("ground_truth") or r.get("reference") or r.get("gt") or r.get("answer")

def run_pipe_to_samples(pipe, rows, max_chars=2400, max_contexts=30, limit=None):
    samples = []
    n = len(rows) if limit is None else min(limit, len(rows))

    for i in range(n):
        r = rows[i]
        q = r.get("question") or r.get("query")
        if not q:
            continue

        # ✅ 네 파이프라인은 이걸로 호출해야 함
        out = pipe.answer_with_trace(q)

        # out이 dict일 수도 있고, (answer, ctxs, trace) 튜플일 수도 있어서 안전 처리
        ans, ctxs, trace = "", [], None

        if isinstance(out, dict):
            ans = out.get("answer") or out.get("result") or out.get("output") or out.get("text") or ""
            ctxs = out.get("contexts") or out.get("context") or out.get("docs") or []
            trace = out.get("trace") or out.get("debug") or out.get("meta")
        elif isinstance(out, tuple):
            # 흔한 패턴들 대응
            if len(out) == 3:
                ans, ctxs, trace = out
            elif len(out) == 2:
                ans, ctxs = out
            elif len(out) == 1:
                ans = out[0]
        else:
            ans = str(out)

        samples.append({
            "question": q,
            "answer": ans or "",
            "contexts": shrink_contexts(ctxs, max_chars=max_chars, max_contexts=max_contexts),
            "ground_truth": row_get_ground_truth(r) or "",
            "_trace": trace,  # ✅ trace도 같이 보관(원하면 저장 가능)
        })

    return samples

# ✅ 스모크 테스트: 1문제만
BASE_SAMPLES = run_pipe_to_samples(base_pipe, rows, limit=None)
EXP_SAMPLES = run_pipe_to_samples(exp_pipe, rows, limit=None)

print("✅ BASE_SAMPLES:", len(BASE_SAMPLES))
print("✅ EXP_SAMPLES :", len(EXP_SAMPLES))
pd.DataFrame([{k:v for k,v in BASE_SAMPLES[0].items() if k != "_trace"}])
# Out:
# 2026-02-02 17:15:30,758 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:15:30,760 - rag_module - INFO - 🔄 표준화된 질문: 조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
#
# 변경된 질문: 조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
#
# ※ [용어 사전]에 '조정'이 명시되어 있지 않아 원문을 유지하였습니다. 필요 시 추가 매핑 요청 바랍니다.
# 2026-02-02 17:15:30,761 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
#
# 변경된 질문: 조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
#
# ※ [용어 사전]에 '조정'이 명시되어 있지 않아 원문을 유지하였습니다. 필요 시 추가 매핑 요청 바랍니다.'
# 2026-02-02 17:15:31,349 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:15:33,498 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:15:35,541 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:15:40,306 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-02 17:15:40,312 - rag_module - INFO - 📌 Rerank selected=20 (threshold=0.2)
# 2026-02-02 17:15:40,313 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-02 17:15:48,833 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:15:49,617 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:15:49,620 - rag_module - INFO - 🔄 표준화된 질문: 임대인(임대인)이 임대차보증금(보증금)을 보증금미반환(안 돌려줘서)해서 제가 일부러 주민등록(전입신고)을 유지하고 있는데, 다른 임차주택(다른 집)으로 주민등록(전입신고)을 하면 제 임차인 권리는 어떻게 되나요?
# 2026-02-02 17:15:49,621 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='임대인(임대인)이 임대차보증금(보증금)을 보증금미반환(안 돌려줘서)해서 제가 일부러 주민등록(전입신고)을 유지하고 있는데, 다른 임차주택(다른 집)으로 주민등록(전입신고)을 하면 제 임차인 권리는 어떻게 되나요?'
# 2026-02-02 17:15:50,076 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:15:52,129 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:15:52,612 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:15:54,456 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-02 17:15:54,462 - rag_module - INFO - 📌 Rerank selected=20 (threshold=0.2)
# 2026-02-02 17:15:54,464 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-02 17:16:04,035 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:16:04,999 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:16:05,002 - rag_module - INFO - 🔄 표준화된 질문: 계약서에 1년이라고 써 있으면, 1년 지나면 무조건 나가야 하나요? → 임대차계약증서에 1년이라고 기재되면, 1년 경과하면 무조건 주택의인도를 해야 하나요?
#
# 변경된 질문:
# 임대차계약증서(계약서)에 1년이라고 기재되면, 1년 경과하면 무조건 주택의인도(퇴거)를 해야 하나요?
# 2026-02-02 17:16:05,003 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='계약서에 1년이라고 써 있으면, 1년 지나면 무조건 나가야 하나요? → 임대차계약증서에 1년이라고 기재되면, 1년 경과하면 무조건 주택의인도를 해야 하나요?
#
# 변경된 질문:
# 임대차계약증서(계약서)에 1년이라고 기재되면, 1년 경과하면 무조건 주택의인도(퇴거)를 해야 하나요?'
# 2026-02-02 17:16:05,645 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:16:06,338 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:16:06,993 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:16:08,906 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-02 17:16:08,910 - rag_module - INFO - 📌 Rerank selected=20 (threshold=0.2)
# 2026-02-02 17:16:08,911 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-02 17:16:17,101 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:16:17,938 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:16:17,942 - rag_module - INFO - 🔄 표준화된 질문: 임대인(임대인)이 “주민등록(주민등록) 하지 말아달라”고 특약사항(특약사항)을 넣자고 합니다. 이 특약사항(특약사항)을 지키면 정말 문제가 생기나요?
# 2026-02-02 17:16:17,943 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='임대인(임대인)이 “주민등록(주민등록) 하지 말아달라”고 특약사항(특약사항)을 넣자고 합니다. 이 특약사항(특약사항)을 지키면 정말 문제가 생기나요?'
# 2026-02-02 17:16:18,413 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:16:19,122 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:16:19,769 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:16:21,599 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-02 17:16:21,603 - rag_module - INFO - 📌 Rerank selected=11 (threshold=0.2)
# 2026-02-02 17:16:21,604 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-02 17:16:28,514 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:16:29,121 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:16:29,124 - rag_module - INFO - 🔄 표준화된 질문: 경기도에 사는데 임차주택이 경매절차로 넘어가면, 임대차보증금 일부라도 우선변제권으로 받을 수 있나요?
# 2026-02-02 17:16:29,125 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='경기도에 사는데 임차주택이 경매절차로 넘어가면, 임대차보증금 일부라도 우선변제권으로 받을 수 있나요?'
# 2026-02-02 17:16:29,714 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:16:30,614 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:16:31,549 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:16:33,354 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-02 17:16:33,357 - rag_module - INFO - 📌 Rerank selected=7 (threshold=0.2)
# 2026-02-02 17:16:33,359 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-02 17:16:43,701 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:16:44,358 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:16:44,362 - rag_module - INFO - 🔄 표준화된 질문: 계약기간 중 임대인(임대인)이 바뀌었고, 새 임대인(임대인)이 나가라고 해요. 저는 누구에게 임대차보증금(임대차보증금)을 청구해야 하나요?
# 2026-02-02 17:16:44,363 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='계약기간 중 임대인(임대인)이 바뀌었고, 새 임대인(임대인)이 나가라고 해요. 저는 누구에게 임대차보증금(임대차보증금)을 청구해야 하나요?'
# 2026-02-02 17:16:45,369 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:16:46,234 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:16:46,879 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:16:48,853 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-02 17:16:48,860 - rag_module - INFO - 📌 Rerank selected=3 (threshold=0.2)
# 2026-02-02 17:16:48,861 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-02 17:16:57,896 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:16:58,499 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:16:58,502 - rag_module - INFO - 🔄 표준화된 질문: 묵시적갱신(묵시적갱신)으로 연장된 줄 모르고 살았는데, 주택의인도(주택의인도) 가려면 언제까지 살아야 하나요?
# 2026-02-02 17:16:58,503 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='묵시적갱신(묵시적갱신)으로 연장된 줄 모르고 살았는데, 주택의인도(주택의인도) 가려면 언제까지 살아야 하나요?'
# 2026-02-02 17:16:59,199 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:17:00,010 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:17:01,183 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:17:03,102 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-02 17:17:03,110 - rag_module - INFO - 📌 Rerank selected=13 (threshold=0.2)
# 2026-02-02 17:17:03,111 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-02 17:17:14,037 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:17:15,015 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:17:15,018 - rag_module - INFO - 🔄 표준화된 질문: 신축 임차주택인데 임대차보증금이 너무 높아서 불안합니다. 실거래가보다 훨씬 비싼 임대차보증금 계약도 법적으로 문제될 수 있나요?
#
# 변경된 질문:
# 신축 임차주택(임차주택)인데 임대차보증금(임대차보증금)이 너무 높아서 불안합니다. 실거래가보다 훨씬 비싼 임대차보증금(임대차보증금) 계약도 법적으로 문제될 수 있나요?
# 2026-02-02 17:17:15,020 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='신축 임차주택인데 임대차보증금이 너무 높아서 불안합니다. 실거래가보다 훨씬 비싼 임대차보증금 계약도 법적으로 문제될 수 있나요?
#
# 변경된 질문:
# 신축 임차주택(임차주택)인데 임대차보증금(임대차보증금)이 너무 높아서 불안합니다. 실거래가보다 훨씬 비싼 임대차보증금(임대차보증금) 계약도 법적으로 문제될 수 있나요?'
# 2026-02-02 17:17:15,480 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:17:16,306 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:17:17,706 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:17:19,610 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-02 17:17:19,616 - rag_module - INFO - 📌 Rerank selected=20 (threshold=0.2)
# 2026-02-02 17:17:19,617 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-02 17:17:33,058 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:17:33,531 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:17:33,534 - rag_module - INFO - 🔄 표준화된 질문: 주민등록·확정일자(확정일자) 했는데, 확정일자부(확정일자부) 내용까지 중요한가요?
# 2026-02-02 17:17:33,536 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='주민등록·확정일자(확정일자) 했는데, 확정일자부(확정일자부) 내용까지 중요한가요?'
# 2026-02-02 17:17:33,822 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:17:34,674 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:17:35,403 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:17:38,520 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-02 17:17:38,528 - rag_module - INFO - 📌 Rerank selected=2 (threshold=0.2)
# 2026-02-02 17:17:38,529 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-02 17:17:46,247 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:17:47,189 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:17:47,192 - rag_module - INFO - 🔄 표준화된 질문: 전세피해(권리리스크)로 아직 공식 결정 전인데 경매절차(경매) 매각기일이 잡혔습니다. 이 경우에도 경매절차(경매)를 멈출 수 있는 방법이 있나요?
# 2026-02-02 17:17:47,193 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='전세피해(권리리스크)로 아직 공식 결정 전인데 경매절차(경매) 매각기일이 잡혔습니다. 이 경우에도 경매절차(경매)를 멈출 수 있는 방법이 있나요?'
# 2026-02-02 17:17:47,902 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:17:48,539 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:17:49,440 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:17:51,172 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-02 17:17:51,178 - rag_module - INFO - 📌 Rerank selected=3 (threshold=0.2)
# 2026-02-02 17:17:51,179 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-02 17:17:59,635 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:18:00,372 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:18:00,375 - rag_module - INFO - 🔄 표준화된 질문: 조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
# 2026-02-02 17:18:00,376 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?'
# 2026-02-02 17:18:00,992 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:18:03,144 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:18:05,656 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:18:11,042 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-02 17:18:11,047 - rag_module - INFO - 📌 Rerank selected=13 (threshold=0.24)
# 2026-02-02 17:18:11,048 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-02 17:18:18,694 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:18:19,514 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:18:19,517 - rag_module - INFO - 🔄 표준화된 질문: 임대인(임대인)이 임대차보증금(보증금)을 보증금미반환(안돌려줌)해서 제가 일부러 주민등록(전입신고)을 유지하고 있는데, 다른 임차주택(집)으로 주민등록(전입신고)을 하면 제 임차인(임차인) 권리는 어떻게 되나요?
# 2026-02-02 17:18:19,518 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='임대인(임대인)이 임대차보증금(보증금)을 보증금미반환(안돌려줌)해서 제가 일부러 주민등록(전입신고)을 유지하고 있는데, 다른 임차주택(집)으로 주민등록(전입신고)을 하면 제 임차인(임차인) 권리는 어떻게 되나요?'
# 2026-02-02 17:18:20,012 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:18:20,720 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:18:21,405 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:18:23,547 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-02 17:18:23,554 - rag_module - INFO - 📌 Rerank selected=20 (threshold=0.24)
# 2026-02-02 17:18:23,555 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-02 17:18:32,455 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:18:34,072 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:18:34,075 - rag_module - INFO - 🔄 표준화된 질문: 계약서에 1년이라고 써 있으면, 1년 지나면 무조건 나가야 하나요?
# → 임대차계약증서에 1년이라고 기재(임대차계약증서)되어 있으면, 1년 경과 시 무조건 주택의인도(퇴거)해야 하나요?
#
# (※ 참고: 실제 법률 적용 시 「주택임대차보호법」 제4조(존속기간) 및 제6조(계약갱신요구권) 등 관련 규정 반드시 확인 필요)
#
# [용어 매핑 결과]
# - 계약서 → 임대차계약증서
# - 1년 → 1년 (변경 없음)
# - 무조건 나가야 → 주택의인도(퇴거)해야 (의도 보존을 위해 추가 설명 포함)
#
# ※ 주의: 사용자 질문 의도 왜곡 방지를 위해 '무조건 나가야'를 '주택의인도(퇴거)해야'로 변환하면서 괄호 설명을 추가하였습니다. 이는 '퇴거'의 법률 용어 정확성을 보완하기 위한 최소한의 설명입니다.
# 2026-02-02 17:18:34,076 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='계약서에 1년이라고 써 있으면, 1년 지나면 무조건 나가야 하나요?
# → 임대차계약증서에 1년이라고 기재(임대차계약증서)되어 있으면, 1년 경과 시 무조건 주택의인도(퇴거)해야 하나요?
#
# (※ 참고: 실제 법률 적용 시 「주택임대차보호법」 제4조(존속기간) 및 제6조(계약갱신요구권) 등 관련 규정 반드시 확인 필요)
#
# [용어 매핑 결과]
# - 계약서 → 임대차계약증서
# - 1년 → 1년 (변경 없음)
# - 무조건 나가야 → 주택의인도(퇴거)해야 (의도 보존을 위해 추가 설명 포함)
#
# ※ 주의: 사용자 질문 의도 왜곡 방지를 위해 '무조건 나가야'를 '주택의인도(퇴거)해야'로 변환하면서 괄호 설명을 추가하였습니다. 이는 '퇴거'의 법률 용어 정확성을 보완하기 위한 최소한의 설명입니다.'
# 2026-02-02 17:18:34,552 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:18:35,479 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:18:36,133 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:18:38,130 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-02 17:18:38,136 - rag_module - INFO - 📌 Rerank selected=20 (threshold=0.24)
# 2026-02-02 17:18:38,138 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-02 17:18:46,241 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:18:47,864 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:18:47,868 - rag_module - INFO - 🔄 표준화된 질문: 임대인(임대인)가 “주민등록(주민등록) 하지 말아달라”고 특약사항(특약사항)을 넣자고 합니다. 이 특약사항(특약사항)을 지키면 정말 문제(무효여부)가 생기나요?
# 2026-02-02 17:18:47,869 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='임대인(임대인)가 “주민등록(주민등록) 하지 말아달라”고 특약사항(특약사항)을 넣자고 합니다. 이 특약사항(특약사항)을 지키면 정말 문제(무효여부)가 생기나요?'
# 2026-02-02 17:18:48,595 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:18:50,599 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:18:51,333 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:18:53,704 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-02 17:18:53,710 - rag_module - INFO - 📌 Rerank selected=8 (threshold=0.24)
# 2026-02-02 17:18:53,711 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-02 17:19:00,226 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:19:01,056 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:19:01,058 - rag_module - INFO - 🔄 표준화된 질문: 경기도에 사는데 임차주택이 경매절차로 넘어가면, 임대차보증금 중 일부라도 우선변제권으로 받을 수 있나요?
# 2026-02-02 17:19:01,060 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='경기도에 사는데 임차주택이 경매절차로 넘어가면, 임대차보증금 중 일부라도 우선변제권으로 받을 수 있나요?'
# 2026-02-02 17:19:01,741 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:19:02,492 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:19:03,389 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:19:06,095 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-02 17:19:06,101 - rag_module - INFO - 📌 Rerank selected=5 (threshold=0.24)
# 2026-02-02 17:19:06,102 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-02 17:19:16,465 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:19:17,009 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:19:17,010 - rag_module - INFO - 🔄 표준화된 질문: 계약기간 중 임대인(임대인)이 바뀌었고, 새 임대인(임대인)이 나가라고 해요. 저는 누구에게 임대차보증금(임대차보증금)을 청구해야 하나요?
# 2026-02-02 17:19:17,011 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='계약기간 중 임대인(임대인)이 바뀌었고, 새 임대인(임대인)이 나가라고 해요. 저는 누구에게 임대차보증금(임대차보증금)을 청구해야 하나요?'
# 2026-02-02 17:19:17,301 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:19:18,905 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:19:19,826 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:19:23,069 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-02 17:19:23,074 - rag_module - INFO - 📌 Rerank selected=2 (threshold=0.24)
# 2026-02-02 17:19:23,074 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-02 17:19:32,306 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:19:32,977 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:19:32,980 - rag_module - INFO - 🔄 표준화된 질문: 묵시적갱신(묵시적갱신)으로 연장된 줄 모르고 살았는데, 주택의인도(주택의인도) 가려면 언제까지 살아야 하나요?
# 2026-02-02 17:19:32,982 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='묵시적갱신(묵시적갱신)으로 연장된 줄 모르고 살았는데, 주택의인도(주택의인도) 가려면 언제까지 살아야 하나요?'
# 2026-02-02 17:19:33,575 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:19:34,392 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:19:35,029 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:19:37,878 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-02 17:19:37,882 - rag_module - INFO - 📌 Rerank selected=13 (threshold=0.24)
# 2026-02-02 17:19:37,884 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-02 17:19:44,940 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:19:45,692 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:19:45,694 - rag_module - INFO - 🔄 표준화된 질문: 신축 임차주택인데 임대차보증금이 너무 높아서 불안합니다. 실거래가보다 훨씬 비싼 임대차보증금 계약도 법적으로 문제될 수 있나요?
# (빌라→임차주택, 전세가→임대차보증금)
# 2026-02-02 17:19:45,695 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='신축 임차주택인데 임대차보증금이 너무 높아서 불안합니다. 실거래가보다 훨씬 비싼 임대차보증금 계약도 법적으로 문제될 수 있나요?
# (빌라→임차주택, 전세가→임대차보증금)'
# 2026-02-02 17:19:46,550 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:19:47,211 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:19:48,041 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:19:50,827 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-02 17:19:50,833 - rag_module - INFO - 📌 Rerank selected=13 (threshold=0.24)
# 2026-02-02 17:19:50,835 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-02 17:20:00,589 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:20:01,695 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:20:01,699 - rag_module - INFO - 🔄 표준화된 질문: 주민등록·확정일자 했는데, 확정일자부 내용까지 중요한가요? (주민등록·확정일자 했는데, 확정일자부 내용까지 중요한가요?)
#
# ※ [용어 사전]에 '전입신고'는 '주민등록'으로만 매핑되어 있으며, '확정일자부'는 별도 매핑 대상이 아니므로 원문을 유지하였습니다.
# 2026-02-02 17:20:01,700 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='주민등록·확정일자 했는데, 확정일자부 내용까지 중요한가요? (주민등록·확정일자 했는데, 확정일자부 내용까지 중요한가요?)
#
# ※ [용어 사전]에 '전입신고'는 '주민등록'으로만 매핑되어 있으며, '확정일자부'는 별도 매핑 대상이 아니므로 원문을 유지하였습니다.'
# 2026-02-02 17:20:02,205 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:20:03,639 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:20:04,308 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:20:06,731 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-02 17:20:06,737 - rag_module - INFO - 📌 Rerank selected=20 (threshold=0.24)
# 2026-02-02 17:20:06,739 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-02 17:20:13,967 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:20:14,663 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:20:14,667 - rag_module - INFO - 🔄 표준화된 질문: 전세피해(권리리스크)로 아직 공식 결정 전인데 경매절차(경매) 매각기일이 잡혔습니다. 이 경우에도 경매절차(경매)를 멈출 수 있는 방법이 있나요?
# 2026-02-02 17:20:14,668 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='전세피해(권리리스크)로 아직 공식 결정 전인데 경매절차(경매) 매각기일이 잡혔습니다. 이 경우에도 경매절차(경매)를 멈출 수 있는 방법이 있나요?'
# 2026-02-02 17:20:15,227 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:20:16,074 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:20:16,749 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:20:18,851 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 200 OK"
# 2026-02-02 17:20:18,858 - rag_module - INFO - 📌 Rerank selected=3 (threshold=0.24)
# 2026-02-02 17:20:18,858 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-02 17:20:30,579 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ✅ BASE_SAMPLES: 10
# ✅ EXP_SAMPLES : 10
#                                question  \
# 0  조정에서 합의했는데 집주인이 안 지켜요. 이거 강제할 수 있나요?
#
#                                               answer  \
# 0  A. 조정에서 합의한 내용을 임대인이 지키지 않는 경우, 강제할 수 있는 방법이 있...
#
#                                             contexts  \
# 0  [page_content='이 법에 위반된 약정(約定)으로서 임차인에게 불리한 것은...
#
#                                         ground_truth
# 0  네, 강제할 수 있습니다.\n주택임대차보호법 제27조에 따르면,\n 제26조제4항 ...

# %% [markdown]
# ## 6) RAGAS evaluation (prepared cell)
#
# - Creates per-sample detail dataframe (when supported by your RAGAS version)
# - Creates summary dataframe (mean over samples)
# - Keeps timing metrics

# %%
# ============================================================
# RAGAS compare + clean saving (ragas==0.3.2 compatible)
# FIXES:
#  1) detail.csv에서 _trace 제거 (trace는 trace.jsonl로만)
#  2) samples에 run_tag를 미리 주입해서 trace.jsonl에 태그가 남도록
#  3) ground_truths=[...] 안전장치 추가 (버전/환경 호환성↑)
#  4) samples/detail 컬럼 충돌 방지(가능한 한 안전하게 merge)
# ============================================================

import time, json, re
from pathlib import Path
from datetime import datetime

import pandas as pd
from datasets import Dataset

from ragas import evaluate
from ragas.llms import llm_factory

# ----------------------------
# LLM + METRICS (ragas 0.3.2)
# ----------------------------

from openai import OpenAI
from langchain_openai import OpenAIEmbeddings

client = OpenAI()  # OPENAI_API_KEY 환경변수 사용
llm = llm_factory("gpt-4o-mini", client=client)
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")  # RAGAS metrics용

def build_metrics_032():
    from ragas.metrics import context_precision, context_recall, faithfulness
    metrics = [context_precision, context_recall, faithfulness]
    # answer_relevancy는 환경에 따라 없을 수 있어 optional
    try:
        from ragas.metrics import answer_relevancy
        metrics.append(answer_relevancy)
    except ImportError:
        pass
    return metrics

METRICS = build_metrics_032()
print("✅ METRICS:", [getattr(m, "__name__", m.__class__.__name__) for m in METRICS])

# ----------------------------
# utils
# ----------------------------
def _json_safe(obj):
    """Make config/meta safe to dump to json."""
    try:
        json.dumps(obj, ensure_ascii=False)
        return obj
    except TypeError:
        if hasattr(obj, "model_dump"):
            return obj.model_dump()
        if hasattr(obj, "dict"):
            return obj.dict()
        if hasattr(obj, "__dict__"):
            return obj.__dict__
        return str(obj)

def _write_json(path: Path, data):
    path.write_text(json.dumps(_json_safe(data), ensure_ascii=False, indent=2), encoding="utf-8")

def _write_jsonl(path: Path, rows):
    with path.open("w", encoding="utf-8") as f:
        for r in rows:
            f.write(json.dumps(_json_safe(r), ensure_ascii=False) + "\n")

def _next_run_dir(project_root: Path, prefix: str):
    runs_root = Path(project_root) / "results" / "ragas_runs"
    runs_root.mkdir(parents=True, exist_ok=True)

    pat = re.compile(rf"^{re.escape(prefix)}_(\d{{4}})_")
    nums = []
    for p in runs_root.iterdir():
        if p.is_dir():
            m = pat.match(p.name)
            if m:
                nums.append(int(m.group(1)))
    next_idx = (max(nums) + 1) if nums else 1

    ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    run_dir = runs_root / f"{prefix}_{next_idx:04d}_{ts}"
    run_dir.mkdir(parents=True, exist_ok=False)
    return run_dir, next_idx, ts

def _strip_trace(samples):
    """detail.csv에는 _trace를 넣지 않기(파일 폭발 방지)."""
    out = []
    for s in samples:
        if isinstance(s, dict):
            out.append({k: v for k, v in s.items() if k != "_trace"})
        else:
            out.append(s)
    return out

# ----------------------------
# core eval
# ----------------------------
def eval_ragas_with_details(samples, run_tag: str):
    # ✅ samples에 run_tag를 미리 주입 (trace.jsonl에서 태그 유지)
    for s in samples:
        if isinstance(s, dict):
            s["run_tag"] = run_tag
            # ✅ 안전장치: ground_truths도 함께
            if "ground_truths" not in s:
                gt = s.get("ground_truth") or ""
                s["ground_truths"] = [gt] if isinstance(gt, str) else (gt or [])

    ds = Dataset.from_list(samples)

    t0 = time.time()
    res = evaluate(
        dataset=ds,
        metrics=METRICS,
        embeddings=embeddings,   # ✅ 여기
    )
    eval_sec = time.time() - t0

    t1 = time.time()
    detail_df = res.to_pandas() if hasattr(res, "to_pandas") else pd.DataFrame()
    to_pandas_sec = time.time() - t1

    # ✅ detail에는 _trace 제외
    samples_df = pd.DataFrame(_strip_trace(samples))

    # merge per-sample metrics back onto samples (길이 동일할 때만)
    if len(detail_df) == len(samples_df) and len(detail_df) > 0:
        # 충돌 컬럼 방지: detail_df의 컬럼이 samples_df에 이미 있으면 prefix
        overlap = set(samples_df.columns) & set(detail_df.columns)
        if overlap:
            detail_df = detail_df.rename(columns={c: f"metric__{c}" for c in overlap})

        out_detail = pd.concat(
            [samples_df.reset_index(drop=True), detail_df.reset_index(drop=True)],
            axis=1
        )
    else:
        out_detail = samples_df.copy()

    out_detail["eval_seconds"] = round(eval_sec, 3)
    out_detail["to_pandas_seconds"] = round(to_pandas_sec, 3)

    # summary (mean of numeric metric columns if available)
    summary = {}
    if len(detail_df) > 0:
        summary = detail_df.mean(numeric_only=True).to_dict()
    elif isinstance(res, dict):
        summary = {k: float(v) for k, v in res.items() if isinstance(v, (int, float))}

    summary["run_tag"] = run_tag
    summary["eval_seconds"] = round(eval_sec, 3)
    summary["to_pandas_seconds"] = round(to_pandas_sec, 3)

    return res, out_detail, pd.DataFrame([summary])

# ----------------------------
# compare + save (clean)
# ----------------------------
def run_compare_and_save(
    base_samples,
    exp_samples,
    project_root: Path,
    prefix="ragas_compare",
    base_cfg=None,
    exp_cfg=None,
):
    # --- sanity ---
    print(f"✅ base_samples: {len(base_samples)} | exp_samples: {len(exp_samples)}")

    base_res, base_detail_df, base_summary_df = eval_ragas_with_details(base_samples, "baseline")
    exp_res,  exp_detail_df,  exp_summary_df  = eval_ragas_with_details(exp_samples,  "experiment")

    summary_df = pd.concat([base_summary_df, exp_summary_df], ignore_index=True)
    detail_df  = pd.concat([base_detail_df,  exp_detail_df],  ignore_index=True)

    run_dir, run_id, ts = _next_run_dir(project_root, prefix)

    out_summary = run_dir / "summary.csv"
    out_detail  = run_dir / "detail.csv"
    out_meta    = run_dir / "meta.json"
    out_config  = run_dir / "config.json"
    out_base_in = run_dir / "samples_base.jsonl"
    out_exp_in  = run_dir / "samples_exp.jsonl"
    out_trace   = run_dir / "trace.jsonl"

    summary_df.to_csv(out_summary, index=False, encoding="utf-8-sig")
    detail_df.to_csv(out_detail, index=False, encoding="utf-8-sig")

    # config snapshot (best-effort)
    cfg_payload = {
        "base_cfg": _json_safe(base_cfg) if base_cfg is not None else None,
        "exp_cfg":  _json_safe(exp_cfg)  if exp_cfg  is not None else None,
        "llm": {"model": "gpt-4o-mini"},
        "metrics": [getattr(m, "__name__", m.__class__.__name__) for m in METRICS],
        "created_at": datetime.now().isoformat(),
    }
    _write_json(out_config, cfg_payload)

    # input snapshots (원본 유지: _trace 포함)
    _write_jsonl(out_base_in, base_samples)
    _write_jsonl(out_exp_in,  exp_samples)

    # trace snapshot (best-effort) - samples의 _trace만 모아서 저장
    trace_rows = []
    for s in list(base_samples) + list(exp_samples):
        if isinstance(s, dict) and ("_trace" in s) and (s.get("_trace") is not None):
            trace_rows.append({
                "run_tag": s.get("run_tag"),
                "question": s.get("question"),
                "_trace": s.get("_trace"),
            })

    # trace가 아예 없으면 최소 정보라도 남김
    if not trace_rows:
        cols = [c for c in ["run_tag", "question", "eval_seconds"] if c in detail_df.columns]
        trace_rows = detail_df[cols].to_dict(orient="records") if cols else []

    _write_jsonl(out_trace, trace_rows)

    meta = {
        "created_at": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
        "ragas_version": "0.3.2",
        "run_id": run_id,
        "timestamp": ts,
        "run_dir": str(run_dir),
        "prefix": prefix,
        "n_base_samples": len(base_samples),
        "n_exp_samples": len(exp_samples),
        "saved": {
            "summary": str(out_summary),
            "detail": str(out_detail),
            "meta": str(out_meta),
            "config": str(out_config),
            "samples_base": str(out_base_in),
            "samples_exp": str(out_exp_in),
            "trace": str(out_trace),
        },
    }
    _write_json(out_meta, meta)

    print(f"✅ Saved to: {run_dir}")
    print(f"   - summary: {out_summary.name}")
    print(f"   - detail : {out_detail.name}")
    print(f"   - meta   : {out_meta.name}")
    print(f"   - config : {out_config.name}")
    print(f"   - inputs : {out_base_in.name}, {out_exp_in.name}")
    print(f"   - trace  : {out_trace.name}")

    return {
        "base_res": base_res,
        "exp_res": exp_res,
        "summary_df": summary_df,
        "detail_df": detail_df,
        "run_dir": run_dir,
        "out_summary": out_summary,
        "out_detail": out_detail,
        "out_meta": out_meta,
        "out_config": out_config,
        "out_samples_base": out_base_in,
        "out_samples_exp": out_exp_in,
        "out_trace": out_trace,
        "run_id": run_id,
    }

# ============================
# USAGE (예시)
# ============================
# result = run_compare_and_save(
#     base_samples=BASE_SAMPLES,
#     exp_samples=EXP_SAMPLES,
#     project_root=PROJECT_ROOT,
#     prefix="ragas_compare",
#     base_cfg=base_cfg,
#     exp_cfg=exp_cfg,
# )
# display(result["summary_df"])
# display(result["detail_df"].head(3))
# Out:
# ✅ METRICS: ['ContextPrecision', 'ContextRecall', 'Faithfulness', 'AnswerRelevancy']
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9156\1536660505.py:32: DeprecationWarning: Importing context_precision from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_precision
#   from ragas.metrics import context_precision, context_recall, faithfulness
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9156\1536660505.py:32: DeprecationWarning: Importing context_recall from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_recall
#   from ragas.metrics import context_precision, context_recall, faithfulness
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9156\1536660505.py:32: DeprecationWarning: Importing faithfulness from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import faithfulness
#   from ragas.metrics import context_precision, context_recall, faithfulness
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9156\1536660505.py:36: DeprecationWarning: Importing answer_relevancy from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import answer_relevancy
#   from ragas.metrics import answer_relevancy

# %% [markdown]
# ## 7) Run + compare + save

# %%
# ============================================================
# One-cell: RAGAS compare + save (+ delta outputs + dataset fingerprint)
# Adds:
#  - delta_summary.csv
#  - delta_detail.csv
#  - top_regressions.csv
#  - top_improvements.csv
#  - meta.json: testset fingerprint (path/lines/sha1) if TESTSET_JSONL exists
# ============================================================

import time, re, json, hashlib
from pathlib import Path
from datetime import datetime

import pandas as pd
from datasets import Dataset

from openai import OpenAI
from ragas import evaluate
from ragas.llms import llm_factory
from langchain_openai import OpenAIEmbeddings


# ----------------------------
# LLM (non-deprecated)
# ----------------------------
client = OpenAI()
llm = llm_factory("gpt-4o-mini", client=client)  # ✅ client 전달
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")  # RAGAS metrics용


# ----------------------------
# METRICS (version-tolerant)
# ----------------------------
def build_metrics():
    from ragas.metrics import context_precision, context_recall, faithfulness
    metrics = [context_precision, context_recall, faithfulness]
    try:
        from ragas.metrics import answer_relevancy
        metrics.append(answer_relevancy)
    except ImportError:
        pass
    return metrics

METRICS = build_metrics()
print("✅ METRICS:", [getattr(m, "__name__", m.__class__.__name__) for m in METRICS])


# ----------------------------
# JSON helpers (safe)
# ----------------------------
def _json_safe(obj):
    try:
        json.dumps(obj, ensure_ascii=False)
        return obj
    except TypeError:
        if hasattr(obj, "model_dump"):
            return obj.model_dump()
        if hasattr(obj, "dict"):
            return obj.dict()
        if hasattr(obj, "__dict__"):
            return obj.__dict__
        return str(obj)

def _write_json(path: Path, data):
    path.write_text(json.dumps(_json_safe(data), ensure_ascii=False, indent=2), encoding="utf-8")

def _write_jsonl(path: Path, rows):
    with path.open("w", encoding="utf-8") as f:
        for r in rows:
            f.write(json.dumps(_json_safe(r), ensure_ascii=False) + "\n")

def _df_to_jsonl_rows(df, prefer_cols):
    cols = [c for c in prefer_cols if c in df.columns]
    if cols:
        df = df[cols].copy()
    return df.to_dict(orient="records"), cols


# ----------------------------
# dataset fingerprint helpers
# ----------------------------
def _file_sha1(path: Path, chunk_size=1024 * 1024) -> str:
    h = hashlib.sha1()
    with path.open("rb") as f:
        while True:
            b = f.read(chunk_size)
            if not b:
                break
            h.update(b)
    return h.hexdigest()

def _count_jsonl_lines(path: Path) -> int:
    n = 0
    with path.open("r", encoding="utf-8") as f:
        for line in f:
            if line.strip():
                n += 1
    return n


# ----------------------------
# core: eval + detail/summary frames
# ----------------------------
def eval_ragas_with_details(samples, run_tag: str):
    ds = Dataset.from_list(samples)


    t0 = time.time()
    res = evaluate(
        dataset=ds,    # ✅ 여기
        metrics=METRICS,
        embeddings=embeddings,
    )
    eval_sec = time.time() - t0

    t1 = time.time()
    detail_df = res.to_pandas() if hasattr(res, "to_pandas") else pd.DataFrame()
    to_pandas_sec = time.time() - t1

    samples_df = pd.DataFrame(samples)

    # merge
    if len(detail_df) == len(samples_df) and len(detail_df) > 0:
        out_detail = pd.concat(
            [samples_df.reset_index(drop=True), detail_df.reset_index(drop=True)],
            axis=1
        )
    else:
        out_detail = samples_df.copy()

    out_detail["run_tag"] = run_tag
    out_detail["eval_seconds"] = round(eval_sec, 3)
    out_detail["to_pandas_seconds"] = round(to_pandas_sec, 3)

    # summary
    summary = {}
    if len(detail_df) > 0:
        summary = detail_df.mean(numeric_only=True).to_dict()
    elif isinstance(res, dict):
        summary = {k: float(v) for k, v in res.items() if isinstance(v, (int, float))}

    summary["run_tag"] = run_tag
    summary["eval_seconds"] = round(eval_sec, 3)
    summary["to_pandas_seconds"] = round(to_pandas_sec, 3)

    return res, out_detail, pd.DataFrame([summary])


# ----------------------------
# run dir allocator
# ----------------------------
def _next_run_dir(project_root: Path, prefix: str):
    runs_root = Path(project_root) / "results" / "ragas_runs"
    runs_root.mkdir(parents=True, exist_ok=True)

    pat = re.compile(rf"^{re.escape(prefix)}_(\d{{4}})_")
    nums = []
    for p in runs_root.iterdir():
        if p.is_dir():
            m = pat.match(p.name)
            if m:
                nums.append(int(m.group(1)))
    next_id = (max(nums) + 1) if nums else 1

    ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    run_dir = runs_root / f"{prefix}_{next_id:04d}_{ts}"
    run_dir.mkdir(parents=True, exist_ok=False)
    return run_dir, next_id, ts


# ----------------------------
# delta builders
# ----------------------------
def _pick_question_col(df: pd.DataFrame) -> str:
    for c in ["question", "normalized_question", "normalized_query", "query"]:
        if c in df.columns:
            return c
    return ""

def _ensure_question_id(df: pd.DataFrame) -> pd.DataFrame:
    # prefer an existing stable id
    for c in ["question_id", "id", "sample_id"]:
        if c in df.columns:
            df = df.copy()
            df["__qid__"] = df[c].astype(str)
            return df
    # fallback: hash question text
    qcol = _pick_question_col(df)
    df = df.copy()
    if qcol:
        def _h(x: str) -> str:
            s = (x or "").strip().encode("utf-8")
            return hashlib.sha1(s).hexdigest()[:12]
        df["__qid__"] = df[qcol].astype(str).map(_h)
    else:
        df["__qid__"] = [f"row{i:04d}" for i in range(len(df))]
    return df

def _metric_cols(df: pd.DataFrame) -> list:
    # heuristic: numeric columns from ragas result + common metric names
    prefer = [
        "context_precision", "context_recall", "faithfulness", "answer_relevancy",
        "ContextPrecision", "ContextRecall", "Faithfulness", "AnswerRelevancy",
    ]
    cols = [c for c in prefer if c in df.columns]
    if cols:
        return cols

    # fallback: any numeric columns that are not obvious non-metrics
    exclude = set(["eval_seconds", "to_pandas_seconds"])
    num_cols = []
    for c in df.columns:
        if c in exclude:
            continue
        if pd.api.types.is_numeric_dtype(df[c]):
            num_cols.append(c)
    return num_cols


def _make_delta_summary(summary_df: pd.DataFrame) -> pd.DataFrame:
    # summary_df has rows: baseline/experiment
    metric_cols = [c for c in summary_df.columns if c not in ["run_tag"]]
    base = summary_df[summary_df["run_tag"] == "baseline"].iloc[0].to_dict()
    exp  = summary_df[summary_df["run_tag"] == "experiment"].iloc[0].to_dict()

    rows = []
    for c in metric_cols:
        if c == "run_tag":
            continue
        b = base.get(c)
        e = exp.get(c)
        if isinstance(b, (int, float)) and isinstance(e, (int, float)):
            rows.append({"metric": c, "baseline": float(b), "experiment": float(e), "delta": float(e - b)})
        else:
            # keep non-numeric too
            rows.append({"metric": c, "baseline": b, "experiment": e, "delta": None})
    return pd.DataFrame(rows)


def _make_delta_detail(detail_df: pd.DataFrame) -> pd.DataFrame:
    df = _ensure_question_id(detail_df)

    base = df[df["run_tag"] == "baseline"].copy()
    exp  = df[df["run_tag"] == "experiment"].copy()

    # --- choose question column ---
    qcol = _pick_question_col(df)

    # --- metric columns ---
    mcols = _metric_cols(df)

    # --- info columns to keep (these overlap across base/exp) ---
    info_cols = ["__qid__"]
    if qcol:
        info_cols.append(qcol)
    for c in ["ground_truth", "reference", "answer", "contexts"]:
        if c in df.columns:
            info_cols.append(c)

    # --- select + rename (so no overlap) ---
    base_small = base[info_cols + mcols].copy()
    exp_small  = exp[info_cols + mcols].copy()

    rename_base = {c: f"{c}_base" for c in info_cols if c != "__qid__"}
    rename_exp  = {c: f"{c}_exp"  for c in info_cols if c != "__qid__"}
    rename_base.update({c: f"{c}_base" for c in mcols})
    rename_exp.update({c: f"{c}_exp"  for c in mcols})

    base_small = base_small.rename(columns=rename_base)
    exp_small  = exp_small.rename(columns=rename_exp)

    # --- merge safely ---
    merged = exp_small.merge(base_small, on="__qid__", how="outer")

    # --- compute deltas ---
    for c in mcols:
        cb = f"{c}_base"
        ce = f"{c}_exp"
        if cb in merged.columns and ce in merged.columns:
            merged[f"{c}_delta"] = merged[ce] - merged[cb]

    # --- convenience: make a unified question column (prefer exp, fallback base) ---
    if qcol:
        qe = f"{qcol}_exp"
        qb = f"{qcol}_base"
        if qe in merged.columns or qb in merged.columns:
            merged[qcol] = None
            if qe in merged.columns:
                merged[qcol] = merged[qe]
            if qb in merged.columns:
                merged[qcol] = merged[qcol].fillna(merged[qb])

    # --- order columns nicely ---
    ordered = ["__qid__"]
    if qcol and qcol in merged.columns:
        ordered.append(qcol)

    # keep references (unified view is optional; we keep exp/base separately)
    for c in ["ground_truth", "reference"]:
        # add unified if you want; here we keep exp/base columns only
        pass

    # metrics grouped
    for c in mcols:
        for suf in ["_base", "_exp", "_delta"]:
            col = f"{c}{suf}"
            if col in merged.columns:
                ordered.append(col)

    # then common info columns (exp/base)
    tail_info = []
    for c in ["ground_truth", "reference", "answer", "contexts"]:
        ce, cb = f"{c}_exp", f"{c}_base"
        if ce in merged.columns:
            tail_info.append(ce)
        if cb in merged.columns:
            tail_info.append(cb)

    remaining = [c for c in merged.columns if c not in ordered and c not in tail_info]
    return merged[ordered + remaining + tail_info].copy()



def _make_top_changes(delta_detail_df: pd.DataFrame, top_k=10) -> tuple[pd.DataFrame, pd.DataFrame, str]:
    # choose primary metric for sorting
    candidates = [
        "answer_relevancy_delta", "AnswerRelevancy_delta",
        "faithfulness_delta", "Faithfulness_delta",
        "context_precision_delta", "ContextPrecision_delta",
        "context_recall_delta", "ContextRecall_delta",
    ]
    sort_col = next((c for c in candidates if c in delta_detail_df.columns), None)
    if sort_col is None:
        # fallback: first *_delta numeric column
        delta_cols = [c for c in delta_detail_df.columns if c.endswith("_delta") and pd.api.types.is_numeric_dtype(delta_detail_df[c])]
        sort_col = delta_cols[0] if delta_cols else ""

    if not sort_col:
        # nothing to rank
        return pd.DataFrame(), pd.DataFrame(), ""

    # pick minimal view columns
    qcol = _pick_question_col(delta_detail_df)
    view_cols = [c for c in ["__qid__", qcol, sort_col] if c and c in delta_detail_df.columns]
    # add also base/exp of that metric if present
    base_col = sort_col.replace("_delta", "_base")
    exp_col  = sort_col.replace("_delta", "_exp")
    for c in [base_col, exp_col]:
        if c in delta_detail_df.columns and c not in view_cols:
            view_cols.append(c)

    regress = delta_detail_df.sort_values(sort_col, ascending=True).head(top_k)[view_cols].copy()
    improve = delta_detail_df.sort_values(sort_col, ascending=False).head(top_k)[view_cols].copy()
    return regress, improve, sort_col


# ----------------------------
# main: compare + save (csv/json + optional snapshots)
# ----------------------------
def run_compare_and_save_all(
    base_samples,
    exp_samples,
    project_root: Path,
    prefix="ragas_compare",
    save_snapshots=True,
    save_config=True,
    save_samples_jsonl=True,
    save_trace_jsonl=True,
    trace_cols_priority=None,
    save_delta_outputs=True,
    top_k=10,
):
    # 1) evaluate
    base_res, base_detail_df, base_summary_df = eval_ragas_with_details(base_samples, "baseline")
    exp_res,  exp_detail_df,  exp_summary_df  = eval_ragas_with_details(exp_samples,  "experiment")

    summary_df = pd.concat([base_summary_df, exp_summary_df], ignore_index=True)
    detail_df  = pd.concat([base_detail_df,  exp_detail_df],  ignore_index=True)

    # 2) run dir
    run_dir, run_id, ts = _next_run_dir(project_root, prefix)

    # 3) basic outputs
    out_summary = run_dir / "summary.csv"
    out_detail  = run_dir / "detail.csv"
    out_meta    = run_dir / "meta.json"

    summary_df.to_csv(out_summary, index=False, encoding="utf-8-sig")
    detail_df.to_csv(out_detail, index=False, encoding="utf-8-sig")

    # --- dataset fingerprint (optional) ---
    testset_info = None
    if "TESTSET_JSONL" in globals():
        p = Path(globals()["TESTSET_JSONL"])
        if p.exists():
            testset_info = {
                "testset_path": str(p),
                "testset_lines": _count_jsonl_lines(p),
                "testset_sha1": _file_sha1(p),
            }

    meta = {
        "created_at": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
        "run_id": run_id,
        "timestamp": ts,
        "run_dir": str(run_dir),
        "prefix": prefix,
        "n_base_samples": len(base_samples),
        "n_exp_samples": len(exp_samples),
        "metrics": [getattr(m, "__name__", m.__class__.__name__) for m in METRICS],
        "llm": {"model": "gpt-4o-mini"},
        "testset": testset_info,
    }
    _write_json(out_meta, meta)

    # 3-1) DELTA outputs (⭐️ NEW)
    extra = {}
    if save_delta_outputs:
        # delta_summary
        delta_summary_df = _make_delta_summary(summary_df)
        out_delta_summary = run_dir / "delta_summary.csv"
        delta_summary_df.to_csv(out_delta_summary, index=False, encoding="utf-8-sig")
        extra["out_delta_summary"] = str(out_delta_summary)

        # delta_detail
        delta_detail_df = _make_delta_detail(detail_df)
        out_delta_detail = run_dir / "delta_detail.csv"
        delta_detail_df.to_csv(out_delta_detail, index=False, encoding="utf-8-sig")
        extra["out_delta_detail"] = str(out_delta_detail)

        # top changes (regressions/improvements)
        top_regress, top_improve, sort_col = _make_top_changes(delta_detail_df, top_k=top_k)
        out_top_regress = run_dir / "top_regressions.csv"
        out_top_improve = run_dir / "top_improvements.csv"
        top_regress.to_csv(out_top_regress, index=False, encoding="utf-8-sig")
        top_improve.to_csv(out_top_improve, index=False, encoding="utf-8-sig")
        extra["out_top_regressions"] = str(out_top_regress)
        extra["out_top_improvements"] = str(out_top_improve)
        extra["top_rank_metric"] = sort_col

    # 4) optional snapshots
    if save_snapshots:
        # 4-1) config.json
        if save_config:
            cfg_payload = {
                "created_at": datetime.now().isoformat(),
                "llm": {"model": "gpt-4o-mini"},
                "metrics": [getattr(m, "__name__", m.__class__.__name__) for m in METRICS],
                "base_cfg": _json_safe(globals().get("base_cfg")) if "base_cfg" in globals() else None,
                "exp_cfg":  _json_safe(globals().get("exp_cfg"))  if "exp_cfg"  in globals() else None,
            }
            out_config = run_dir / "config.json"
            _write_json(out_config, cfg_payload)
            extra["out_config"] = str(out_config)

        # 4-2) input samples jsonl
        if save_samples_jsonl:
            out_samples_base = run_dir / "samples_base.jsonl"
            out_samples_exp  = run_dir / "samples_exp.jsonl"
            _write_jsonl(out_samples_base, base_samples)
            _write_jsonl(out_samples_exp,  exp_samples)
            extra["out_samples_base"] = str(out_samples_base)
            extra["out_samples_exp"]  = str(out_samples_exp)

        # 4-3) trace jsonl (from detail_df)
        if save_trace_jsonl:
            if trace_cols_priority is None:
                trace_cols_priority = [
                    "id", "sample_id", "__qid__",
                    "question", "normalized_question", "normalized_query", "query",
                    "answer", "ground_truth", "reference",
                    "contexts",
                    "_trace",
                    "retrieved_doc_ids", "retrieved_docs", "retrieval_scores",
                    "rerank_selected_ids", "rerank_scores",
                    "final_context_ids", "final_contexts",
                    "latency_ms", "latency_sec",
                    "run_tag",
                ]
            trace_rows, used_cols = _df_to_jsonl_rows(detail_df, trace_cols_priority)
            out_trace = run_dir / "trace.jsonl"
            _write_jsonl(out_trace, trace_rows)
            extra["out_trace"] = str(out_trace)
            extra["trace_cols_used"] = used_cols

    return {
        "base_res": base_res,
        "exp_res": exp_res,
        "summary_df": summary_df,
        "detail_df": detail_df,
        "run_dir": str(run_dir),
        "out_summary": str(out_summary),
        "out_detail": str(out_detail),
        "out_meta": str(out_meta),
        **extra,
    }


# ----------------------------
# RUN
# ----------------------------
result = run_compare_and_save_all(
    base_samples=BASE_SAMPLES,
    exp_samples=EXP_SAMPLES,
    project_root=PROJECT_ROOT,
    prefix="ragas_compare",
    save_snapshots=True,
    save_config=True,
    save_samples_jsonl=True,
    save_trace_jsonl=True,
    save_delta_outputs=True,  # ✅ NEW
    top_k=10,                 # ✅ NEW
)

print("✅ run_dir:", result["run_dir"])
print("✅ saved:", result["out_summary"], result["out_detail"], result["out_meta"])

# NEW delta outputs
if "out_delta_summary" in result:
    print("✅ delta saved:", result["out_delta_summary"], result.get("out_delta_detail"))
    print("✅ top changes metric:", result.get("top_rank_metric"))
    print("✅ top regressions:", result.get("out_top_regressions"))
    print("✅ top improvements:", result.get("out_top_improvements"))

# snapshots
if "out_config" in result:
    print("✅ extra saved config :", result["out_config"])
if "out_samples_base" in result:
    print("✅ extra saved samples:", result["out_samples_base"], "and", result.get("out_samples_exp"))
if "out_trace" in result:
    print("✅ extra saved trace  :", result["out_trace"])
    print("✅ trace columns used :", result.get("trace_cols_used"))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9156\2485394119.py:36: DeprecationWarning: Importing context_precision from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_precision
#   from ragas.metrics import context_precision, context_recall, faithfulness
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9156\2485394119.py:36: DeprecationWarning: Importing context_recall from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_recall
#   from ragas.metrics import context_precision, context_recall, faithfulness
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9156\2485394119.py:36: DeprecationWarning: Importing faithfulness from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import faithfulness
#   from ragas.metrics import context_precision, context_recall, faithfulness
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9156\2485394119.py:39: DeprecationWarning: Importing answer_relevancy from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import answer_relevancy
#   from ragas.metrics import answer_relevancy
# ✅ METRICS: ['ContextPrecision', 'ContextRecall', 'Faithfulness', 'AnswerRelevancy']
# Evaluating:   0%|                                                                               | 0/40 [00:00<?, ?it/s]2026-02-02 17:20:36,934 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:20:41,088 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:20:46,378 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:20:49,996 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:20:53,857 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:20:56,877 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:20:59,542 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:21:02,628 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:21:05,782 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:21:09,149 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:21:47,673 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:22:17,604 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:22:48,241 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:22:48,256 - ragas.executor - ERROR - Exception raised in Job[1]: InstructorRetryException(<failed_attempts>
#
# <generation number="1">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-D4jTCfbWjZutpxEGhebw5SBfzSI1U', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "classifications": [\n        {\n            "statement": "네, 강제할 수 있습니다.",\n            "reason": "The statement confirms the ability to enforce an agreement, which aligns with the context regarding the enforcement of agreements.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택임대차보호법 제27조에 따르면,",\n            "reason": "This references a specific law related to housing lease protection, which is relevant to the context provided.",\n            "attributed": 1\n        },\n        {\n            "statement": "제26조제4항 후단에 따라 강제집행을 승낙하는 취지의 내용이 기재된 조정서의 정본은",\n            "reason": "This statement discusses the content of a specific legal document, which is directly related to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "「민사집행법」 제56조에도 불구하고",\n            "reason": "This refers to another law that is relevant to the enforcement of agreements, thus it is attributed to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "집행력 있는 집행권원과 같은 효력을 가집니다.",\n            "reason": "This statement explains the legal effect of the document mentioned, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "즉, 조정서는 단순한 합의서가 아니라",\n            "reason": "This clarifies the nature of the document, which is pertinent to the context regarding agreements.",\n            "attributed": 1\n        },\n        {\n            "statement": "강제집행이 가능한 집행권원입니다.",\n            "reason": "This statement directly relates to the enforcement capabilities of the agreement, aligning with the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "또한 조정서가 집행력을 갖기 위해서는",\n            "reason": "This discusses the requirements for the document to have enforcement power, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "법과 시행령에서 정한 형식과 요건을 갖추어야 합니다.",\n            "reason": "This statement outlines the necessary legal requirements, which is pertinent to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "이에 대해 주택임대차보호법 시행령 제34조에 따르면,",\n            "reason": "This references a specific regulation related to housing lease protection, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "조정서에는 다음과 같은 사항이 기재되어야 합니다:",\n            "reason": "This introduces a list of requirements for the document, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "사건번호 및 사건명",\n            "reason": "This is part of the list of requirements for the document, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "당사자의 성명, 생년월일 및 주소",\n            "reason": "This is part of the list of requirements for the document, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차주택 소재지",\n            "reason": "This is part of the list of requirements for the document, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "신청의 취지 및 이유",\n            "reason": "This is part of the list of requirements for the document, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "조정내용(강제집행을 승낙하는 취지의 합의를 포함)",\n            "reason": "This is part of the list of requirements for the document, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "작성일",\n            "reason": "This is part of the list ...
# </completion>
# </generation>
#
# <generation number="2">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-D4jToztrMEnCTkmh4lG4oCvxnGzff', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "classifications": [\n        {\n            "statement": "네, 강제할 수 있습니다.",\n            "reason": "The statement confirms the ability to enforce an agreement, which aligns with the context regarding legal enforcement.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택임대차보호법 제27조에 따르면,",\n            "reason": "This references a specific law related to housing lease protection, which is relevant to the context provided.",\n            "attributed": 1\n        },\n        {\n            "statement": "제26조제4항 후단에 따라 강제집행을 승낙하는 취지의 내용이 기재된 조정서의 정본은",\n            "reason": "This statement discusses the content of a legal document that is directly related to the context about enforcement of agreements.",\n            "attributed": 1\n        },\n        {\n            "statement": "「민사집행법」 제56조에도 불구하고",\n            "reason": "This refers to another legal statute that is relevant to the enforcement of agreements, thus it is attributed.",\n            "attributed": 1\n        },\n        {\n            "statement": "집행력 있는 집행권원과 같은 효력을 가집니다.",\n            "reason": "This statement explains the legal effect of the document, which is pertinent to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "즉, 조정서는 단순한 합의서가 아니라",\n            "reason": "This clarifies the nature of the agreement, which is relevant to the context about legal enforcement.",\n            "attributed": 1\n        },\n        {\n            "statement": "강제집행이 가능한 집행권원입니다.",\n            "reason": "This statement directly relates to the enforcement capability of the agreement, aligning with the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "또한 조정서가 집행력을 갖기 위해서는",\n            "reason": "This discusses the requirements for the document to have enforcement power, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "법과 시행령에서 정한 형식과 요건을 갖추어야 합니다.",\n            "reason": "This statement outlines the necessary legal requirements, which is pertinent to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택임대차보호법 시행령 제34조에 따르면,",\n            "reason": "This references a specific regulation related to housing lease protection, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "조정서에는 다음과 같은 사항이 기재되어야 합니다:",\n            "reason": "This introduces a list of requirements for the document, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "사건번호 및 사건명",\n            "reason": "This is part of the list of requirements for the document, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "당사자의 성명, 생년월일 및 주소",\n            "reason": "This is part of the list of requirements for the document, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차주택 소재지",\n            "reason": "This is part of the list of requirements for the document, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "신청의 취지 및 이유",\n            "reason": "This is part of the list of requirements for the document, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "조정내용(강제집행을 승낙하는 취지의 합의를 포함)",\n            "reason": "This is part of the list of requirements for the document, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "작성일",\n            "reason": "This is part of the list of requir ...
# </completion>
# </generation>
#
# <generation number="3">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-D4jUHdG3kA9JTBfAgXqRAAxHpEge3', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "classifications": [\n        {\n            "statement": "네, 강제할 수 있습니다.",\n            "reason": "The statement confirms the ability to enforce the agreement, which aligns with the context regarding the enforcement of agreements.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택임대차보호법 제27조에 따르면,",\n            "reason": "This references a specific law that is relevant to the context provided.",\n            "attributed": 1\n        },\n        {\n            "statement": "제26조제4항 후단에 따라 강제집행을 승낙하는 취지의 내용이 기재된 조정서의 정본은",\n            "reason": "This statement directly relates to the provisions of the law mentioned in the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "「민사집행법」 제56조에도 불구하고",\n            "reason": "This refers to another law that is relevant to the enforcement of agreements, supporting the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "집행력 있는 집행권원과 같은 효력을 가집니다.",\n            "reason": "This statement explains the legal effect of the agreement, which is consistent with the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "즉, 조정서는 단순한 합의서가 아니라",\n            "reason": "This clarifies the nature of the agreement, which is relevant to the context provided.",\n            "attributed": 1\n        },\n        {\n            "statement": "강제집행이 가능한 집행권원입니다.",\n            "reason": "This statement directly relates to the enforcement capabilities discussed in the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "또한 조정서가 집행력을 갖기 위해서는",\n            "reason": "This statement introduces conditions for enforcement, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "법과 시행령에서 정한 형식과 요건을 갖추어야 합니다.",\n            "reason": "This statement discusses the requirements for the agreement to be enforceable, which aligns with the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "이에 대해 주택임대차보호법 시행령 제34조에 따르면,",\n            "reason": "This references a specific regulation that is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "조정서에는 다음과 같은 사항이 기재되어야 합니다:",\n            "reason": "This statement outlines requirements for the agreement, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "사건번호 및 사건명",\n            "reason": "This is part of the requirements for the agreement, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "당사자의 성명, 생년월일 및 주소",\n            "reason": "This is part of the requirements for the agreement, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차주택 소재지",\n            "reason": "This is part of the requirements for the agreement, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "신청의 취지 및 이유",\n            "reason": "This is part of the requirements for the agreement, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "조정내용(강제집행을 승낙하는 취지의 합의를 포함)",\n            "reason": "This is part of the requirements for the agreement, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "작성일",\n            "reason": "This is part of the requirements for the agreement, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "그리고 주택임대차보호법 시행령 제35조에 따르면,",\n            "r ...
# </completion>
# </generation>
#
# </failed_attempts>
#
# <last_exception>
#     The output is incomplete due to a max_tokens length limit.
# </last_exception>)
# 2026-02-02 17:22:57,176 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:23:26,407 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:23:48,999 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:24:15,434 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:24:15,445 - ragas.executor - ERROR - Exception raised in Job[2]: InstructorRetryException(<failed_attempts>
#
# <generation number="1">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-D4jUw2zHHdFdoAnGxT2cupxPbDyZu', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "조정에서 합의한 내용을 임대인이 지키지 않는 경우, 강제할 수 있는 방법이 존재한다.",\n            "reason": "The context discusses the enforcement of agreements made in mediation, implying that there are methods to enforce them if not followed.",\n            "verdict": 1\n        },\n        {\n            "statement": "지금 당장 할 일은 조정서의 내용을 확인하고 복사본을 보관하는 것이다.",\n            "reason": "The context does not provide specific instructions for immediate actions regarding the mediation document, making this statement unverifiable.",\n            "verdict": 0\n        },\n        {\n            "statement": "조정위원회에 이행을 요청하는 내용을 담은 서면을 제출해야 한다.",\n            "reason": "The context implies that a written request for enforcement can be made to the mediation committee, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "필요시 법원에 강제집행 신청을 고려해야 한다.",\n            "reason": "The context mentions the possibility of legal enforcement through the court, which supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "변호사와 상담하여 법적 조치를 검토해야 한다.",\n            "reason": "While consulting a lawyer is generally advisable, the context does not specifically mention this as a necessary step, making it unverifiable.",\n            "verdict": 0\n        },\n        {\n            "statement": "법적 근거로 주택임대차보호법 제26조에 따르면 조정안이 수락된 경우, 조정안과 동일한 내용의 합의가 성립된 것으로 본다.",\n            "reason": "The context explicitly states that acceptance of the mediation proposal results in a binding agreement, confirming this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "민사집행법 제1조에 따르면 법원의 판결이나 조정에 따라 강제집행이 가능하다.",\n            "reason": "The context supports the notion that enforcement can occur based on court rulings or mediation agreements, validating this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "절차와 증빙으로 조정서 사본을 준비하고, 조정위원회에 이행 요청서를 제출해야 한다.",\n            "reason": "The context implies that having a copy of the mediation document is necessary for enforcement requests, supporting this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "법원에 강제집행 신청 시, 조정서와 함께 필요한 서류를 제출해야 한다.",\n            "reason": "The context suggests that necessary documents must accompany enforcement requests to the court, confirming this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "변호사와 상담하여 필요한 서류 및 절차를 확인해야 한다.",\n            "reason": "While consulting a lawyer is generally advisable, the context does not specifically mention this as a necessary step, making it unverifiable.",\n            "verdict": 0\n        },\n        {\n            "statement": "유사 판례로 조정안이 성립된 경우, 이를 이행하지 않을 경우 강제집행이 가능하다는 판례가 존재한다.",\n            "reason": "The context does not provide information about specific precedents related to enforcement of mediation agreements, making this unverifiable.",\n            "verdict": 0\n        },\n        {\n            "statement": "구체적인 사례는 변호사와 상담하여 확인하는 것이 좋다.",\n            "reason": "While consulting a lawyer is generally advisable, the context does not specifically mention this as a necessary step, making it unverifiable.",\n            "verdict": 0\n        },\n        {\n            "statement": "추가 확인 질문으로 조정에서 합의한 내용은 무엇인지 확인해야 한다.",\n            "reason": "The context does not provide specific guidance on follow-up questions regarding the mediation agreement, making this unverifiable.",\n            "verdict": 0\n        },\n        {\n            "statement": "조정서의 사본을 보관하고 있는지 확인해야 한다.",\n            "reason": "The context implies the importance of keeping a copy of the mediation document, supporting this statement. ...
# </completion>
# </generation>
#
# <generation number="2">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-D4jVOuNCDXOV8nsC4LU27K9LBWvme', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "조정에서 합의한 내용을 임대인이 지키지 않는 경우, 강제할 수 있는 방법이 존재한다.",\n            "reason": "The context implies that if the landlord does not comply with the agreement made in the mediation, there are legal means to enforce it, although it does not explicitly state this.",\n            "verdict": 1\n        },\n        {\n            "statement": "지금 당장 할 일은 조정서의 내용을 확인하고 복사본을 보관하는 것이다.",\n            "reason": "The context does not provide specific instructions for immediate actions regarding the mediation document, making this statement unverifiable.",\n            "verdict": 0\n        },\n        {\n            "statement": "조정위원회에 이행을 요청하는 내용을 담은 서면을 제출해야 한다.",\n            "reason": "The context discusses the process of mediation but does not explicitly mention the need to submit a written request to the mediation committee for enforcement.",\n            "verdict": 0\n        },\n        {\n            "statement": "필요시 법원에 강제집행 신청을 고려해야 한다.",\n            "reason": "The context suggests that legal action may be necessary if the agreement is not followed, which supports this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "변호사와 상담하여 법적 조치를 검토해야 한다.",\n            "reason": "The context does not specifically mention consulting a lawyer, making this statement unverifiable.",\n            "verdict": 0\n        },\n        {\n            "statement": "법적 근거로 주택임대차보호법 제26조에 따르면 조정안이 수락된 경우, 조정안과 동일한 내용의 합의가 성립된 것으로 본다.",\n            "reason": "The context directly references the legal basis that an agreement is established when the mediation proposal is accepted, confirming this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "민사집행법 제1조에 따르면 법원의 판결이나 조정에 따라 강제집행이 가능하다.",\n            "reason": "The context does not provide information about the Civil Execution Act, making this statement unverifiable.",\n            "verdict": 0\n        },\n        {\n            "statement": "절차와 증빙으로 조정서 사본을 준비하고, 조정위원회에 이행 요청서를 제출해야 한다.",\n            "reason": "The context does not specify the need to prepare a copy of the mediation document or submit an enforcement request to the mediation committee.",\n            "verdict": 0\n        },\n        {\n            "statement": "법원에 강제집행 신청 시, 조정서와 함께 필요한 서류를 제출해야 한다.",\n            "reason": "The context does not provide details about the specific documents required for a court application for enforcement, making this statement unverifiable.",\n            "verdict": 0\n        },\n        {\n            "statement": "변호사와 상담하여 필요한 서류 및 절차를 확인해야 한다.",\n            "reason": "The context does not mention consulting a lawyer for necessary documents and procedures, making this statement unverifiable.",\n            "verdict": 0\n        },\n        {\n            "statement": "유사 판례로 조정안이 성립된 경우, 이를 이행하지 않을 경우 강제집행이 가능하다는 판례가 존재한다.",\n            "reason": "The context does not provide information about similar case law regarding enforcement of mediation agreements, making this statement unverifiable.",\n            "verdict": 0\n        },\n        {\n            "statement": "구체적인 사례는 변호사와 상담하여 확인하는 것이 좋다.",\n            "reason": "The context does not mention consulting a lawyer for specific cases, making this statement unverifiable.",\n            "verdict": 0\n        },\n        {\n            "statement": "추가 확인 질문으로 조정에서 합의한 내용은 무엇인지 확인해야 한다.",\n            "reason": "The context does not provide information about confirming the details of the agreement made in mediation, making this statement unverifiable.",\n            "verdict": 0\n        },\n        {\n            "statement": "조정서의 사본을 보관하고 있는지 확인해야 한다.",\n            "reason": "The context does not mention the need to check for a copy of t ...
# </completion>
# </generation>
#
# <generation number="3">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-D4jVlhDY052N7AafOeqwVOzHjTOLh', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "statements": [\n        {\n            "statement": "조정에서 합의한 내용을 임대인이 지키지 않는 경우, 강제할 수 있는 방법이 존재한다.",\n            "reason": "The context discusses the enforcement of agreements made in mediation, implying that there are methods to enforce such agreements.",\n            "verdict": 1\n        },\n        {\n            "statement": "지금 당장 할 일은 조정서의 내용을 확인하고 복사본을 보관하는 것이다.",\n            "reason": "The context does not provide specific instructions for immediate actions regarding the mediation document, making this statement unverifiable.",\n            "verdict": 0\n        },\n        {\n            "statement": "조정위원회에 이행을 요청하는 내용을 담은 서면을 제출해야 한다.",\n            "reason": "The context implies that a request for enforcement can be made, but it does not explicitly state that a written request must be submitted to the mediation committee.",\n            "verdict": 0\n        },\n        {\n            "statement": "필요시 법원에 강제집행 신청을 고려해야 한다.",\n            "reason": "The context mentions the possibility of enforcement through the court, indicating that considering a court application for enforcement is valid.",\n            "verdict": 1\n        },\n        {\n            "statement": "변호사와 상담하여 법적 조치를 검토해야 한다.",\n            "reason": "The context suggests consulting a lawyer for legal advice, making this statement reasonable.",\n            "verdict": 1\n        },\n        {\n            "statement": "법적 근거로 주택임대차보호법 제26조에 따르면 조정안이 수락된 경우, 조정안과 동일한 내용의 합의가 성립된 것으로 본다.",\n            "reason": "The context directly references the legal basis for the establishment of agreements in mediation, confirming this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "민사집행법 제1조에 따르면 법원의 판결이나 조정에 따라 강제집행이 가능하다.",\n            "reason": "The context supports the possibility of enforcement based on court rulings or mediation agreements, validating this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "절차와 증빙으로 조정서 사본을 준비하고, 조정위원회에 이행 요청서를 제출해야 한다.",\n            "reason": "While the context discusses the importance of documentation, it does not explicitly state that a copy of the mediation document must be prepared for submission, making this unverifiable.",\n            "verdict": 0\n        },\n        {\n            "statement": "법원에 강제집행 신청 시, 조정서와 함께 필요한 서류를 제출해야 한다.",\n            "reason": "The context implies that necessary documents must be submitted for court applications, making this statement reasonable.",\n            "verdict": 1\n        },\n        {\n            "statement": "변호사와 상담하여 필요한 서류 및 절차를 확인해야 한다.",\n            "reason": "The context suggests consulting a lawyer for necessary documents and procedures, validating this statement.",\n            "verdict": 1\n        },\n        {\n            "statement": "유사 판례로 조정안이 성립된 경우, 이를 이행하지 않을 경우 강제집행이 가능하다는 판례가 존재한다.",\n            "reason": "The context does not provide specific case law references, making this statement unverifiable.",\n            "verdict": 0\n        },\n        {\n            "statement": "구체적인 사례는 변호사와 상담하여 확인하는 것이 좋다.",\n            "reason": "The context supports the idea of consulting a lawyer for specific cases, making this statement reasonable.",\n            "verdict": 1\n        },\n        {\n            "statement": "추가 확인 질문으로 조정에서 합의한 내용은 무엇인지 확인해야 한다.",\n            "reason": "The context does not provide specific guidance on follow-up questions regarding the mediation agreement, making this unverifiable.",\n            "verdict": 0\n        },\n        {\n            "statement": "조정서의 사본을 보관하고 있는지 확인해야 한다.",\n            "reason": "The context does not explicitly mention the need to check for a copy of the mediation document, making this unverifiable.",\n            "verdict": 0\n       ...
# </completion>
# </generation>
#
# </failed_attempts>
#
# <last_exception>
#     The output is incomplete due to a max_tokens length limit.
# </last_exception>)
# 2026-02-02 17:24:16,734 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:24:17,268 - ragas.prompt.pydantic_prompt - WARNING - LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# 2026-02-02 17:24:18,188 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:24:19,108 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:24:21,811 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:24:25,610 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:24:29,320 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:24:31,970 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:24:35,246 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:24:38,015 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:24:41,153 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:24:44,489 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:24:47,086 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:24:50,451 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:25:34,077 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:25:45,171 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:26:11,624 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:26:14,242 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:26:14,816 - ragas.prompt.pydantic_prompt - WARNING - LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# 2026-02-02 17:26:15,694 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:26:16,513 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:26:19,055 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:26:22,193 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:26:25,293 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:26:28,402 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:26:32,426 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:26:36,627 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:26:39,662 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:26:42,817 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:26:45,796 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:26:48,615 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:27:05,793 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:27:15,725 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:27:35,938 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:27:38,345 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:27:38,874 - ragas.prompt.pydantic_prompt - WARNING - LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# 2026-02-02 17:27:39,739 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:27:40,519 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:27:44,052 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:27:47,158 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:27:50,013 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:27:53,090 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:27:55,819 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:27:58,821 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:28:01,575 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:28:04,365 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:28:07,290 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:28:10,344 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:28:36,017 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:29:03,659 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:29:34,346 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:29:34,356 - ragas.executor - ERROR - Exception raised in Job[13]: InstructorRetryException(<failed_attempts>
#
# <generation number="1">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-D4jZzE0TK5pPuMuNKwGXrWBIrQrgG', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "classifications": [\n        {\n            "statement": "네, 이 특약을 그대로 지키면 실제로 법적인 불이익이 생길 수 있습니다.",\n            "reason": "The statement indicates a potential legal disadvantage, which aligns with the context discussing the implications of not following legal requirements.",\n            "attributed": 1\n        },\n        {\n            "statement": "우선, 임차인이 전입신고를 하는 것은 단순한 행정절차가 아니라",\n            "reason": "This statement emphasizes the importance of the registration process, which is supported by the context that discusses legal procedures.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택임대차보호법상 대항력을 취득하기 위한 핵심 요건입니다.",\n            "reason": "This directly relates to the context that explains the legal requirements for obtaining rights under housing lease laws.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택임대차보호법 제3조 제1항에 따르면,",\n            "reason": "This references a specific legal article, which is relevant to the context provided.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차인은 주택의 인도와 주민등록을 마친 다음 날부터",\n            "reason": "This statement is consistent with the context that discusses the timing of legal rights acquisition.",\n            "attributed": 1\n        },\n        {\n            "statement": "즉, 전입신고를 하지 않으면 대항력이 발생하지 않습니다.",\n            "reason": "This statement directly reflects the legal consequences of not registering, which is discussed in the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "대항력이 없으면,",\n            "reason": "This statement introduces a consequence that is elaborated upon in the context, making it relevant.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택이 매매되거나",\n            "reason": "This statement discusses scenarios that are relevant to the context regarding the implications of lease agreements.",\n            "attributed": 1\n        },\n        {\n            "statement": "경매·공매로 넘어가는 경우",\n            "reason": "This is related to the legal context of property transactions and their implications for tenants.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차인은 새로운 소유자나 낙찰자에게",\n            "reason": "This statement is relevant as it discusses the rights of tenants in relation to new owners, which is a key point in the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차권이나 보증금 반환을 주장할 수 없게 될 위험이 있습니다",\n            "reason": "This statement highlights a risk that is directly related to the legal implications discussed in the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "(대항력의 효력 – 주택임대차보호법 제3조 제1항).",\n            "reason": "This references a specific legal provision, reinforcing the connection to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "그럼에도 불구하고 임대인이",\n            "reason": "This introduces a counterpoint that is relevant to the discussion of tenant rights in the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "“전입신고를 하지 말라”는 특약을 요구하는 것은,",\n            "reason": "This statement discusses a specific request from landlords that is relevant to the context of tenant agreements.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차인이 법에서 보장하는 보호수단을 사전에 포기하도록 만드는 내용에 해당합니다.",\n            "reason": "This statement discusses the implications of the landlord\'s request, which is a key point in the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "이에 대해",\n            "reason": "This statement introduces a legal reference that is relevant to t ...
# </completion>
# </generation>
#
# <generation number="2">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-D4jaO0F15jAZronKjVsXmrmU4fIBI', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "classifications": [\n        {\n            "statement": "네, 이 특약을 그대로 지키면 실제로 법적인 불이익이 생길 수 있습니다.",\n            "reason": "The statement indicates a potential legal disadvantage, which aligns with the context discussing the implications of not following legal requirements.",\n            "attributed": 1\n        },\n        {\n            "statement": "우선, 임차인이 전입신고를 하는 것은 단순한 행정절차가 아니라",\n            "reason": "This statement emphasizes the importance of the registration process, which is supported by the context that discusses the legal implications of such actions.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택임대차보호법상 대항력을 취득하기 위한 핵심 요건입니다.",\n            "reason": "This directly relates to the context that explains the legal requirements for obtaining rights under the housing lease protection law.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택임대차보호법 제3조 제1항에 따르면,",\n            "reason": "This references a specific legal article, which is relevant to the context provided.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차인은 주택의 인도와 주민등록을 마친 다음 날부터",\n            "reason": "This statement is a direct reference to the legal process described in the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "제3자에 대하여 임대차의 효력을 주장할 수 있습니다.",\n            "reason": "This statement is consistent with the context that discusses the effects of registration on third parties.",\n            "attributed": 1\n        },\n        {\n            "statement": "즉, 전입신고를 하지 않으면 대항력이 발생하지 않습니다.",\n            "reason": "This statement directly correlates with the context\'s explanation of the consequences of not registering.",\n            "attributed": 1\n        },\n        {\n            "statement": "대항력이 없으면,",\n            "reason": "This statement introduces a consequence that is elaborated upon in the context, making it relevant.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택이 매매되거나",\n            "reason": "This statement is relevant as it discusses scenarios that are mentioned in the context regarding the implications of not having legal rights.",\n            "attributed": 1\n        },\n        {\n            "statement": "경매·공매로 넘어가는 경우",\n            "reason": "This statement is relevant as it discusses scenarios that are mentioned in the context regarding the implications of not having legal rights.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차인은 새로운 소유자나 낙찰자에게",\n            "reason": "This statement is relevant as it discusses scenarios that are mentioned in the context regarding the implications of not having legal rights.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차권이나 보증금 반환을 주장할 수 없게 될 위험이 있습니다",\n            "reason": "This statement discusses the risks involved, which is a key point in the context provided.",\n            "attributed": 1\n        },\n        {\n            "statement": "(대항력의 효력 – 주택임대차보호법 제3조 제1항).",\n            "reason": "This references a specific legal article, which is relevant to the context provided.",\n            "attributed": 1\n        },\n        {\n            "statement": "그럼에도 불구하고 임대인이",\n            "reason": "This statement introduces a scenario that is relevant to the context discussing the landlord\'s actions.",\n            "attributed": 1\n        },\n        {\n            "statement": "“전입신고를 하지 말라”는 특약을 요구하는 것은,",\n            "reason": "This statement discusses the specific clause in question, which is central to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차인이 법에서 보장하는 보호수단을 사전에 포기하도록 만드는 내용에 해당합니다.",\n    ...
# </completion>
# </generation>
#
# <generation number="3">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-D4japp37uq1KreVBtWH53koLZqqA7', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "classifications": [\n        {\n            "statement": "네, 이 특약을 그대로 지키면 실제로 법적인 불이익이 생길 수 있습니다.",\n            "reason": "The statement indicates a potential legal disadvantage, which aligns with the context discussing the implications of not following the law.",\n            "attributed": 1\n        },\n        {\n            "statement": "우선, 임차인이 전입신고를 하는 것은 단순한 행정절차가 아니라",\n            "reason": "This statement emphasizes the importance of the registration process, which is relevant to the context provided.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택임대차보호법상 대항력을 취득하기 위한 핵심 요건입니다.",\n            "reason": "This directly relates to the context that discusses the legal requirements for obtaining rights under the housing lease protection law.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택임대차보호법 제3조 제1항에 따르면,",\n            "reason": "Citing a specific law aligns with the context that discusses legal provisions.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차인은 주택의 인도와 주민등록을 마친 다음 날부터",\n            "reason": "This statement is a direct reference to the legal requirements mentioned in the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "즉, 전입신고를 하지 않으면 대항력이 발생하지 않습니다.",\n            "reason": "This statement explains a consequence of not following the law, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "대항력이 없으면,",\n            "reason": "This statement introduces a consequence that is discussed in the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택이 매매되거나",\n            "reason": "This statement is relevant as it discusses scenarios that are mentioned in the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "경매·공매로 넘어가는 경우",\n            "reason": "This statement is relevant as it discusses scenarios that are mentioned in the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차인은 새로운 소유자나 낙찰자에게",\n            "reason": "This statement discusses the implications of the legal situation, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차권이나 보증금 반환을 주장할 수 없게 될 위험이 있습니다",\n            "reason": "This statement discusses the risks involved, which aligns with the context\'s focus on legal protections.",\n            "attributed": 1\n        },\n        {\n            "statement": "(대항력의 효력 – 주택임대차보호법 제3조 제1항).",\n            "reason": "This statement references a specific legal provision, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "그럼에도 불구하고 임대인이",\n            "reason": "This statement introduces a new point that is relevant to the discussion of the landlord\'s actions.",\n            "attributed": 1\n        },\n        {\n            "statement": "“전입신고를 하지 말라”는 특약을 요구하는 것은,",\n            "reason": "This statement discusses the landlord\'s request, which is directly related to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차인이 법에서 보장하는 보호수단을 사전에 포기하도록 만드는 내용에 해당합니다.",\n            "reason": "This statement explains the implications of the landlord\'s request, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "이에 대해",\n            "reason": "This statement introduces a legal reference, which is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택임대차보호법 제10조에 따르면,",\n            "reason": "This statement references a s ...
# </completion>
# </generation>
#
# </failed_attempts>
#
# <last_exception>
# ...
# </completion>
# </generation>
#
# </failed_attempts>
#
# <last_exception>
#     The output is incomplete due to a max_tokens length limit.
# </last_exception>)
# 2026-02-02 17:57:24,022 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:57:24,574 - ragas.prompt.pydantic_prompt - WARNING - LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# 2026-02-02 17:57:25,401 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:57:26,235 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-02 17:57:29,601 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:57:33,244 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:57:54,244 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:58:13,918 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:58:36,904 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-02 17:58:36,913 - ragas.executor - ERROR - Exception raised in Job[21]: InstructorRetryException(<failed_attempts>
#
# <generation number="1">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-D4k2Q3a24o9s46yYBVLxa5Hc23zC8', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "classifications": [\n        {\n            "statement": "원칙적으로 새 집주인에게 보증금을 청구해야 합니다.",\n            "reason": "The statement aligns with the context that discusses the obligations of the new landlord regarding the security deposit.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택임대차보호법 제3조 제1항에 따르면,",\n            "reason": "The reference to the housing lease protection law is relevant to the context provided.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차인이 주택의 인도와 주민등록을 마쳐 대항력을 갖춘 상태라면,",\n            "reason": "This condition is mentioned in the context regarding the rights of the tenant.",\n            "attributed": 1\n        },\n        {\n            "statement": "그 이후에 주택을 매수한 새 집주인에게도 임대차의 효력을 주장할 수 있습니다.",\n            "reason": "This statement is supported by the context that explains the transfer of lease rights to the new landlord.",\n            "attributed": 1\n        },\n        {\n            "statement": "즉, 임대차관계는 종전 집주인 개인에게만 묶여 있는 것이 아니라,",\n            "reason": "This statement reflects the context\'s explanation of the lease relationship not being limited to the previous landlord.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택 소유권과 결합된 상태로 새 집주인에게 이전됩니다.",\n            "reason": "The context discusses the transfer of ownership and its implications on the lease.",\n            "attributed": 1\n        },\n        {\n            "statement": "이 경우 보증금 반환의무 역시 함께 이전됩니다.",\n            "reason": "This is consistent with the context that states the obligations of the new landlord regarding the security deposit.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택임대차보호법 제3조 제4항에 따르면,",\n            "reason": "The reference to the housing lease protection law is relevant to the context provided.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차주택의 양수인(그 밖에 임대할 권리를 승계한 자를 포함한다)은",\n            "reason": "This statement is relevant as it discusses the rights of the new owner in relation to the lease.",\n            "attributed": 1\n        },\n        {\n            "statement": "임대인의 지위를 승계한 것으로 본다고 명확히 규정하고 있습니다.",\n            "reason": "This aligns with the context that explains the legal succession of the landlord\'s position.",\n            "attributed": 1\n        },\n        {\n            "statement": "이는 주택 소유권을 취득한 새 집주인이 법률상 당연히 종전 임대인의 지위와 의무를 승계한다는 의미이며,",\n            "reason": "This statement is supported by the context regarding the legal implications of ownership transfer.",\n            "attributed": 1\n        },\n        {\n            "statement": "보증금 반환의무도 이에 포함됩니다.",\n            "reason": "This is consistent with the context that states the obligations of the new landlord regarding the security deposit.",\n            "attributed": 1\n        },\n        {\n            "statement": "따라서 계약기간 중 집주인이 바뀌었고,",\n            "reason": "This statement directly relates to the context of the landlord changing during the contract period.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차인이 대항력을 갖춘 상태라면,",\n            "reason": "This condition is mentioned in the context regarding the rights of the tenant.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차인은 종전 집주인이 아니라 새 집주인에게 보증금 반환을 청구해야 합니다.",\n            "reason": "This statement is a direct conclusion drawn from the context provided.",\n            "attributed": 1\n        },\n        {\n            "statement": "반대로, 임차인이 대항력을 갖추지 못한 상태에서 주택 소유권이 이전된 경우에는",\n            "reason": "This statement discusses a scenario mentioned in the context regarding the tenant\'s rights.",\n            "attributed": 1\n        },\n        {\n    ...
# </completion>
# </generation>
#
# <generation number="2">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-D4k2kZL7aW4ZIPY7kxO02JCYysD4T', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "classifications": [\n        {\n            "statement": "원칙적으로 새 집주인에게 보증금을 청구해야 합니다.",\n            "reason": "The statement aligns with the context that discusses the obligations of the new landlord regarding the security deposit.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택임대차보호법 제3조 제1항에 따르면,",\n            "reason": "The reference to the housing lease protection law is relevant to the context provided.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차인이 주택의 인도와 주민등록을 마쳐 대항력을 갖춘 상태라면,",\n            "reason": "This condition is implied in the context regarding the rights of the tenant.",\n            "attributed": 1\n        },\n        {\n            "statement": "그 이후에 주택을 매수한 새 집주인에게도 임대차의 효력을 주장할 수 있습니다.",\n            "reason": "The context supports the idea that the lease\'s effectiveness can be claimed against the new landlord.",\n            "attributed": 1\n        },\n        {\n            "statement": "즉, 임대차관계는 종전 집주인 개인에게만 묶여 있는 것이 아니라,",\n            "reason": "This statement reflects the legal principle discussed in the context about the transfer of lease rights.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택 소유권과 결합된 상태로 새 집주인에게 이전됩니다.",\n            "reason": "The context indicates that the ownership transfer includes the lease obligations.",\n            "attributed": 1\n        },\n        {\n            "statement": "이 경우 보증금 반환의무 역시 함께 이전됩니다.",\n            "reason": "This is consistent with the context that discusses the transfer of obligations to the new landlord.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택임대차보호법 제3조 제4항에 따르면,",\n            "reason": "The reference to the housing lease protection law is relevant to the context provided.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차주택의 양수인(그 밖에 임대할 권리를 승계한 자를 포함한다)은",\n            "reason": "This statement is relevant as it discusses the rights of the new owner in relation to the lease.",\n            "attributed": 1\n        },\n        {\n            "statement": "임대인의 지위를 승계한 것으로 본다고 명확히 규정하고 있습니다.",\n            "reason": "This aligns with the context that states the new landlord inherits the obligations.",\n            "attributed": 1\n        },\n        {\n            "statement": "이는 주택 소유권을 취득한 새 집주인이 법률상 당연히 종전 임대인의 지위와 의무를 승계한다는 의미이며,",\n            "reason": "This is a direct interpretation of the legal principles outlined in the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "보증금 반환의무도 이에 포함됩니다.",\n            "reason": "This is consistent with the context that discusses the obligations of the new landlord.",\n            "attributed": 1\n        },\n        {\n            "statement": "따라서 계약기간 중 집주인이 바뀌었고,",\n            "reason": "This statement is a summary of the situation described in the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차인이 대항력을 갖춘 상태라면,",\n            "reason": "This condition is relevant to the context regarding the rights of the tenant.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차인은 종전 집주인이 아니라 새 집주인에게 보증금 반환을 청구해야 합니다.",\n            "reason": "This is a direct conclusion drawn from the context provided.",\n            "attributed": 1\n        },\n        {\n            "statement": "반대로, 임차인이 대항력을 갖추지 못한 상태에서 주택 소유권이 이전된 경우에는",\n            "reason": "This statement introduces a condition that is relevant to the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "임대차관계 자체를 새 집주인에게 주장할 수 없으므로,",\n            "reason": "This is consistent with the legal principles discussed in the context.",\n    ...
# </completion>
# </generation>
#
# <generation number="3">
# <exception>
#     The output is incomplete due to a max_tokens length limit.
# </exception>
# <completion>
#     ChatCompletion(id='chatcmpl-D4k34e6cDQu6XVPGsmb5geEzZvnCO', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "classifications": [\n        {\n            "statement": "원칙적으로 새 집주인에게 보증금을 청구해야 합니다.",\n            "reason": "The statement aligns with the context that discusses the obligations of the new landlord regarding the security deposit.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택임대차보호법 제3조 제1항에 따르면,",\n            "reason": "The reference to the housing lease protection law is relevant to the context provided.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차인이 주택의 인도와 주민등록을 마쳐 대항력을 갖춘 상태라면,",\n            "reason": "This condition is mentioned in the context regarding the rights of the tenant.",\n            "attributed": 1\n        },\n        {\n            "statement": "그 이후에 주택을 매수한 새 집주인에게도 임대차의 효력을 주장할 수 있습니다.",\n            "reason": "The context supports the assertion that the lease\'s effectiveness can be claimed against the new landlord.",\n            "attributed": 1\n        },\n        {\n            "statement": "즉, 임대차관계는 종전 집주인 개인에게만 묶여 있는 것이 아니라,",\n            "reason": "This statement reflects the legal principle discussed in the context about the transfer of lease rights.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택 소유권과 결합된 상태로 새 집주인에게 이전됩니다.",\n            "reason": "The context indicates that the ownership transfer includes the lease obligations.",\n            "attributed": 1\n        },\n        {\n            "statement": "이 경우 보증금 반환의무 역시 함께 이전됩니다.",\n            "reason": "This is consistent with the context that states the obligation to return the deposit transfers to the new landlord.",\n            "attributed": 1\n        },\n        {\n            "statement": "주택임대차보호법 제3조 제4항에 따르면,",\n            "reason": "The reference to the housing lease protection law is relevant to the context provided.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차주택의 양수인(그 밖에 임대할 권리를 승계한 자를 포함한다)은",\n            "reason": "This statement is relevant as it discusses the rights of the new owner in relation to the lease.",\n            "attributed": 1\n        },\n        {\n            "statement": "임대인의 지위를 승계한 것으로 본다고 명확히 규정하고 있습니다.",\n            "reason": "This aligns with the context that explains the legal succession of the landlord\'s position.",\n            "attributed": 1\n        },\n        {\n            "statement": "이는 주택 소유권을 취득한 새 집주인이 법률상 당연히 종전 임대인의 지위와 의무를 승계한다는 의미이며,",\n            "reason": "This statement is supported by the context regarding the legal implications of ownership transfer.",\n            "attributed": 1\n        },\n        {\n            "statement": "보증금 반환의무도 이에 포함됩니다.",\n            "reason": "This is consistent with the context that states the obligation to return the deposit transfers to the new landlord.",\n            "attributed": 1\n        },\n        {\n            "statement": "따라서 계약기간 중 집주인이 바뀌었고,",\n            "reason": "This statement directly relates to the situation described in the context.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차인이 대항력을 갖춘 상태라면,",\n            "reason": "This condition is mentioned in the context regarding the rights of the tenant.",\n            "attributed": 1\n        },\n        {\n            "statement": "임차인은 종전 집주인이 아니라 새 집주인에게 보증금 반환을 청구해야 합니다.",\n            "reason": "This conclusion is directly supported by the context provided.",\n            "attributed": 1\n        },\n        {\n            "statement": "반대로, 임차인이 대항력을 갖추지 못한 상태에서 주택 소유권이 이전된 경우에는",\n            "reason": "This statement discusses a scenario that is relevant to the context about tenant rights.",\n            "attributed": 1\n        },\n        {\n            "statement": "임대차관계 자체를 새 집주인에게 주장할 수 없으므로," ...
# </completion>
# </generation>
#
# </failed_attempts>
#
# <last_exception>
#     The output is incomplete due to a max_tokens length limit.
# </last_exception>)
# 2026-02-02 17:58:46,545 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
