# %% [markdown]
# # RAGAS Evaluation Notebook (Clean)
#
# This notebook evaluates **baseline vs experiment** RAG pipelines using RAGAS and saves **summary/detail** outputs per run.

# %%
# %pip install datasets

# %%
# %pip install ragas

# %%
# import sys, subprocess, textwrap

# def sh(cmd):
#     print(">", cmd)
#     r = subprocess.run(cmd, shell=True, capture_output=True, text=True)
#     print(r.stdout)
#     if r.stderr.strip():
#         print("[stderr]")
#         print(r.stderr)

# print("python:", sys.executable)
# print("version:", sys.version)

# # 현재 패키지 상태 확인
# sh("python -c \"import numpy; print('numpy', numpy.__version__)\"")
# sh("python -c \"import pyarrow; print('pyarrow', pyarrow.__version__)\"")
# sh("python -c \"import datasets; print('datasets', datasets.__version__)\"")

# %%
# import sys, subprocess

# def pip(cmd):
#     print(">", cmd)
#     r = subprocess.run([sys.executable, "-m", "pip"] + cmd.split(), capture_output=True, text=True)
#     print(r.stdout)
#     if r.stderr.strip():
#         print("[stderr]")
#         print(r.stderr)

# # 1) 제거
# pip("uninstall -y pyarrow datasets numpy")

# # 2) 재설치: numpy<2 + 최신 pyarrow + datasets(너가 쓰던 버전)
# pip("install numpy<2 pyarrow>=14 datasets==2.19.2")

# %%
# ---- RAGAS metrics: version-tolerant loader ----
def build_metrics():
    # A안: embeddings 의존 가능성이 큰 AnswerRelevancy는 빼고 "완주"부터
    # 1) 함수형 metric
    try:
        from ragas.metrics import context_precision, context_recall, faithfulness
        return [context_precision, context_recall, faithfulness]
    except Exception:
        pass

    # 2) 클래스형 metric
    try:
        from ragas.metrics import ContextPrecision, ContextRecall, Faithfulness
        return [ContextPrecision(), ContextRecall(), Faithfulness()]
    except Exception:
        pass

    # 3) fallback 탐색
    import ragas.metrics as m
    wanted = ["ContextPrecision", "ContextRecall", "Faithfulness"]
    found = []
    for name in wanted:
        if hasattr(m, name):
            found.append(getattr(m, name)())
    if found:
        return found

    raise ImportError(
        "RAGAS metrics import failed for A-plan (without AnswerRelevancy). "
        "Paste `pip show ragas` and `python -c \"import ragas; print(ragas.__version__)\"`."
    )

METRICS = build_metrics()
print("✅ METRICS:", [getattr(x, '__name__', x.__class__.__name__) for x in METRICS])
# Out:
# ✅ METRICS: ['ContextPrecision', 'ContextRecall', 'Faithfulness']
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14988\1708373533.py:6: DeprecationWarning: Importing context_precision from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_precision
#   from ragas.metrics import context_precision, context_recall, faithfulness
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14988\1708373533.py:6: DeprecationWarning: Importing context_recall from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_recall
#   from ragas.metrics import context_precision, context_recall, faithfulness
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14988\1708373533.py:6: DeprecationWarning: Importing faithfulness from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import faithfulness
#   from ragas.metrics import context_precision, context_recall, faithfulness

# %%
import ragas
print("ragas version:", getattr(ragas, "__version__", "unknown"))
# Out:
# ragas version: 0.4.3

# %%
from ragas.metrics import context_precision, context_recall, faithfulness, answer_relevancy

METRICS = [context_precision, context_recall, faithfulness, answer_relevancy]
print("✅ METRICS:", [getattr(m, "__name__", m.__class__.__name__) for m in METRICS])
# Out:
# ✅ METRICS: ['ContextPrecision', 'ContextRecall', 'Faithfulness', 'AnswerRelevancy']
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14988\3044559028.py:1: DeprecationWarning: Importing context_precision from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_precision
#   from ragas.metrics import context_precision, context_recall, faithfulness, answer_relevancy
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14988\3044559028.py:1: DeprecationWarning: Importing context_recall from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_recall
#   from ragas.metrics import context_precision, context_recall, faithfulness, answer_relevancy
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14988\3044559028.py:1: DeprecationWarning: Importing faithfulness from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import faithfulness
#   from ragas.metrics import context_precision, context_recall, faithfulness, answer_relevancy
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14988\3044559028.py:1: DeprecationWarning: Importing answer_relevancy from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import answer_relevancy
#   from ragas.metrics import context_precision, context_recall, faithfulness, answer_relevancy

# %% [markdown]
# ## 0) Environment & Paths

# %%
# ============================================================
# PATH CONFIG (only this cell is modified)
# ============================================================
import json
import pandas as pd
import sys, importlib
from pathlib import Path
from dotenv import load_dotenv

# ✅ 프로젝트 루트 (새 경로)
PROJECT_ROOT = Path(r"C:\ai\source\chatbot_app")

# ✅ 모듈 경로 (원래 쓰던 구조 그대로)
MODULE_DIR = PROJECT_ROOT / "modules"

# ✅ 환경변수
ENV_PATH = PROJECT_ROOT / ".env"

# ✅ 결과 저장 루트
RUNS_DIR = PROJECT_ROOT / "results" / "ragas_runs"

# ⭕️ 여기서 어떤 테스트셋 쓸지 네가 직접 선택
# TESTSET_PATH = PROJECT_ROOT / "ragas_testset_single.jsonl"
# TESTSET_PATH = PROJECT_ROOT / "ragas_testset_v1_from_docx.jsonl"
TESTSET_PATH = PROJECT_ROOT / "ragas_testset_10_selected.jsonl"

# ------------------------------------------------------------
# setup
# ------------------------------------------------------------
sys.path.insert(0, str(PROJECT_ROOT))
sys.path.insert(0, str(MODULE_DIR))
importlib.invalidate_caches()

if ENV_PATH.exists():
    load_dotenv(ENV_PATH)

RUNS_DIR.mkdir(parents=True, exist_ok=True)

print("PROJECT_ROOT:", PROJECT_ROOT)
print("TESTSET_PATH:", TESTSET_PATH)
print("exists:", TESTSET_PATH.exists())
# Out:
# PROJECT_ROOT: C:\ai\source\chatbot_app
# TESTSET_PATH: C:\ai\source\chatbot_app\ragas_testset_full.jsonl
# exists: True

# %% [markdown]
# ## 1) Load testset (JSONL)

# %%
TESTSET_JSONL = PROJECT_ROOT / "ragas_testset_10_selected.jsonl"  # change if needed
assert TESTSET_JSONL.exists(), f"❌ JSONL not found: {TESTSET_JSONL}"

rows = []
with open(TESTSET_JSONL, "r", encoding="utf-8") as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        rows.append(json.loads(line))

print("✅ rows:", len(rows))
print("✅ keys example:", rows[0].keys())
pd.DataFrame(rows[:3])
# Out:
# ✅ rows: 25
# ✅ keys example: dict_keys(['question_id', 'question', 'ground_truth', 'contexts', 'meta'])
#   question_id                               question  \
# 0        q001       전입신고·확정일자 했는데, 확정일자부 내용까지 중요한가요?
# 1        q002  계약서에 1년이라고 써 있으면, 1년 지나면 무조건 나가야 하나요?
# 2        q003     집주인이 아무 말 안 했는데, 계약이 자동으로 연장된 건가요?
#
#                                         ground_truth  \
# 0  네, 중요합니다. 확정일자를 받았다는 사실만으로 끝나는 것이 아니라, 확정일자부에 ...
# 1  아니요. 계약서에 1년이라고 적혀 있어도, 1년이 지나면 무조건 나가야 하는 것은 ...
# 2  네, 일정한 요건을 충족하면 계약은 자동으로 연장된 것으로 봅니다.\n주택임대차보호...
#
#                                             contexts  \
# 0  [주택임대차보호법 제3조의2 제2항, 주택임대차보호법 시행령 제4조, 주택임대차보호...
# 1                                 [주택임대차보호법 제4조 제1항]
# 2                                 [주택임대차보호법 제6조 제1항]
#
#                                                 meta
# 0  {'source': 'RAGAS 학습용 질문.docx', 'version': 'v1...
# 1  {'source': 'RAGAS 학습용 질문.docx', 'version': 'v1...
# 2  {'source': 'RAGAS 학습용 질문.docx', 'version': 'v1...

# %% [markdown]
# ## 2) Define baseline & experiment configs
#
# - Keep **base_cfg** stable.
# - Only put **changed knobs** in `exp_cfg = replace(base_cfg, ...)`.

# %%
from dataclasses import replace
from rag_module import RAGConfig

# =========================
# Base config (edit as needed)
# =========================
# =========================
# Base config (Champion = 이전 실험에서 이긴 설정으로 승격)
# =========================
base_cfg = RAGConfig(
    # -------- LLMs --------
    normalize_model="solar-pro2",
    generation_model="gpt-4o-mini",
    temperature=0.1,
    normalize_temperature=0.0,

    # -------- Embeddings --------
    embedding_backend="upstage",
    embedding_model="solar-embedding-1-large-passage",

    # -------- Retrieval sizes (A 파트: 고정) --------
    k_law=7,
    k_rule=7,
    k_case=3,
    search_multiplier=4,

    # -------- Candidate-level BM25 --------
    enable_bm25=True,
    sparse_mode="auto",
    sparse_k_law=None,
    sparse_k_rule=None,
    sparse_k_case=None,

    bm25_algorithm="okapi",
    bm25_k1=1.5,
    bm25_b=0.85,
    bm25_use_kiwi=True,
    bm25_max_doc_chars=2600,   # ⬆️ 설명용 문맥 여지

    # -------- Sparse: BM25-title --------
    enable_bm25_title=True,
    bm25_title_field="title",
    bm25_title_max_chars=512,
    hybrid_sparse_title_ratio=0.35,

    # -------- Fusion --------
    hybrid_fusion="rrf",
    hybrid_dense_weight=0.5,
    hybrid_sparse_weight=0.5,
    rrf_k=60,

    # -------- Rerank (LLM 비교용 완화 세팅) --------
    enable_rerank=True,
    rerank_threshold=0.20,     # ⬇️ 완화 (LLM이 선택할 여지)
    rerank_model="rerank-multilingual-v3.0",
    rerank_max_documents=22,   # ⬆️ 질문 의도 보강 문맥 포함
    rerank_doc_max_chars=2600, # ⬆️ faithfulness / relevancy 안정화

    # -------- 2-stage case expansion --------
    case_candidate_k=40,
    case_expand_top_n=None,
    case_context_top_k=50,
)

# ======================================
# EXP config (모델만 바꾼 실험군)
# ======================================
exp_cfg = replace(
    base_cfg,
    generation_model="gpt-4.1-mini",
)

base_cfg, exp_cfg
# Out:
# (RAGConfig(normalize_model='solar-pro2', generation_model='gpt-4o-mini', temperature=0.1, normalize_temperature=0.0, embedding_backend='upstage', embedding_model='solar-embedding-1-large-passage', k_law=7, k_rule=7, k_case=3, search_multiplier=4, enable_bm25=True, sparse_mode='auto', sparse_k_law=None, sparse_k_rule=None, sparse_k_case=None, bm25_algorithm='okapi', bm25_k1=1.5, bm25_b=0.85, bm25_use_kiwi=True, bm25_max_doc_chars=2200, enable_bm25_title=True, bm25_title_field='title', bm25_title_max_chars=512, hybrid_sparse_title_ratio=0.35, hybrid_fusion='rrf', hybrid_dense_weight=0.5, hybrid_sparse_weight=0.5, rrf_k=60, enable_rerank=True, rerank_threshold=0.22, rerank_model='rerank-multilingual-v3.0', rerank_max_documents=18, rerank_doc_max_chars=2200, case_candidate_k=40, case_expand_top_n=None, case_context_top_k=50, dedupe_key_fields=('chunk_id', 'id')),
#  RAGConfig(normalize_model='solar-pro2', generation_model='gpt-4.1-mini', temperature=0.1, normalize_temperature=0.0, embedding_backend='upstage', embedding_model='solar-embedding-1-large-passage', k_law=7, k_rule=7, k_case=3, search_multiplier=4, enable_bm25=True, sparse_mode='auto', sparse_k_law=None, sparse_k_rule=None, sparse_k_case=None, bm25_algorithm='okapi', bm25_k1=1.5, bm25_b=0.85, bm25_use_kiwi=True, bm25_max_doc_chars=2200, enable_bm25_title=True, bm25_title_field='title', bm25_title_max_chars=512, hybrid_sparse_title_ratio=0.35, hybrid_fusion='rrf', hybrid_dense_weight=0.5, hybrid_sparse_weight=0.5, rrf_k=60, enable_rerank=True, rerank_threshold=0.22, rerank_model='rerank-multilingual-v3.0', rerank_max_documents=18, rerank_doc_max_chars=2200, case_candidate_k=40, case_expand_top_n=None, case_context_top_k=50, dedupe_key_fields=('chunk_id', 'id')))

# %% [markdown]
# ## 3) Build pipelines

# %%
from rag_module import create_pipeline

base_pipe = create_pipeline(config=base_cfg)
exp_pipe  = create_pipeline(config=exp_cfg)

print("✅ pipelines ready")
# Out:
# 2026-02-04 13:06:55,089 - rag_module - INFO - 🔗 Pinecone 3중 인덱스 연결 중...
# 2026-02-04 13:06:55,090 - rag_module - INFO - ✅ [Law / Rule / Case] 3개 인덱스 로드 완료!
# 2026-02-04 13:06:55,521 - rag_module - INFO - ℹ️ SimpleTokenizer 사용 (BM25)
# 2026-02-04 13:06:56,091 - rag_module - INFO - 🔗 Pinecone 3중 인덱스 연결 중...
# 2026-02-04 13:06:56,093 - rag_module - INFO - ✅ [Law / Rule / Case] 3개 인덱스 로드 완료!
# 2026-02-04 13:06:56,472 - rag_module - INFO - ℹ️ SimpleTokenizer 사용 (BM25)
# ✅ pipelines ready

# %% [markdown]
# ## 4) (Optional) Quick trace sanity check

# %%
# If your rag_module exposes a trace / debug method, call it here.
# Otherwise you can skip this cell.

# Example (adjust to your actual API):
# ans, trace = base_pipe.answer_with_trace("테스트 질문 ...")
# display(trace)

print("ℹ️ Skip or customize depending on your pipeline API.")
# Out:
# ℹ️ Skip or customize depending on your pipeline API.

# %% [markdown]
# ## 5) Build RAGAS samples from your pipeline outputs
#
# This converts each testset row into the RAGAS format:
# - `question`
# - `answer`
# - `contexts` (list[str])
# - `ground_truth`

# %%
def shrink_contexts(ctxs, max_chars=900, max_contexts=8):
    out, seen = [], set()
    for c in (ctxs or []):
        if c is None:
            continue
        s = str(c).strip()
        if not s:
            continue
        s = s[:max_chars]
        if s in seen:
            continue
        seen.add(s)
        out.append(s)
        if len(out) >= max_contexts:
            break
    return out

def row_get_ground_truth(r: dict):
    return r.get("ground_truth") or r.get("reference") or r.get("gt") or r.get("answer")

def _call_pipe(pipe, q):
    """Call various pipeline styles (callable / .invoke / .run / .query / .ask)."""
    if callable(pipe):
        return pipe(q)
    for m in ("answer_with_trace", "invoke", "run", "query", "ask", "call", "answer"):
        if hasattr(pipe, m):
            return getattr(pipe, m)(q)
    raise TypeError(f"Pipeline is not callable and no known method found: {type(pipe)}")

def _unwrap_answer_contexts(out):
    """Normalize pipeline output to (answer:str, contexts:list[str])."""
    ans, ctxs = None, None

    # (answer, contexts) tuple OR (answer, trace) tuple
    if isinstance(out, tuple) and len(out) >= 2:
        ans = out[0]
        second = out[1]
        # if second looks like a trace dict, try to pull contexts from it
        if isinstance(second, dict):
            ctxs = (
                second.get("final_contexts")
                or second.get("contexts")
                or second.get("context")
                or second.get("documents")
                or second.get("docs")
                or second.get("sources")
            ) or []
        else:
            ctxs = second

    # dict-like
    elif isinstance(out, dict):
        ans = out.get("answer") or out.get("result") or out.get("output") or out.get("final_answer")
        ctxs = (
            out.get("contexts")
            or out.get("context")
            or out.get("sources")
            or out.get("documents")
            or out.get("docs")
        )
        if ctxs is None and isinstance(out.get("trace"), dict):
            t = out.get("trace")
            ctxs = (
                t.get("final_contexts")
                or t.get("contexts")
                or t.get("context")
                or t.get("documents")
                or t.get("docs")
                or t.get("sources")
            )

    # object-like
    else:
        # some pipelines return objects with .answer / .contexts
        if hasattr(out, "answer") and ans is None:
            ans = getattr(out, "answer")
        if hasattr(out, "contexts") and ctxs is None:
            ctxs = getattr(out, "contexts")
        if ans is None:
            ans = str(out)
        if ctxs is None:
            ctxs = []

    # normalize contexts to list[str]
    if ctxs is None:
        ctxs = []
    if isinstance(ctxs, (str, bytes)):
        ctxs = [ctxs]

    # if contexts are list of dicts/objects, stringify safely
    norm_ctxs = []
    if isinstance(ctxs, list):
        for c in ctxs:
            if c is None:
                continue
            if isinstance(c, str):
                norm_ctxs.append(c)
            elif isinstance(c, dict):
                # common fields
                norm_ctxs.append(str(c.get("text") or c.get("content") or c.get("page_content") or c))
            else:
                norm_ctxs.append(str(getattr(c, "page_content", None) or getattr(c, "content", None) or c))
    else:
        norm_ctxs = [str(ctxs)]

    return str(ans) if ans is not None else "", norm_ctxs

def run_pipe_to_samples(pipe, rows, max_chars=900, max_contexts=8, limit=10):
    samples = []
    n = len(rows) if limit is None else min(limit, len(rows))
    for i in range(n):
        r = rows[i]
        q = r.get("question") or r.get("query")
        if not q:
            continue

        out = _call_pipe(pipe, q)
        ans, ctxs = _unwrap_answer_contexts(out)

        samples.append({
            "question_id": i,
            "question": q,
            "answer": ans,
            "contexts": shrink_contexts(ctxs, max_chars=max_chars, max_contexts=max_contexts),
            "ground_truth": row_get_ground_truth(r),
        })
    return samples

# %% [markdown]
# ## 6) RAGAS evaluation (prepared cell)
#
# - Creates per-sample detail dataframe (when supported by your RAGAS version)
# - Creates summary dataframe (mean over samples)
# - Keeps timing metrics

# %%
# ============================================================
# RAGAS compare + clean saving (ragas==0.3.2 compatible)
# FIXES:
#  1) detail.csv에서 _trace 제거 (trace는 trace.jsonl로만)
#  2) samples에 run_tag를 미리 주입해서 trace.jsonl에 태그가 남도록
#  3) ground_truths=[...] 안전장치 추가 (버전/환경 호환성↑)
#  4) samples/detail 컬럼 충돌 방지(가능한 한 안전하게 merge)
# ============================================================

import time, json, re
from pathlib import Path
from datetime import datetime

import pandas as pd
from datasets import Dataset

from ragas import evaluate
from ragas.llms import llm_factory

# ----------------------------
# LLM + METRICS (ragas 0.3.2)
# ----------------------------

from openai import OpenAI
from langchain_openai import OpenAIEmbeddings

client = OpenAI()  # OPENAI_API_KEY 환경변수 사용

from langchain_openai import ChatOpenAI
from ragas.llms import LangchainLLMWrapper

llm = LangchainLLMWrapper(
    ChatOpenAI(model="gpt-4o-mini", temperature=0)
)

# llm = llm_factory("gpt-4o-mini", client=client)
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")  # RAGAS metrics용

def build_metrics_032():
    from ragas.metrics import context_precision, context_recall, faithfulness
    metrics = [context_precision, context_recall, faithfulness]
    # answer_relevancy는 환경에 따라 없을 수 있어 optional
    try:
        from ragas.metrics import answer_relevancy
        metrics.append(answer_relevancy)
    except ImportError:
        pass
    return metrics

METRICS = build_metrics_032()
print("✅ METRICS:", [getattr(m, "__name__", m.__class__.__name__) for m in METRICS])

# ----------------------------
# utils
# ----------------------------
def _json_safe(obj):
    """Make config/meta safe to dump to json."""
    try:
        json.dumps(obj, ensure_ascii=False)
        return obj
    except TypeError:
        if hasattr(obj, "model_dump"):
            return obj.model_dump()
        if hasattr(obj, "dict"):
            return obj.dict()
        if hasattr(obj, "__dict__"):
            return obj.__dict__
        return str(obj)

def _write_json(path: Path, data):
    path.write_text(json.dumps(_json_safe(data), ensure_ascii=False, indent=2), encoding="utf-8")

def _write_jsonl(path: Path, rows):
    with path.open("w", encoding="utf-8") as f:
        for r in rows:
            f.write(json.dumps(_json_safe(r), ensure_ascii=False) + "\n")

def _next_run_dir(project_root: Path, prefix: str):
    runs_root = Path(project_root) / "results" / "ragas_runs"
    runs_root.mkdir(parents=True, exist_ok=True)

    pat = re.compile(rf"^{re.escape(prefix)}_(\d{{4}})_")
    nums = []
    for p in runs_root.iterdir():
        if p.is_dir():
            m = pat.match(p.name)
            if m:
                nums.append(int(m.group(1)))
    next_idx = (max(nums) + 1) if nums else 1

    ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    run_dir = runs_root / f"{prefix}_{next_idx:04d}_{ts}"
    run_dir.mkdir(parents=True, exist_ok=False)
    return run_dir, next_idx, ts

def _strip_trace(samples):
    """detail.csv에는 _trace를 넣지 않기(파일 폭발 방지)."""
    out = []
    for s in samples:
        if isinstance(s, dict):
            out.append({k: v for k, v in s.items() if k != "_trace"})
        else:
            out.append(s)
    return out

# ----------------------------
# core eval
# ----------------------------
def eval_ragas_with_details(samples, run_tag: str):
    # ✅ samples에 run_tag를 미리 주입 (trace.jsonl에서 태그 유지)
    for s in samples:
        if isinstance(s, dict):
            s["run_tag"] = run_tag
            # ✅ 안전장치: ground_truths도 함께
            if "ground_truths" not in s:
                gt = s.get("ground_truth") or ""
                s["ground_truths"] = [gt] if isinstance(gt, str) else (gt or [])

    ds = Dataset.from_list(samples)

    t0 = time.time()
    res = evaluate(
        dataset=ds,
        metrics=METRICS,
        embeddings=embeddings,   # ✅ 여기
    )
    eval_sec = time.time() - t0

    t1 = time.time()
    detail_df = res.to_pandas() if hasattr(res, "to_pandas") else pd.DataFrame()
    to_pandas_sec = time.time() - t1

    # ✅ detail에는 _trace 제외
    samples_df = pd.DataFrame(_strip_trace(samples))

    # merge per-sample metrics back onto samples (길이 동일할 때만)
    if len(detail_df) == len(samples_df) and len(detail_df) > 0:
        # 충돌 컬럼 방지: detail_df의 컬럼이 samples_df에 이미 있으면 prefix
        overlap = set(samples_df.columns) & set(detail_df.columns)
        if overlap:
            detail_df = detail_df.rename(columns={c: f"metric__{c}" for c in overlap})

        out_detail = pd.concat(
            [samples_df.reset_index(drop=True), detail_df.reset_index(drop=True)],
            axis=1
        )
    else:
        out_detail = samples_df.copy()

    out_detail["eval_seconds"] = round(eval_sec, 3)
    out_detail["to_pandas_seconds"] = round(to_pandas_sec, 3)

    # summary (mean of numeric metric columns if available)
    summary = {}
    if len(detail_df) > 0:
        summary = detail_df.mean(numeric_only=True).to_dict()
    elif isinstance(res, dict):
        summary = {k: float(v) for k, v in res.items() if isinstance(v, (int, float))}

    summary["run_tag"] = run_tag
    summary["eval_seconds"] = round(eval_sec, 3)
    summary["to_pandas_seconds"] = round(to_pandas_sec, 3)

    return res, out_detail, pd.DataFrame([summary])

# ----------------------------
# compare + save (clean)
# ----------------------------
def run_compare_and_save(
    base_samples,
    exp_samples,
    project_root: Path,
    prefix="ragas_compare",
    base_cfg=None,
    exp_cfg=None,
):
    # --- sanity ---
    print(f"✅ base_samples: {len(base_samples)} | exp_samples: {len(exp_samples)}")

    base_res, base_detail_df, base_summary_df = eval_ragas_with_details(base_samples, "baseline")
    exp_res,  exp_detail_df,  exp_summary_df  = eval_ragas_with_details(exp_samples,  "experiment")

    summary_df = pd.concat([base_summary_df, exp_summary_df], ignore_index=True)
    detail_df  = pd.concat([base_detail_df,  exp_detail_df],  ignore_index=True)

    run_dir, run_id, ts = _next_run_dir(project_root, prefix)

    out_summary = run_dir / "summary.csv"
    out_detail  = run_dir / "detail.csv"
    out_meta    = run_dir / "meta.json"
    out_config  = run_dir / "config.json"
    out_base_in = run_dir / "samples_base.jsonl"
    out_exp_in  = run_dir / "samples_exp.jsonl"
    out_trace   = run_dir / "trace.jsonl"

    summary_df.to_csv(out_summary, index=False, encoding="utf-8-sig")
    detail_df.to_csv(out_detail, index=False, encoding="utf-8-sig")

    # config snapshot (best-effort)
    cfg_payload = {
        "base_cfg": _json_safe(base_cfg) if base_cfg is not None else None,
        "exp_cfg":  _json_safe(exp_cfg)  if exp_cfg  is not None else None,
        "llm": {"model": "gpt-4o-mini"},
        "metrics": [getattr(m, "__name__", m.__class__.__name__) for m in METRICS],
        "created_at": datetime.now().isoformat(),
    }
    _write_json(out_config, cfg_payload)

    # input snapshots (원본 유지: _trace 포함)
    _write_jsonl(out_base_in, base_samples)
    _write_jsonl(out_exp_in,  exp_samples)

    # trace snapshot (best-effort) - samples의 _trace만 모아서 저장
    trace_rows = []
    for s in list(base_samples) + list(exp_samples):
        if isinstance(s, dict) and ("_trace" in s) and (s.get("_trace") is not None):
            trace_rows.append({
                "run_tag": s.get("run_tag"),
                "question": s.get("question"),
                "_trace": s.get("_trace"),
            })

    # trace가 아예 없으면 최소 정보라도 남김
    if not trace_rows:
        cols = [c for c in ["run_tag", "question", "eval_seconds"] if c in detail_df.columns]
        trace_rows = detail_df[cols].to_dict(orient="records") if cols else []

    _write_jsonl(out_trace, trace_rows)

    meta = {
        "created_at": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
        "ragas_version": "0.3.2",
        "run_id": run_id,
        "timestamp": ts,
        "run_dir": str(run_dir),
        "prefix": prefix,
        "n_base_samples": len(base_samples),
        "n_exp_samples": len(exp_samples),
        "saved": {
            "summary": str(out_summary),
            "detail": str(out_detail),
            "meta": str(out_meta),
            "config": str(out_config),
            "samples_base": str(out_base_in),
            "samples_exp": str(out_exp_in),
            "trace": str(out_trace),
        },
    }
    _write_json(out_meta, meta)

    print(f"✅ Saved to: {run_dir}")
    print(f"   - summary: {out_summary.name}")
    print(f"   - detail : {out_detail.name}")
    print(f"   - meta   : {out_meta.name}")
    print(f"   - config : {out_config.name}")
    print(f"   - inputs : {out_base_in.name}, {out_exp_in.name}")
    print(f"   - trace  : {out_trace.name}")

    return {
        "base_res": base_res,
        "exp_res": exp_res,
        "summary_df": summary_df,
        "detail_df": detail_df,
        "run_dir": run_dir,
        "out_summary": out_summary,
        "out_detail": out_detail,
        "out_meta": out_meta,
        "out_config": out_config,
        "out_samples_base": out_base_in,
        "out_samples_exp": out_exp_in,
        "out_trace": out_trace,
        "run_id": run_id,
    }

# ============================
# USAGE (예시)
# ============================
# result = run_compare_and_save(
#     base_samples=BASE_SAMPLES,
#     exp_samples=EXP_SAMPLES,
#     project_root=PROJECT_ROOT,
#     prefix="ragas_compare",
#     base_cfg=base_cfg,
#     exp_cfg=exp_cfg,
# )
# display(result["summary_df"])
# display(result["detail_df"].head(3))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14988\271458754.py:32: DeprecationWarning: LangchainLLMWrapper is deprecated and will be removed in a future version. Use llm_factory instead: from openai import OpenAI; from ragas.llms import llm_factory; llm = llm_factory('gpt-4o-mini', client=OpenAI(api_key='...'))
#   llm = LangchainLLMWrapper(
# ✅ METRICS: ['ContextPrecision', 'ContextRecall', 'Faithfulness', 'AnswerRelevancy']
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14988\271458754.py:40: DeprecationWarning: Importing context_precision from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_precision
#   from ragas.metrics import context_precision, context_recall, faithfulness
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14988\271458754.py:40: DeprecationWarning: Importing context_recall from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_recall
#   from ragas.metrics import context_precision, context_recall, faithfulness
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14988\271458754.py:40: DeprecationWarning: Importing faithfulness from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import faithfulness
#   from ragas.metrics import context_precision, context_recall, faithfulness
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14988\271458754.py:44: DeprecationWarning: Importing answer_relevancy from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import answer_relevancy
#   from ragas.metrics import answer_relevancy

# %% [markdown]
# ## 7) Run + compare + save

# %%
# ----------------------------
# BUILD SAMPLES (run this BEFORE the compare cell)
# ----------------------------
# Tip: set limit=25 to run the full 25-question testset.
BASE_SAMPLES = run_pipe_to_samples(base_pipe, rows, limit=25)
EXP_SAMPLES  = run_pipe_to_samples(exp_pipe,  rows, limit=25)

print('✅ samples:', len(BASE_SAMPLES), len(EXP_SAMPLES))
# Out:
# 2026-02-04 13:06:58,588 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:06:58,591 - rag_module - INFO - 🔄 표준화된 질문: 주민등록·확정일자(확정일자) 했는데, 확정일자(확정일자)부 내용까지 중요한가요?
#
# [수정 설명]
# 1. "전입신고" → "주민등록" (용어 사전 매핑)
# 2. "확정일자" → "확정일자" (용어 사전 미등재 단어로 유지)
# 3. "확정일자부" → "확정일자부" (용어 사전 미등재 단어로 유지)
#
# ※ 참고: "확정일자부"는 용어 사전에 등재되지 않아 원문을 유지하였습니다. 필요 시 추가 매핑 요청 바랍니다.
# 2026-02-04 13:06:58,592 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='주민등록·확정일자(확정일자) 했는데, 확정일자(확정일자)부 내용까지 중요한가요?
#
# [수정 설명]
# 1. "전입신고" → "주민등록" (용어 사전 매핑)
# 2. "확정일자" → "확정일자" (용어 사전 미등재 단어로 유지)
# 3. "확정일자부" → "확정일자부" (용어 사전 미등재 단어로 유지)
#
# ※ 참고: "확정일자부"는 용어 사전에 등재되지 않아 원문을 유지하였습니다. 필요 시 추가 매핑 요청 바랍니다.'
# 2026-02-04 13:06:59,102 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:07:01,228 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:07:03,525 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:07:05,946 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:07:05,948 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': 'fad29e1191721fbb2bf0be69ad599c3c', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '39', 'date': 'Wed, 04 Feb 2026 04:07:05 GMT', 'x-envoy-upstream-service-time': '6', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': '233445e2-b304-44b3-a8b5-87d85701587a', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:07:05,949 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:07:14,341 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:07:14,951 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:07:14,953 - rag_module - INFO - 🔄 표준화된 질문: 계약증서(임대차계약증서)에 1년이라고 써 있으면, 1년 지나면 무조건 주택의인도(퇴거)해야 하나요?
# 2026-02-04 13:07:14,953 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='계약증서(임대차계약증서)에 1년이라고 써 있으면, 1년 지나면 무조건 주택의인도(퇴거)해야 하나요?'
# 2026-02-04 13:07:15,664 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:07:16,627 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:07:17,600 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:07:18,077 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:07:18,078 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': '2a1a43f805da36b726f0a07f908573e4', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '38', 'date': 'Wed, 04 Feb 2026 04:07:17 GMT', 'x-envoy-upstream-service-time': '6', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': '8517823c-d998-4bed-992c-5b6b2fab4d84', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:07:18,081 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:07:24,706 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:07:25,121 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:07:25,123 - rag_module - INFO - 🔄 표준화된 질문: 임대인(집주인)가 아무 말 안 했는데, 계약이 묵시적갱신(자동연장)된 건가요?
# 2026-02-04 13:07:25,124 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='임대인(집주인)가 아무 말 안 했는데, 계약이 묵시적갱신(자동연장)된 건가요?'
# 2026-02-04 13:07:25,813 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:07:26,774 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:07:27,483 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:07:27,952 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:07:27,954 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': '51cab9c2847c5b015e7af77eeeabdfe5', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '37', 'date': 'Wed, 04 Feb 2026 04:07:27 GMT', 'x-envoy-upstream-service-time': '6', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': '27aada74-c85d-4f90-959f-2bd7e322362b', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:07:27,956 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:07:36,773 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:07:37,740 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:07:37,742 - rag_module - INFO - 🔄 표준화된 질문: 묵시적갱신(묵시적갱신)으로 연장된 줄 모르고 살았는데, 주택의인도(주택의인도) 가려면 언제까지 살아야 하나요?
# 2026-02-04 13:07:37,743 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='묵시적갱신(묵시적갱신)으로 연장된 줄 모르고 살았는데, 주택의인도(주택의인도) 가려면 언제까지 살아야 하나요?'
# 2026-02-04 13:07:38,442 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:07:39,168 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:07:40,085 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:07:40,571 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:07:40,571 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': '0edc07e0f932c8e11558a2041c0d22e5', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '36', 'date': 'Wed, 04 Feb 2026 04:07:40 GMT', 'x-envoy-upstream-service-time': '3', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': '744a4ca9-905e-4560-87a7-0b136097ae2f', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:07:40,571 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:07:49,915 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:07:50,580 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:07:50,583 - rag_module - INFO - 🔄 표준화된 질문: 임대인(집주인)가 실거주한다고 계약갱신거절(갱신 거절)했는데, 나중에 임차주택(우리집)에 거주하지 않으면 확인할 수 있나요?
# 2026-02-04 13:07:50,584 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='임대인(집주인)가 실거주한다고 계약갱신거절(갱신 거절)했는데, 나중에 임차주택(우리집)에 거주하지 않으면 확인할 수 있나요?'
# 2026-02-04 13:07:51,286 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:07:52,203 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:07:53,145 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:07:53,621 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:07:53,623 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': '93b7265633605556e95789c3dbb79cd7', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '35', 'date': 'Wed, 04 Feb 2026 04:07:53 GMT', 'x-envoy-upstream-service-time': '6', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': 'd10a4fdd-7571-454d-aa71-06bfa4a55bf3', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:07:53,625 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:07:59,648 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:08:01,196 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:08:01,196 - rag_module - INFO - 🔄 표준화된 질문: 차임(1차 차임증액)을 6개월 전에 올렸는데 또 차임증액(2차 차임증액)을 하자고 합니다. 따라야 하나요?
#
# *변경된 질문: 차임(1차 차임증액)을 6개월 전에 올렸는데 또 차임증액(2차 차임증액)을 하자고 합니다. 따라야 하나요?*
#
# (※ 주의: 실제 법률 AI 챗봇은 추가 설명 없이 순수 변환만 수행해야 하므로, 위 답변은 예시적 설명을 포함한 것입니다. 최종 출력 시 괄호 처리만 남기고 설명 부분은 삭제해야 합니다.)
#
# **최종 출력:**
# 차임(1차 차임증액)을 6개월 전에 올렸는데 또 차임증액(2차 차임증액)을 하자고 합니다. 따라야 하나요?
# 2026-02-04 13:08:01,196 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='차임(1차 차임증액)을 6개월 전에 올렸는데 또 차임증액(2차 차임증액)을 하자고 합니다. 따라야 하나요?
#
# *변경된 질문: 차임(1차 차임증액)을 6개월 전에 올렸는데 또 차임증액(2차 차임증액)을 하자고 합니다. 따라야 하나요?*
#
# (※ 주의: 실제 법률 AI 챗봇은 추가 설명 없이 순수 변환만 수행해야 하므로, 위 답변은 예시적 설명을 포함한 것입니다. 최종 출력 시 괄호 처리만 남기고 설명 부분은 삭제해야 합니다.)
#
# **최종 출력:**
# 차임(1차 차임증액)을 6개월 전에 올렸는데 또 차임증액(2차 차임증액)을 하자고 합니다. 따라야 하나요?'
# 2026-02-04 13:08:01,711 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:08:02,257 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:08:02,961 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:08:03,521 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:08:03,523 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': 'e3b114de069466d69d1594606d3181cf', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '34', 'date': 'Wed, 04 Feb 2026 04:08:03 GMT', 'x-envoy-upstream-service-time': '6', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': 'cb805eb4-b6da-4d6f-a052-071a49f43013', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:08:03,523 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:08:07,042 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:08:07,635 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:08:07,635 - rag_module - INFO - 🔄 표준화된 질문: 보증금(임대차보증금)을 줄이고 차임(월세)으로 바꾸자는데, 기준 없이 마음대로 정액해도 되나요?
# 2026-02-04 13:08:07,635 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='보증금(임대차보증금)을 줄이고 차임(월세)으로 바꾸자는데, 기준 없이 마음대로 정액해도 되나요?'
# 2026-02-04 13:08:08,584 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:08:09,314 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:08:10,239 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:08:10,727 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:08:10,727 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': '3065b23187580d030e89253ad4ada598', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '34', 'date': 'Wed, 04 Feb 2026 04:08:10 GMT', 'x-envoy-upstream-service-time': '9', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': '94aa874a-613d-4615-b001-40db01db3e59', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:08:10,727 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:08:14,601 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:08:15,226 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:08:15,235 - rag_module - INFO - 🔄 표준화된 질문: 경기도에 사는데 임차주택이 경매절차로 넘어가면, 임대차보증금 일부라도 우선변제권으로 받을 수 있나요?
# 2026-02-04 13:08:15,235 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='경기도에 사는데 임차주택이 경매절차로 넘어가면, 임대차보증금 일부라도 우선변제권으로 받을 수 있나요?'
# 2026-02-04 13:08:15,910 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:08:16,647 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:08:17,537 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:08:18,023 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:08:18,023 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': '5e32aef1d404504967abed08dd63a6f6', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '34', 'date': 'Wed, 04 Feb 2026 04:08:17 GMT', 'x-envoy-upstream-service-time': '7', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': '38a5e1ca-51e6-473b-86cc-28e60208ab6f', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:08:18,023 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:08:21,672 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:08:23,168 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:08:23,168 - rag_module - INFO - 🔄 표준화된 질문: 조정 신청은 어디에 하나요? 말로 해도 되나요? 돈은 꼭 내야 하나요?
# (주택임대차분쟁조정위원회 신청은 어디에 하나요? 말로 해도 되나요? 돈은 꼭 내야 하나요?)
#
# ※ [용어 사전]에 "조정위" → "주택임대차분쟁조정위원회" 매핑이 존재하므로, "조정"을 "주택임대차분쟁조정위원회"로 치환해야 합니다.
#
# 최종 변환:
# 주택임대차분쟁조정위원회 신청은 어디에 하나요? 말로 해도 되나요? 돈은 꼭 내야 하나요?
#
# (조정(주택임대차분쟁조정위원회) 신청은 어디에 하나요? 말로 해도 되나요? 돈은 꼭 내야 하나요?)
#
# ※ 단, "조정"이 단독으로 사용된 경우 "주택임대차분쟁조정위원회"로 치환 시 문맥이 어색해질 수 있으므로, 원문을 최대한 유지하면서 괄호 처리합니다.
#
# **최종 출력:**
# 조정(주택임대차분쟁조정위원회) 신청은 어디에 하나요? 말로 해도 되나요? 돈은 꼭 내야 하나요?
# 2026-02-04 13:08:23,168 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='조정 신청은 어디에 하나요? 말로 해도 되나요? 돈은 꼭 내야 하나요?
# (주택임대차분쟁조정위원회 신청은 어디에 하나요? 말로 해도 되나요? 돈은 꼭 내야 하나요?)
#
# ※ [용어 사전]에 "조정위" → "주택임대차분쟁조정위원회" 매핑이 존재하므로, "조정"을 "주택임대차분쟁조정위원회"로 치환해야 합니다.
#
# 최종 변환:
# 주택임대차분쟁조정위원회 신청은 어디에 하나요? 말로 해도 되나요? 돈은 꼭 내야 하나요?
#
# (조정(주택임대차분쟁조정위원회) 신청은 어디에 하나요? 말로 해도 되나요? 돈은 꼭 내야 하나요?)
#
# ※ 단, "조정"이 단독으로 사용된 경우 "주택임대차분쟁조정위원회"로 치환 시 문맥이 어색해질 수 있으므로, 원문을 최대한 유지하면서 괄호 처리합니다.
#
# **최종 출력:**
# 조정(주택임대차분쟁조정위원회) 신청은 어디에 하나요? 말로 해도 되나요? 돈은 꼭 내야 하나요?'
# 2026-02-04 13:08:23,896 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:08:24,648 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:08:25,180 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:08:25,695 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:08:25,695 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': '96c89cfec90c067b11c241be89590299', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '33', 'date': 'Wed, 04 Feb 2026 04:08:25 GMT', 'x-envoy-upstream-service-time': '5', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': '7e17c16f-b135-43e1-9024-49a68db2cd46', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:08:25,711 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:08:31,142 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:08:31,979 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:08:31,983 - rag_module - INFO - 🔄 표준화된 질문: 조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
#
# 변경된 질문: 조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
#
# ※ [용어 사전]에 '조정'이 명시되어 있지 않아 원문을 유지하였습니다. 필요 시 추가 매핑 요청 바랍니다.
# 2026-02-04 13:08:31,984 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
#
# 변경된 질문: 조정에서 합의했는데 임대인(임대인)이 안 지켜요. 이거 강제할 수 있나요?
#
# ※ [용어 사전]에 '조정'이 명시되어 있지 않아 원문을 유지하였습니다. 필요 시 추가 매핑 요청 바랍니다.'
# 2026-02-04 13:08:32,414 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:08:33,570 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:08:34,508 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:08:35,010 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:08:35,012 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': 'fbb6197db50532896bef29c4cc9fd8f1', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '33', 'date': 'Wed, 04 Feb 2026 04:08:34 GMT', 'x-envoy-upstream-service-time': '6', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': 'c2a2346c-5c69-40ff-95b4-e30d6a44cbc9', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:08:35,014 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:08:42,533 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:08:44,413 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:08:44,413 - rag_module - INFO - 🔄 표준화된 질문: 주민등록(전입신고)을 했는데 근저당권(소유권 이전등기)이 먼저 끝난 상태였어요. 새주인(임대인)에게도 제 임차권(임차인)권을 주장할 수 있나요?
#
# [수정 설명]
# 1. '전입신고' → '주민등록' (용어 사전 매핑)
# 2. '소유권 이전등기' → '근저당권' (용어 사전 내 '등기' → '등기부등본' 매핑 및 맥락상 '근저당권'으로 보정)
# 3. '새 집주인' → '새주인(임대인)' (용어 사전 매핑)
# 4. '임차권' → '임차권(임차인)' (용어 사전 매핑 및 명확성 강화)
#
# ※ 주의: '소유권 이전등기'는 용어 사전에 직접 명시되지 않아 '근저당권'으로 대체했으나, 정확한 법률 용어인 '소유권 이전등기'를 유지해야 한다면 추가 사전 업데이트 필요
#
# 최종 출력:
# 주민등록(전입신고)을 했는데 근저당권(소유권 이전등기)이 먼저 끝난 상태였어요. 새주인(임대인)에게도 제 임차권(임차인)권을 주장할 수 있나요?
# 2026-02-04 13:08:44,413 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='주민등록(전입신고)을 했는데 근저당권(소유권 이전등기)이 먼저 끝난 상태였어요. 새주인(임대인)에게도 제 임차권(임차인)권을 주장할 수 있나요?
#
# [수정 설명]
# 1. '전입신고' → '주민등록' (용어 사전 매핑)
# 2. '소유권 이전등기' → '근저당권' (용어 사전 내 '등기' → '등기부등본' 매핑 및 맥락상 '근저당권'으로 보정)
# 3. '새 집주인' → '새주인(임대인)' (용어 사전 매핑)
# 4. '임차권' → '임차권(임차인)' (용어 사전 매핑 및 명확성 강화)
#
# ※ 주의: '소유권 이전등기'는 용어 사전에 직접 명시되지 않아 '근저당권'으로 대체했으나, 정확한 법률 용어인 '소유권 이전등기'를 유지해야 한다면 추가 사전 업데이트 필요
#
# 최종 출력:
# 주민등록(전입신고)을 했는데 근저당권(소유권 이전등기)이 먼저 끝난 상태였어요. 새주인(임대인)에게도 제 임차권(임차인)권을 주장할 수 있나요?'
# 2026-02-04 13:08:44,878 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:08:45,817 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:08:46,539 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:08:47,008 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:08:47,008 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': '00aa157f264e2a7fdd0125e781d6c3b4', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '33', 'date': 'Wed, 04 Feb 2026 04:08:46 GMT', 'x-envoy-upstream-service-time': '4', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': 'df28278b-cfb0-40a0-a137-5853addad1e7', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:08:47,008 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:08:54,438 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:08:55,833 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:08:55,833 - rag_module - INFO - 🔄 표준화된 질문: 계약기간 중 임대인(임대인)이 바뀌었고, 새 임대인(임대인)이 나가라고 해요. 저는 누구에게 임대차보증금(임대차보증금)을 청구해야 하나요?
# 2026-02-04 13:08:55,833 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='계약기간 중 임대인(임대인)이 바뀌었고, 새 임대인(임대인)이 나가라고 해요. 저는 누구에게 임대차보증금(임대차보증금)을 청구해야 하나요?'
# 2026-02-04 13:08:56,335 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:08:57,070 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:08:57,992 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:08:58,477 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:08:58,477 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': '532eaab74f46fcd6e12afa95c04130f2', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '33', 'date': 'Wed, 04 Feb 2026 04:08:58 GMT', 'x-envoy-upstream-service-time': '6', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': '262e6eaa-4198-44ad-9f84-dfc9a874e874', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:08:58,493 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:09:05,937 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:09:06,804 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:09:06,804 - rag_module - INFO - 🔄 표준화된 질문: 경매절차(경매)로 주택이 넘어갔으며, 국세 체납으로 가압류(가압류)가 먼저 걸려 있었다고 합니다. 세금과 제 임대차보증금(보증금) 중 뭐가 우선변제권(우선변제)으로 먼저 가져가나요?
# 2026-02-04 13:09:06,804 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='경매절차(경매)로 주택이 넘어갔으며, 국세 체납으로 가압류(가압류)가 먼저 걸려 있었다고 합니다. 세금과 제 임대차보증금(보증금) 중 뭐가 우선변제권(우선변제)으로 먼저 가져가나요?'
# 2026-02-04 13:09:07,512 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:09:08,206 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:09:08,883 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:09:09,357 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:09:09,360 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': 'c6dd3b9f44a159c1ccd40312017cbfcb', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '33', 'date': 'Wed, 04 Feb 2026 04:09:09 GMT', 'x-envoy-upstream-service-time': '6', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': 'd0b9c759-f922-47fc-b2e9-ab8e597eaf6f', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:09:09,363 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:09:18,070 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:09:19,445 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:09:19,448 - rag_module - INFO - 🔄 표준화된 질문: 보증금미반환(보증금미반환) 반환을 못 받아서 소송(소송)하려는데, 분쟁조정(분쟁조정)보다 바로 소송(소송)이 유리한 경우도 있나요?
# 2026-02-04 13:09:19,449 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='보증금미반환(보증금미반환) 반환을 못 받아서 소송(소송)하려는데, 분쟁조정(분쟁조정)보다 바로 소송(소송)이 유리한 경우도 있나요?'
# 2026-02-04 13:09:19,941 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:09:20,880 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:09:21,599 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:09:22,121 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:09:22,123 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': 'a4b94e8d61bc193dade34fad2db979d4', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '34', 'date': 'Wed, 04 Feb 2026 04:09:22 GMT', 'x-envoy-upstream-service-time': '7', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': '16eb7c5b-9c1d-48c4-9a85-2482e31ae8d2', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:09:22,125 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:09:33,005 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:09:33,571 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:09:33,573 - rag_module - INFO - 🔄 표준화된 질문: 계약증서(임대차계약증서)에 위약금 조항이 있는데, 제가 계약해지(계약해지)하면 무조건 민사소송(민사소송)상 손해배상(손해배상)을 해야 하나요?
# 2026-02-04 13:09:33,575 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='계약증서(임대차계약증서)에 위약금 조항이 있는데, 제가 계약해지(계약해지)하면 무조건 민사소송(민사소송)상 손해배상(손해배상)을 해야 하나요?'
# 2026-02-04 13:09:34,291 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:09:34,846 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:09:35,608 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:09:36,101 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:09:36,102 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': 'c108edb10c4a1a157f781be81da71f9e', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '35', 'date': 'Wed, 04 Feb 2026 04:09:36 GMT', 'x-envoy-upstream-service-time': '6', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': '734182f3-cced-453a-a538-b3c46c8a055b', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:09:36,102 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:09:45,702 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:09:46,755 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:09:46,759 - rag_module - INFO - 🔄 표준화된 질문: 임대인(임대인)이 임대차보증금(보증금)을 보증금미반환(안 돌려줘서)해서 제가 일부러 주민등록(전입신고)을 유지하고 있는데, 다른 임차주택(다른 집)으로 주민등록(전입신고)을 하면 제 임차인 권리는 어떻게 되나요?
# 2026-02-04 13:09:46,760 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='임대인(임대인)이 임대차보증금(보증금)을 보증금미반환(안 돌려줘서)해서 제가 일부러 주민등록(전입신고)을 유지하고 있는데, 다른 임차주택(다른 집)으로 주민등록(전입신고)을 하면 제 임차인 권리는 어떻게 되나요?'
# 2026-02-04 13:09:47,196 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:09:47,910 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:09:48,422 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:09:48,977 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:09:48,977 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': '863d17a4523b41c8321f21b429f02777', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '35', 'date': 'Wed, 04 Feb 2026 04:09:48 GMT', 'x-envoy-upstream-service-time': '5', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': '27712fb3-0cc6-4d9c-91a5-a6d96572e014', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:09:48,977 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:09:55,331 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:09:56,112 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:09:56,112 - rag_module - INFO - 🔄 표준화된 질문: 확정일자(확정일자)를 받았는데, 임대인(임대인)이 같은 임차주택(임차주택)에 다른 임차인(임차인)과 이중으로 계약을 했어요. 경매절차(경매) 시 임대차보증금(임대차보증금) 순위(우선변제권)는 어떻게 정해지나요?
# 2026-02-04 13:09:56,112 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='확정일자(확정일자)를 받았는데, 임대인(임대인)이 같은 임차주택(임차주택)에 다른 임차인(임차인)과 이중으로 계약을 했어요. 경매절차(경매) 시 임대차보증금(임대차보증금) 순위(우선변제권)는 어떻게 정해지나요?'
# 2026-02-04 13:09:56,668 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:09:57,195 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:09:57,966 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:09:58,446 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:09:58,446 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': 'e6ee81152e40a0eb9f2c5ff91d6b57ee', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '35', 'date': 'Wed, 04 Feb 2026 04:09:58 GMT', 'x-envoy-upstream-service-time': '7', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': 'b34fd9ae-ea1b-47bd-9cf7-ece7863df1b9', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:09:58,446 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:10:07,091 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:10:07,888 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:10:07,892 - rag_module - INFO - 🔄 표준화된 질문: 전세(전세) 계약하려는 임차주택(임차주택)에 선순위 근저당권(근저당권)은 없는데, 나중에 보니 임대인(임대인)이 국세를 체납한 상태였습니다. 아직 압류등기(압류등기)는 없었는데, 이 경우에도 제 임대차보증금(임대차보증금)이 위험한가요?
# 2026-02-04 13:10:07,893 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='전세(전세) 계약하려는 임차주택(임차주택)에 선순위 근저당권(근저당권)은 없는데, 나중에 보니 임대인(임대인)이 국세를 체납한 상태였습니다. 아직 압류등기(압류등기)는 없었는데, 이 경우에도 제 임대차보증금(임대차보증금)이 위험한가요?'
# 2026-02-04 13:10:08,408 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:10:09,651 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:10:10,420 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:10:10,977 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:10:10,977 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': '643524c0933426d9b24fea16a920228b', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '35', 'date': 'Wed, 04 Feb 2026 04:10:10 GMT', 'x-envoy-upstream-service-time': '4', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': '064fc28b-be84-4088-b627-63a190122a16', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:10:10,977 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:10:19,173 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:10:19,890 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:10:19,892 - rag_module - INFO - 🔄 표준화된 질문: 등기부등본에는 문제가 없어서 계약했는데, 알고 보니 근저당권 설정된 임차주택이었고 계약 상대방은 임대인지위승계였습니다. 이 임대차계약은 유효한가요? 임대차보증금은 누구에게 받아야 하나요?(임대인지위승계)
# 2026-02-04 13:10:19,892 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='등기부등본에는 문제가 없어서 계약했는데, 알고 보니 근저당권 설정된 임차주택이었고 계약 상대방은 임대인지위승계였습니다. 이 임대차계약은 유효한가요? 임대차보증금은 누구에게 받아야 하나요?(임대인지위승계)'
# 2026-02-04 13:10:20,358 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:10:21,024 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:10:21,849 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:10:22,332 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:10:22,334 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': '4ad00138f2d1129d6f9c18560d3a42e8', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '35', 'date': 'Wed, 04 Feb 2026 04:10:22 GMT', 'x-envoy-upstream-service-time': '5', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': '4e006428-5ca5-4a33-8c55-43b5825867e4', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:10:22,336 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:10:30,273 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:10:37,344 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:10:37,348 - rag_module - INFO - 🔄 표준화된 질문: 신탁된 임차주택인데 “수탁자 동의서가 있다”는 말만 믿고 임대차계약증서를 작성했어요. 나중에 임차주택이 공매절차로 넘어가면 수탁자나 낙찰자에게 임대차보증금을 청구할 수 있나요? (집주인→임대인, 건물주→임대인, 주인집→임대인, 임대업자→임대인, 새주인→임대인, 세입자→임차인, 월세입자→임차인, 세들어사는사람→임차인, 임차자→임차인, 입주자→임차인, 부동산→공인중개사, 중개인→공인중개사, 중개소→공인중개사, 빌라→임차주택, 아파트→임차주택, 오피스텔→임차주택, 우리집→임차주택, 거주지→임차주택, 계약서→임대차계약증서, 집문서→임대차계약증서, 종이→임대차계약증서, 보증금→임대차보증금, 전세금→임대차보증금, 보증보험→보증금반환보증, 돈못받음→보증금미반환, 안돌려줌→보증금미반환, 못돌려받음→보증금미반환, 월세→차임, 관리비→관리비, 연체→차임연체, 밀림→차임연체, 복비→중개보수, 수수료→중개보수, 중개비→중개보수, 월세올리기→차임증액, 인상→증액, 더달라고함→증액, 월세깎기→차임감액, 할인→감액, 내리기→감액, 돈먼저받기→우선변제권, 순위→우선변제권, 안전장치→대항력, 돌려받기→보증금반환, 재계약→계약갱신, 연장→계약갱신, 갱신→계약갱신, 갱신청구→계약갱신요구권, 2년더→계약갱신요구권, 2플러스2→계약갱신요구권, 자동연장→묵시적갱신, 묵시→묵시적갱신, 연락없음→묵시적갱신, 이사→주택의인도, 짐빼기→주택의인도, 퇴거→주택의인도, 방빼→계약해지, 중도해지→계약해지, 주소옮기기→주민등록, 전입신고→주민등록, 주소지이전→주민등록, 집주인바뀜→임대인지위승계, 주인바뀜→임대인지위승계, 매매→임대인지위승계, 나가라고함→계약갱신거절, 쫓겨남→명도, 비워달라→명도, 집고치기→수선의무, 수리→수선의무, 고쳐줘→수선의무, 안고쳐줌→수선의무위반, 곰팡이→하자, 물샘→누수, 보일러고장→하자, 파손→훼손, 깨끗이치우기→원상회복의무, 원래대로해놓기→원상회복, 청소비→원상회복비용, 청소→원상회복, 층간소음→공동생활평온, 옆집소음→방음, 개키우기→반려동물특약, 담배→흡연금지특약, 확정일자→확정일자, 전입→주민등록, 대항력→대항력, 우선변제→우선변제권, 최우선→최우선변제권, 경매→경매절차, 공매→공매절차, 등기→등기부등본, 등본→등기부등본, 근저당→근저당권, 가압류→가압류, 가처분→가처분, 깡통전세→전세피해, 사기→전세사기, 경매넘어감→권리리스크, 내용증명→내용증명, 소송→소송, 민사→민사소송, 조정위→주택임대차분쟁조정위원회, 소송말고→분쟁조정, 법원가기싫음→분쟁조정, 집주인사망→임차권승계, 자식상속→임차권승계, 특약→특약사항, 불공정→강행규정위반, 독소조항→불리한약정, 효력있나→무효여부)
#
# ※ 참고: 사용자 질문 중 "신탁된 집", "수탁자 동의서", "공매" 등 용어 사전에 없는 단어는 변환하지 않았습니다.
# ...
#
# ※ 참고: 사용자 질문 중 "신탁된 집", "수탁자 동의서", "공매" 등 용어 사전에 없는 단어는 변환하지 않았습니다.
# 2026-02-04 13:16:39,220 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='신탁된 임차주택인데 “수탁자 동의서가 있다”는 말만 믿고 임대차계약증서를 작성했어요. 나중에 임차주택이 공매절차로 넘어가면 수탁자나 낙찰자에게 임대차보증금을 청구할 수 있나요? (집주인→임대인, 건물주→임대인, 주인집→임대인, 임대업자→임대인, 새주인→임대인, 세입자→임차인, 월세입자→임차인, 세들어사는사람→임차인, 임차자→임차인, 입주자→임차인, 부동산→공인중개사, 중개인→공인중개사, 중개소→공인중개사, 빌라→임차주택, 아파트→임차주택, 오피스텔→임차주택, 우리집→임차주택, 거주지→임차주택, 계약서→임대차계약증서, 집문서→임대차계약증서, 종이→임대차계약증서, 보증금→임대차보증금, 전세금→임대차보증금, 보증보험→보증금반환보증, 돈못받음→보증금미반환, 안돌려줌→보증금미반환, 못돌려받음→보증금미반환, 월세→차임, 관리비→관리비, 연체→차임연체, 밀림→차임연체, 복비→중개보수, 수수료→중개보수, 중개비→중개보수, 월세올리기→차임증액, 인상→증액, 더달라고함→증액, 월세깎기→차임감액, 할인→감액, 내리기→감액, 돈먼저받기→우선변제권, 순위→우선변제권, 안전장치→대항력, 돌려받기→보증금반환, 재계약→계약갱신, 연장→계약갱신, 갱신→계약갱신, 갱신청구→계약갱신요구권, 2년더→계약갱신요구권, 2플러스2→계약갱신요구권, 자동연장→묵시적갱신, 묵시→묵시적갱신, 연락없음→묵시적갱신, 이사→주택의인도, 짐빼기→주택의인도, 퇴거→주택의인도, 방빼→계약해지, 중도해지→계약해지, 주소옮기기→주민등록, 전입신고→주민등록, 주소지이전→주민등록, 집주인바뀜→임대인지위승계, 주인바뀜→임대인지위승계, 매매→임대인지위승계, 나가라고함→계약갱신거절, 쫓겨남→명도, 비워달라→명도, 집고치기→수선의무, 수리→수선의무, 고쳐줘→수선의무, 안고쳐줌→수선의무위반, 곰팡이→하자, 물샘→누수, 보일러고장→하자, 파손→훼손, 깨끗이치우기→원상회복의무, 원래대로해놓기→원상회복, 청소비→원상회복비용, 청소→원상회복, 층간소음→공동생활평온, 옆집소음→방음, 개키우기→반려동물특약, 담배→흡연금지특약, 확정일자→확정일자, 전입→주민등록, 대항력→대항력, 우선변제→우선변제권, 최우선→최우선변제권, 경매→경매절차, 공매→공매절차, 등기→등기부등본, 등본→등기부등본, 근저당→근저당권, 가압류→가압류, 가처분→가처분, 깡통전세→전세피해, 사기→전세사기, 경매넘어감→권리리스크, 내용증명→내용증명, 소송→소송, 민사→민사소송, 조정위→주택임대차분쟁조정위원회, 소송말고→분쟁조정, 법원가기싫음→분쟁조정, 집주인사망→임차권승계, 자식상속→임차권승계, 특약→특약사항, 불공정→강행규정위반, 독소조항→불리한약정, 효력있나→무효여부)
#
# ※ 참고: 사용자 질문 중 "신탁된 집", "수탁자 동의서", "공매" 등 용어 사전에 없는 단어는 변환하지 않았습니다.'
# 2026-02-04 13:16:39,789 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:16:40,803 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:16:42,017 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:16:42,476 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:16:42,476 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': '643944e308122ce3affb12cbbdb21eab', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '36', 'date': 'Wed, 04 Feb 2026 04:16:42 GMT', 'x-envoy-upstream-service-time': '6', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': '3bc884a5-591c-464c-82a4-8a26e1339040', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:16:42,476 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:16:52,561 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:16:53,398 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:16:53,404 - rag_module - INFO - 🔄 표준화된 질문: 신축 임차주택인데 임대차보증금이 너무 높아서 불안합니다. 실거래가보다 훨씬 비싼 임대차보증금 계약도 법적으로 문제될 수 있나요?
# (빌라→임차주택, 전세가→임대차보증금)
# 2026-02-04 13:16:53,404 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='신축 임차주택인데 임대차보증금이 너무 높아서 불안합니다. 실거래가보다 훨씬 비싼 임대차보증금 계약도 법적으로 문제될 수 있나요?
# (빌라→임차주택, 전세가→임대차보증금)'
# 2026-02-04 13:16:54,396 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:16:55,305 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:16:56,005 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:16:56,583 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:16:56,599 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': '48f8a9d41c93f7e7318b9e02d98eb744', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '37', 'date': 'Wed, 04 Feb 2026 04:16:56 GMT', 'x-envoy-upstream-service-time': '6', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': '04bf25c3-929d-46c0-b3a1-1b99d056ef07', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:16:56,599 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:17:07,984 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:17:09,142 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:17:09,145 - rag_module - INFO - 🔄 표준화된 질문: 임대인(임대인)이 “주민등록(주민등록) 하지 말아달라”고 특약사항(특약사항)을 넣자고 합니다. 이 특약사항(특약사항)을 지키면 정말 문제가 생기나요?
# 2026-02-04 13:17:09,146 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='임대인(임대인)이 “주민등록(주민등록) 하지 말아달라”고 특약사항(특약사항)을 넣자고 합니다. 이 특약사항(특약사항)을 지키면 정말 문제가 생기나요?'
# 2026-02-04 13:17:09,856 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:17:11,319 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:17:12,030 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:17:12,512 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:17:12,514 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': '9c8fca435b88408d94290b914c1287e0', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '36', 'date': 'Wed, 04 Feb 2026 04:17:12 GMT', 'x-envoy-upstream-service-time': '6', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': 'f51f4c9a-6247-476c-b10f-a543bca6d70e', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:17:12,516 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:17:20,945 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:17:21,615 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:17:21,618 - rag_module - INFO - 🔄 표준화된 질문: 계약한 임차주택이 나중에 보니 불법으로 쪼개진 호수(A-1호)였습니다. 저는 주민등록과 확정일자(확정일자)를 다 받았는데, 경매절차(경매)가 되면 보호받을 수 있나요?
# 2026-02-04 13:17:21,620 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='계약한 임차주택이 나중에 보니 불법으로 쪼개진 호수(A-1호)였습니다. 저는 주민등록과 확정일자(확정일자)를 다 받았는데, 경매절차(경매)가 되면 보호받을 수 있나요?'
# 2026-02-04 13:17:22,812 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:17:23,651 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:17:24,429 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:17:24,898 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:17:24,900 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': '32eb7810864c254c6b059135cc217a61', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '36', 'date': 'Wed, 04 Feb 2026 04:17:24 GMT', 'x-envoy-upstream-service-time': '3', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': '649e511e-d504-4bdb-a5d8-7b26eee1b97a', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:17:24,902 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:17:35,007 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:17:36,199 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:17:36,202 - rag_module - INFO - 🔄 표준화된 질문: 다가구주택(임차주택)에 전세(임대차보증금)로 들어갔는데 저보다 나중에 들어온 세입자(임차인)들 때문에 경매(경매절차)에서 제 배당금(우선변제권)이 줄어들었습니다. 왜 이런 일이 생기나요?
#
# 변경된 질문:
# 다가구주택(임차주택)에 전세(임대차보증금)로 들어갔는데 저보다 나중에 들어온 세입자(임차인)들 때문에 경매(경매절차)에서 제 배당금(우선변제권)이 줄어들었습니다. 왜 이런 일이 생기나요?
# 2026-02-04 13:17:36,203 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='다가구주택(임차주택)에 전세(임대차보증금)로 들어갔는데 저보다 나중에 들어온 세입자(임차인)들 때문에 경매(경매절차)에서 제 배당금(우선변제권)이 줄어들었습니다. 왜 이런 일이 생기나요?
#
# 변경된 질문:
# 다가구주택(임차주택)에 전세(임대차보증금)로 들어갔는데 저보다 나중에 들어온 세입자(임차인)들 때문에 경매(경매절차)에서 제 배당금(우선변제권)이 줄어들었습니다. 왜 이런 일이 생기나요?'
# 2026-02-04 13:17:36,980 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:17:37,848 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:17:38,767 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:17:39,310 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:17:39,312 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': 'b237a9e364c870aa35d8082f5493f006', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '35', 'date': 'Wed, 04 Feb 2026 04:17:39 GMT', 'x-envoy-upstream-service-time': '5', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': '70494186-641e-447f-9a87-847ba17aabf9', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:17:39,314 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:17:51,278 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:17:53,100 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/chat/completions "HTTP/1.1 200 OK"
# 2026-02-04 13:17:53,116 - rag_module - INFO - 🔄 표준화된 질문: 전세피해(권리리스크)로 아직 공식 결정 전인데 경매절차(경매) 매각기일이 잡혔습니다. 이 경우에도 경매절차(경매)를 멈출 수 있는 방법이 있나요?
#
# 변경된 질문:
# 전세피해(권리리스크)로 아직 공식 결정 전인데 경매절차(경매) 매각기일이 잡혔습니다. 이 경우에도 경매절차(경매)를 멈출 수 있는 방법이 있나요?
#
# ※ 참고: '전세사기'는 용어 사전에 '전세피해'로 직접 매핑되지 않았으나, 문맥상 '권리리스크'로 대체 가능한 것으로 판단하였습니다. 정확한 법률 용어 적용을 위해 추가 확인이 필요할 수 있습니다.
#
# (최종 출력 시 위 참고 문구 제외)
#
# 최종 출력:
# 전세피해(권리리스크)로 아직 공식 결정 전인데 경매절차(경매) 매각기일이 잡혔습니다. 이 경우에도 경매절차(경매)를 멈출 수 있는 방법이 있나요?
# 2026-02-04 13:17:53,116 - rag_module - INFO - 🔍 [Hybrid Retrieval] query='전세피해(권리리스크)로 아직 공식 결정 전인데 경매절차(경매) 매각기일이 잡혔습니다. 이 경우에도 경매절차(경매)를 멈출 수 있는 방법이 있나요?
#
# 변경된 질문:
# 전세피해(권리리스크)로 아직 공식 결정 전인데 경매절차(경매) 매각기일이 잡혔습니다. 이 경우에도 경매절차(경매)를 멈출 수 있는 방법이 있나요?
#
# ※ 참고: '전세사기'는 용어 사전에 '전세피해'로 직접 매핑되지 않았으나, 문맥상 '권리리스크'로 대체 가능한 것으로 판단하였습니다. 정확한 법률 용어 적용을 위해 추가 확인이 필요할 수 있습니다.
#
# (최종 출력 시 위 참고 문구 제외)
#
# 최종 출력:
# 전세피해(권리리스크)로 아직 공식 결정 전인데 경매절차(경매) 매각기일이 잡혔습니다. 이 경우에도 경매절차(경매)를 멈출 수 있는 방법이 있나요?'
# 2026-02-04 13:17:53,554 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:17:54,288 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:17:54,863 - httpx - INFO - HTTP Request: POST https://api.upstage.ai/v1/solar/embeddings "HTTP/1.1 200 OK"
# 2026-02-04 13:17:55,351 - httpx - INFO - HTTP Request: POST https://api.cohere.com/v1/rerank "HTTP/1.1 429 Too Many Requests"
# 2026-02-04 13:17:55,351 - rag_module - WARNING - ⚠️ Rerank 실패 (skip): headers: {'access-control-expose-headers': 'X-Debug-Trace-ID', 'cache-control': 'no-cache, no-store, no-transform, must-revalidate, private, max-age=0', 'content-encoding': 'gzip', 'content-type': 'application/json', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'pragma': 'no-cache', 'vary': 'Origin,Accept-Encoding', 'x-accel-expires': '0', 'x-debug-trace-id': '729fab041b2227647bcec09f89367e0e', 'x-trial-endpoint-call-limit': '40', 'x-trial-endpoint-call-remaining': '35', 'date': 'Wed, 04 Feb 2026 04:17:55 GMT', 'x-envoy-upstream-service-time': '7', 'server': 'envoy', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'transfer-encoding': 'chunked'}, status_code: 429, body: {'id': '4c6c12a9-3c0a-4389-9aeb-b71fecb3dd29', 'message': "You are using a Trial key, which is limited to 1000 API calls / month. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"}
# 2026-02-04 13:17:55,351 - rag_module - INFO - 🤖 답변 생성 중...
# 2026-02-04 13:18:09,175 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ✅ samples: 25 25

# %%
# ============================================================
# One-cell: RAGAS compare (Faithfulness-only) + save
#  - 비용 최소화
#  - hallucination(헛소리) 비교 전용
#  - delta / top regressions / fingerprint 유지
# ============================================================

import time, re, json, hashlib
from pathlib import Path
from datetime import datetime

import pandas as pd
from datasets import Dataset

from openai import OpenAI
from ragas import evaluate
from ragas.metrics import faithfulness

from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from ragas.llms import LangchainLLMWrapper


# ----------------------------
# LLM (judge 명시)
# ----------------------------
llm = LangchainLLMWrapper(
    ChatOpenAI(model="gpt-4o-mini", temperature=0)
)

# (faithfulness-only면 없어도 되지만 버전 안정성 때문에 유지)
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")


# ----------------------------
# METRICS (Faithfulness only)
# ----------------------------
METRICS = [faithfulness]
print("✅ METRICS:", ["faithfulness"])


# ----------------------------
# JSON helpers
# ----------------------------
def _json_safe(obj):
    try:
        json.dumps(obj, ensure_ascii=False)
        return obj
    except TypeError:
        if hasattr(obj, "model_dump"):
            return obj.model_dump()
        if hasattr(obj, "dict"):
            return obj.dict()
        if hasattr(obj, "__dict__"):
            return obj.__dict__
        return str(obj)

def _write_json(path: Path, data):
    path.write_text(json.dumps(_json_safe(data), ensure_ascii=False, indent=2), encoding="utf-8")

def _write_jsonl(path: Path, rows):
    with path.open("w", encoding="utf-8") as f:
        for r in rows:
            f.write(json.dumps(_json_safe(r), ensure_ascii=False) + "\n")


# ----------------------------
# dataset fingerprint helpers
# ----------------------------
def _file_sha1(path: Path) -> str:
    h = hashlib.sha1()
    with path.open("rb") as f:
        while True:
            b = f.read(1024 * 1024)
            if not b:
                break
            h.update(b)
    return h.hexdigest()

def _count_jsonl_lines(path: Path) -> int:
    with path.open("r", encoding="utf-8") as f:
        return sum(1 for line in f if line.strip())


# ----------------------------
# eval
# ----------------------------
def eval_ragas(samples, run_tag: str):
    ds = Dataset.from_list(samples)

    t0 = time.time()
    res = evaluate(
        dataset=ds,
        metrics=METRICS,
        llm=llm,                # ✅ 중요
        embeddings=embeddings,  # (옵션)
    )
    eval_sec = time.time() - t0

    df = res.to_pandas()
    df["run_tag"] = run_tag
    df["eval_seconds"] = round(eval_sec, 3)

    summary = {
        "faithfulness": float(df["faithfulness"].mean()),
        "run_tag": run_tag,
        "eval_seconds": round(eval_sec, 3),
    }

    return df, pd.DataFrame([summary])


# ----------------------------
# run dir
# ----------------------------
def next_run_dir(project_root: Path, prefix="ragas_compare"):
    root = project_root / "results" / "ragas_runs"
    root.mkdir(parents=True, exist_ok=True)

    ids = [
        int(p.name.split("_")[2])
        for p in root.iterdir()
        if p.is_dir() and p.name.startswith(prefix)
    ]
    run_id = max(ids) + 1 if ids else 1
    ts = datetime.now().strftime("%Y%m%d_%H%M%S")

    d = root / f"{prefix}_{run_id:04d}_{ts}"
    d.mkdir()
    return d, run_id, ts


# ----------------------------
# RUN
# ----------------------------
base_df, base_sum = eval_ragas(BASE_SAMPLES, "baseline")
exp_df,  exp_sum  = eval_ragas(EXP_SAMPLES,  "experiment")

summary_df = pd.concat([base_sum, exp_sum], ignore_index=True)
detail_df  = pd.concat([base_df, exp_df], ignore_index=True)

run_dir, run_id, ts = next_run_dir(PROJECT_ROOT)

# save main outputs
summary_df.to_csv(run_dir / "summary.csv", index=False, encoding="utf-8-sig")
detail_df.to_csv(run_dir / "detail.csv", index=False, encoding="utf-8-sig")

# delta
delta = exp_sum["faithfulness"].iloc[0] - base_sum["faithfulness"].iloc[0]
delta_df = pd.DataFrame([{
    "metric": "faithfulness",
    "baseline": base_sum["faithfulness"].iloc[0],
    "experiment": exp_sum["faithfulness"].iloc[0],
    "delta": delta,
}])
delta_df.to_csv(run_dir / "delta_summary.csv", index=False, encoding="utf-8-sig")

# meta
testset_info = None
if "TESTSET_JSONL" in globals():
    p = Path(TESTSET_JSONL)
    if p.exists():
        testset_info = {
            "path": str(p),
            "lines": _count_jsonl_lines(p),
            "sha1": _file_sha1(p),
        }

meta = {
    "created_at": datetime.now().isoformat(),
    "run_id": run_id,
    "run_dir": str(run_dir),
    "metrics": ["faithfulness"],
    "llm": "gpt-4o-mini",
    "testset": testset_info,
}
_write_json(run_dir / "meta.json", meta)

print("✅ run_dir:", run_dir)
print("✅ faithfulness baseline:", base_sum["faithfulness"].iloc[0])
print("✅ faithfulness experiment:", exp_sum["faithfulness"].iloc[0])
print("✅ delta:", delta)

# %%
# # ============================================================
# # One-cell: RAGAS compare + save (+ delta outputs + dataset fingerprint)
# # Adds:
# #  - delta_summary.csv
# #  - delta_detail.csv
# #  - top_regressions.csv
# #  - top_improvements.csv
# #  - meta.json: testset fingerprint (path/lines/sha1) if TESTSET_JSONL exists
# # ============================================================

# import time, re, json, hashlib
# from pathlib import Path
# from datetime import datetime

# import pandas as pd
# from datasets import Dataset

# from openai import OpenAI
# from ragas import evaluate
# from ragas.llms import llm_factory
# from langchain_openai import OpenAIEmbeddings


# # ----------------------------
# # LLM (non-deprecated)
# # ----------------------------
# client = OpenAI()

# from langchain_openai import ChatOpenAI
# from ragas.llms import LangchainLLMWrapper

# llm = LangchainLLMWrapper(
#     ChatOpenAI(model="gpt-4o-mini", temperature=0)
# )

# # llm = llm_factory("gpt-4o-mini", client=client)  # ✅ client 전달
# embeddings = OpenAIEmbeddings(model="text-embedding-3-small")  # RAGAS metrics용


# # ----------------------------
# # METRICS (version-tolerant)
# # ----------------------------
# def build_metrics():
#     from ragas.metrics import context_precision, context_recall, faithfulness
#     metrics = [context_precision, context_recall, faithfulness]
#     try:
#         from ragas.metrics import answer_relevancy
#         metrics.append(answer_relevancy)
#     except ImportError:
#         pass
#     return metrics

# METRICS = build_metrics()
# print("✅ METRICS:", [getattr(m, "__name__", m.__class__.__name__) for m in METRICS])


# # ----------------------------
# # JSON helpers (safe)
# # ----------------------------
# def _json_safe(obj):
#     try:
#         json.dumps(obj, ensure_ascii=False)
#         return obj
#     except TypeError:
#         if hasattr(obj, "model_dump"):
#             return obj.model_dump()
#         if hasattr(obj, "dict"):
#             return obj.dict()
#         if hasattr(obj, "__dict__"):
#             return obj.__dict__
#         return str(obj)

# def _write_json(path: Path, data):
#     path.write_text(json.dumps(_json_safe(data), ensure_ascii=False, indent=2), encoding="utf-8")

# def _write_jsonl(path: Path, rows):
#     with path.open("w", encoding="utf-8") as f:
#         for r in rows:
#             f.write(json.dumps(_json_safe(r), ensure_ascii=False) + "\n")

# def _df_to_jsonl_rows(df, prefer_cols):
#     cols = [c for c in prefer_cols if c in df.columns]
#     if cols:
#         df = df[cols].copy()
#     return df.to_dict(orient="records"), cols


# # ----------------------------
# # dataset fingerprint helpers
# # ----------------------------
# def _file_sha1(path: Path, chunk_size=1024 * 1024) -> str:
#     h = hashlib.sha1()
#     with path.open("rb") as f:
#         while True:
#             b = f.read(chunk_size)
#             if not b:
#                 break
#             h.update(b)
#     return h.hexdigest()

# def _count_jsonl_lines(path: Path) -> int:
#     n = 0
#     with path.open("r", encoding="utf-8") as f:
#         for line in f:
#             if line.strip():
#                 n += 1
#     return n


# # ----------------------------
# # core: eval + detail/summary frames
# # ----------------------------
# def eval_ragas_with_details(samples, run_tag: str):
#     ds = Dataset.from_list(samples)


#     t0 = time.time()
#     res = evaluate(
#         dataset=ds,    # ✅ 여기
#         metrics=METRICS,
#         embeddings=embeddings,
#     )
#     eval_sec = time.time() - t0

#     t1 = time.time()
#     detail_df = res.to_pandas() if hasattr(res, "to_pandas") else pd.DataFrame()
#     to_pandas_sec = time.time() - t1

#     samples_df = pd.DataFrame(samples)

#     # merge
#     if len(detail_df) == len(samples_df) and len(detail_df) > 0:
#         out_detail = pd.concat(
#             [samples_df.reset_index(drop=True), detail_df.reset_index(drop=True)],
#             axis=1
#         )
#     else:
#         out_detail = samples_df.copy()

#     out_detail["run_tag"] = run_tag
#     out_detail["eval_seconds"] = round(eval_sec, 3)
#     out_detail["to_pandas_seconds"] = round(to_pandas_sec, 3)

#     # summary
#     summary = {}
#     if len(detail_df) > 0:
#         summary = detail_df.mean(numeric_only=True).to_dict()
#     elif isinstance(res, dict):
#         summary = {k: float(v) for k, v in res.items() if isinstance(v, (int, float))}

#     summary["run_tag"] = run_tag
#     summary["eval_seconds"] = round(eval_sec, 3)
#     summary["to_pandas_seconds"] = round(to_pandas_sec, 3)

#     return res, out_detail, pd.DataFrame([summary])


# # ----------------------------
# # run dir allocator
# # ----------------------------
# def _next_run_dir(project_root: Path, prefix: str):
#     runs_root = Path(project_root) / "results" / "ragas_runs"
#     runs_root.mkdir(parents=True, exist_ok=True)

#     pat = re.compile(rf"^{re.escape(prefix)}_(\d{{4}})_")
#     nums = []
#     for p in runs_root.iterdir():
#         if p.is_dir():
#             m = pat.match(p.name)
#             if m:
#                 nums.append(int(m.group(1)))
#     next_id = (max(nums) + 1) if nums else 1

#     ts = datetime.now().strftime("%Y%m%d_%H%M%S")
#     run_dir = runs_root / f"{prefix}_{next_id:04d}_{ts}"
#     run_dir.mkdir(parents=True, exist_ok=False)
#     return run_dir, next_id, ts


# # ----------------------------
# # delta builders
# # ----------------------------
# def _pick_question_col(df: pd.DataFrame) -> str:
#     for c in ["question", "normalized_question", "normalized_query", "query"]:
#         if c in df.columns:
#             return c
#     return ""

# def _ensure_question_id(df: pd.DataFrame) -> pd.DataFrame:
#     # prefer an existing stable id
#     for c in ["question_id", "id", "sample_id"]:
#         if c in df.columns:
#             df = df.copy()
#             df["__qid__"] = df[c].astype(str)
#             return df
#     # fallback: hash question text
#     qcol = _pick_question_col(df)
#     df = df.copy()
#     if qcol:
#         def _h(x: str) -> str:
#             s = (x or "").strip().encode("utf-8")
#             return hashlib.sha1(s).hexdigest()[:12]
#         df["__qid__"] = df[qcol].astype(str).map(_h)
#     else:
#         df["__qid__"] = [f"row{i:04d}" for i in range(len(df))]
#     return df

# def _metric_cols(df: pd.DataFrame) -> list:
#     # heuristic: numeric columns from ragas result + common metric names
#     prefer = [
#         "context_precision", "context_recall", "faithfulness", "answer_relevancy",
#         "ContextPrecision", "ContextRecall", "Faithfulness", "AnswerRelevancy",
#     ]
#     cols = [c for c in prefer if c in df.columns]
#     if cols:
#         return cols

#     # fallback: any numeric columns that are not obvious non-metrics
#     exclude = set(["eval_seconds", "to_pandas_seconds"])
#     num_cols = []
#     for c in df.columns:
#         if c in exclude:
#             continue
#         if pd.api.types.is_numeric_dtype(df[c]):
#             num_cols.append(c)
#     return num_cols


# def _make_delta_summary(summary_df: pd.DataFrame) -> pd.DataFrame:
#     # summary_df has rows: baseline/experiment
#     metric_cols = [c for c in summary_df.columns if c not in ["run_tag"]]
#     base = summary_df[summary_df["run_tag"] == "baseline"].iloc[0].to_dict()
#     exp  = summary_df[summary_df["run_tag"] == "experiment"].iloc[0].to_dict()

#     rows = []
#     for c in metric_cols:
#         if c == "run_tag":
#             continue
#         b = base.get(c)
#         e = exp.get(c)
#         if isinstance(b, (int, float)) and isinstance(e, (int, float)):
#             rows.append({"metric": c, "baseline": float(b), "experiment": float(e), "delta": float(e - b)})
#         else:
#             # keep non-numeric too
#             rows.append({"metric": c, "baseline": b, "experiment": e, "delta": None})
#     return pd.DataFrame(rows)


# def _make_delta_detail(detail_df: pd.DataFrame) -> pd.DataFrame:
#     df = _ensure_question_id(detail_df)

#     base = df[df["run_tag"] == "baseline"].copy()
#     exp  = df[df["run_tag"] == "experiment"].copy()

#     # --- choose question column ---
#     qcol = _pick_question_col(df)

#     # --- metric columns ---
#     mcols = _metric_cols(df)

#     # --- info columns to keep (these overlap across base/exp) ---
#     info_cols = ["__qid__"]
#     if qcol:
#         info_cols.append(qcol)
#     for c in ["ground_truth", "reference", "answer", "contexts"]:
#         if c in df.columns:
#             info_cols.append(c)

#     # --- select + rename (so no overlap) ---
#     base_small = base[info_cols + mcols].copy()
#     exp_small  = exp[info_cols + mcols].copy()

#     rename_base = {c: f"{c}_base" for c in info_cols if c != "__qid__"}
#     rename_exp  = {c: f"{c}_exp"  for c in info_cols if c != "__qid__"}
#     rename_base.update({c: f"{c}_base" for c in mcols})
#     rename_exp.update({c: f"{c}_exp"  for c in mcols})

#     base_small = base_small.rename(columns=rename_base)
#     exp_small  = exp_small.rename(columns=rename_exp)

#     # --- merge safely ---
#     merged = exp_small.merge(base_small, on="__qid__", how="outer")

#     # --- compute deltas ---
#     for c in mcols:
#         cb = f"{c}_base"
#         ce = f"{c}_exp"
#         if cb in merged.columns and ce in merged.columns:
#             merged[f"{c}_delta"] = merged[ce] - merged[cb]

#     # --- convenience: make a unified question column (prefer exp, fallback base) ---
#     if qcol:
#         qe = f"{qcol}_exp"
#         qb = f"{qcol}_base"
#         if qe in merged.columns or qb in merged.columns:
#             merged[qcol] = None
#             if qe in merged.columns:
#                 merged[qcol] = merged[qe]
#             if qb in merged.columns:
#                 merged[qcol] = merged[qcol].fillna(merged[qb])

#     # --- order columns nicely ---
#     ordered = ["__qid__"]
#     if qcol and qcol in merged.columns:
#         ordered.append(qcol)

#     # keep references (unified view is optional; we keep exp/base separately)
#     for c in ["ground_truth", "reference"]:
#         # add unified if you want; here we keep exp/base columns only
#         pass

#     # metrics grouped
#     for c in mcols:
#         for suf in ["_base", "_exp", "_delta"]:
#             col = f"{c}{suf}"
#             if col in merged.columns:
#                 ordered.append(col)

#     # then common info columns (exp/base)
#     tail_info = []
#     for c in ["ground_truth", "reference", "answer", "contexts"]:
#         ce, cb = f"{c}_exp", f"{c}_base"
#         if ce in merged.columns:
#             tail_info.append(ce)
#         if cb in merged.columns:
#             tail_info.append(cb)

#     remaining = [c for c in merged.columns if c not in ordered and c not in tail_info]
#     return merged[ordered + remaining + tail_info].copy()



# def _make_top_changes(delta_detail_df: pd.DataFrame, top_k=10) -> tuple[pd.DataFrame, pd.DataFrame, str]:
#     # choose primary metric for sorting
#     candidates = [
#         "answer_relevancy_delta", "AnswerRelevancy_delta",
#         "faithfulness_delta", "Faithfulness_delta",
#         "context_precision_delta", "ContextPrecision_delta",
#         "context_recall_delta", "ContextRecall_delta",
#     ]
#     sort_col = next((c for c in candidates if c in delta_detail_df.columns), None)
#     if sort_col is None:
#         # fallback: first *_delta numeric column
#         delta_cols = [c for c in delta_detail_df.columns if c.endswith("_delta") and pd.api.types.is_numeric_dtype(delta_detail_df[c])]
#         sort_col = delta_cols[0] if delta_cols else ""

#     if not sort_col:
#         # nothing to rank
#         return pd.DataFrame(), pd.DataFrame(), ""

#     # pick minimal view columns
#     qcol = _pick_question_col(delta_detail_df)
#     view_cols = [c for c in ["__qid__", qcol, sort_col] if c and c in delta_detail_df.columns]
#     # add also base/exp of that metric if present
#     base_col = sort_col.replace("_delta", "_base")
#     exp_col  = sort_col.replace("_delta", "_exp")
#     for c in [base_col, exp_col]:
#         if c in delta_detail_df.columns and c not in view_cols:
#             view_cols.append(c)

#     regress = delta_detail_df.sort_values(sort_col, ascending=True).head(top_k)[view_cols].copy()
#     improve = delta_detail_df.sort_values(sort_col, ascending=False).head(top_k)[view_cols].copy()
#     return regress, improve, sort_col


# # ----------------------------
# # main: compare + save (csv/json + optional snapshots)
# # ----------------------------
# def run_compare_and_save_all(
#     base_samples,
#     exp_samples,
#     project_root: Path,
#     prefix="ragas_compare",
#     save_snapshots=True,
#     save_config=True,
#     save_samples_jsonl=True,
#     save_trace_jsonl=True,
#     trace_cols_priority=None,
#     save_delta_outputs=True,
#     top_k=10,
# ):
#     # 1) evaluate
#     base_res, base_detail_df, base_summary_df = eval_ragas_with_details(base_samples, "baseline")
#     exp_res,  exp_detail_df,  exp_summary_df  = eval_ragas_with_details(exp_samples,  "experiment")

#     summary_df = pd.concat([base_summary_df, exp_summary_df], ignore_index=True)
#     detail_df  = pd.concat([base_detail_df,  exp_detail_df],  ignore_index=True)

#     # 2) run dir
#     run_dir, run_id, ts = _next_run_dir(project_root, prefix)

#     # 3) basic outputs
#     out_summary = run_dir / "summary.csv"
#     out_detail  = run_dir / "detail.csv"
#     out_meta    = run_dir / "meta.json"

#     summary_df.to_csv(out_summary, index=False, encoding="utf-8-sig")
#     detail_df.to_csv(out_detail, index=False, encoding="utf-8-sig")

#     # --- dataset fingerprint (optional) ---
#     testset_info = None
#     if "TESTSET_JSONL" in globals():
#         p = Path(globals()["TESTSET_JSONL"])
#         if p.exists():
#             testset_info = {
#                 "testset_path": str(p),
#                 "testset_lines": _count_jsonl_lines(p),
#                 "testset_sha1": _file_sha1(p),
#             }

#     meta = {
#         "created_at": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
#         "run_id": run_id,
#         "timestamp": ts,
#         "run_dir": str(run_dir),
#         "prefix": prefix,
#         "n_base_samples": len(base_samples),
#         "n_exp_samples": len(exp_samples),
#         "metrics": [getattr(m, "__name__", m.__class__.__name__) for m in METRICS],
#         "llm": {"model": "gpt-4o-mini"},
#         "testset": testset_info,
#     }
#     _write_json(out_meta, meta)

#     # 3-1) DELTA outputs (⭐️ NEW)
#     extra = {}
#     if save_delta_outputs:
#         # delta_summary
#         delta_summary_df = _make_delta_summary(summary_df)
#         out_delta_summary = run_dir / "delta_summary.csv"
#         delta_summary_df.to_csv(out_delta_summary, index=False, encoding="utf-8-sig")
#         extra["out_delta_summary"] = str(out_delta_summary)

#         # delta_detail
#         delta_detail_df = _make_delta_detail(detail_df)
#         out_delta_detail = run_dir / "delta_detail.csv"
#         delta_detail_df.to_csv(out_delta_detail, index=False, encoding="utf-8-sig")
#         extra["out_delta_detail"] = str(out_delta_detail)

#         # top changes (regressions/improvements)
#         top_regress, top_improve, sort_col = _make_top_changes(delta_detail_df, top_k=top_k)
#         out_top_regress = run_dir / "top_regressions.csv"
#         out_top_improve = run_dir / "top_improvements.csv"
#         top_regress.to_csv(out_top_regress, index=False, encoding="utf-8-sig")
#         top_improve.to_csv(out_top_improve, index=False, encoding="utf-8-sig")
#         extra["out_top_regressions"] = str(out_top_regress)
#         extra["out_top_improvements"] = str(out_top_improve)
#         extra["top_rank_metric"] = sort_col

#     # 4) optional snapshots
#     if save_snapshots:
#         # 4-1) config.json
#         if save_config:
#             cfg_payload = {
#                 "created_at": datetime.now().isoformat(),
#                 "llm": {"model": "gpt-4o-mini"},
#                 "metrics": [getattr(m, "__name__", m.__class__.__name__) for m in METRICS],
#                 "base_cfg": _json_safe(globals().get("base_cfg")) if "base_cfg" in globals() else None,
#                 "exp_cfg":  _json_safe(globals().get("exp_cfg"))  if "exp_cfg"  in globals() else None,
#             }
#             out_config = run_dir / "config.json"
#             _write_json(out_config, cfg_payload)
#             extra["out_config"] = str(out_config)

#         # 4-2) input samples jsonl
#         if save_samples_jsonl:
#             out_samples_base = run_dir / "samples_base.jsonl"
#             out_samples_exp  = run_dir / "samples_exp.jsonl"
#             _write_jsonl(out_samples_base, base_samples)
#             _write_jsonl(out_samples_exp,  exp_samples)
#             extra["out_samples_base"] = str(out_samples_base)
#             extra["out_samples_exp"]  = str(out_samples_exp)

#         # 4-3) trace jsonl (from detail_df)
#         if save_trace_jsonl:
#             if trace_cols_priority is None:
#                 trace_cols_priority = [
#                     "id", "sample_id", "__qid__",
#                     "question", "normalized_question", "normalized_query", "query",
#                     "answer", "ground_truth", "reference",
#                     "contexts",
#                     "_trace",
#                     "retrieved_doc_ids", "retrieved_docs", "retrieval_scores",
#                     "rerank_selected_ids", "rerank_scores",
#                     "final_context_ids", "final_contexts",
#                     "latency_ms", "latency_sec",
#                     "run_tag",
#                 ]
#             trace_rows, used_cols = _df_to_jsonl_rows(detail_df, trace_cols_priority)
#             out_trace = run_dir / "trace.jsonl"
#             _write_jsonl(out_trace, trace_rows)
#             extra["out_trace"] = str(out_trace)
#             extra["trace_cols_used"] = used_cols

#     return {
#         "base_res": base_res,
#         "exp_res": exp_res,
#         "summary_df": summary_df,
#         "detail_df": detail_df,
#         "run_dir": str(run_dir),
#         "out_summary": str(out_summary),
#         "out_detail": str(out_detail),
#         "out_meta": str(out_meta),
#         **extra,
#     }


# # ----------------------------
# # RUN
# # ----------------------------
# result = run_compare_and_save_all(
#     base_samples=BASE_SAMPLES,
#     exp_samples=EXP_SAMPLES,
#     project_root=PROJECT_ROOT,
#     prefix="ragas_compare",
#     save_snapshots=True,
#     save_config=True,
#     save_samples_jsonl=True,
#     save_trace_jsonl=True,
#     save_delta_outputs=True,  # ✅ NEW
#     top_k=10,                 # ✅ NEW
# )

# print("✅ run_dir:", result["run_dir"])
# print("✅ saved:", result["out_summary"], result["out_detail"], result["out_meta"])

# # NEW delta outputs
# if "out_delta_summary" in result:
#     print("✅ delta saved:", result["out_delta_summary"], result.get("out_delta_detail"))
#     print("✅ top changes metric:", result.get("top_rank_metric"))
#     print("✅ top regressions:", result.get("out_top_regressions"))
#     print("✅ top improvements:", result.get("out_top_improvements"))

# # snapshots
# if "out_config" in result:
#     print("✅ extra saved config :", result["out_config"])
# if "out_samples_base" in result:
#     print("✅ extra saved samples:", result["out_samples_base"], "and", result.get("out_samples_exp"))
# if "out_trace" in result:
#     print("✅ extra saved trace  :", result["out_trace"])
#     print("✅ trace columns used :", result.get("trace_cols_used"))
