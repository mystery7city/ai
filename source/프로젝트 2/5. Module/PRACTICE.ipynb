# %%
# !where python
# Out:
# C:\Users\darks\anaconda3\python.exe
# C:\Users\darks\AppData\Local\Microsoft\WindowsApps\python.exe

# %%
# %cd "C:/Users/darks/Desktop/자료들/AI자료/ai/source/프로젝트 2/5. Module"
# !dir
# Out:
# C:\Users\darks\Desktop\자료들\AI자료\ai\source\프로젝트 2\5. Module
# C:\Users\darks\anaconda3\envs\tfenv\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 96A1-095D
#
#  C:\Users\darks\Desktop\자료들\AI자료\ai\source\프로젝트 2\5. Module 디렉터리
#
# 2026-01-24  오후 10:47    <DIR>          .
# 2026-01-24  오후 10:47    <DIR>          ..
# 2026-01-24  오후 10:00               277 .env
# 2026-01-24  오후 10:35    <DIR>          .ipynb_checkpoints
# 2026-01-24  오후 09:47    <DIR>          final comparison
# 2026-01-24  오후 10:47             1,425 PRACTICE.ipynb
# 2026-01-24  오후 09:47    <DIR>          rag optimizing
# 2026-01-24  오후 09:47            48,159 rag_module.py
# 2026-01-24  오후 09:47                 0 requirements.txt
# 2026-01-24  오후 09:47    <DIR>          solar+bm25
# ...

# %%
# !"C:\Users\darks\anaconda3\envs\tfenv\python.exe" -m pip install -U streamlit python-dotenv

# %%
open("test_st.py", "w", encoding="utf-8").write(
    'import streamlit as st\nst.title("Streamlit OK")\nst.write("환경 정상")\n'
)
# Out:
# 66

# %%
!"C:\Users\darks\anaconda3\envs\tfenv\python.exe" -m streamlit run test_st.py --server.port 8503 --server.address 127.0.0.1 --server.headless true

# %%
# !"C:\Users\darks\anaconda3\envs\tfenv\python.exe" -m pip uninstall -y pinecone-client
# !"C:\Users\darks\anaconda3\envs\tfenv\python.exe" -m pip install -U pinecone

!"C:\Users\darks\anaconda3\envs\tfenv\python.exe" -c "import pinecone; print('pinecone OK', pinecone.__version__)"
# Out:
# pinecone OK 8.0.0

# %%
!"C:\Users\darks\anaconda3\envs\tfenv\python.exe" -m streamlit run web_chatbot.py --server.port 8502 --server.address 127.0.0.1 --server.headless true

# %%
# http://127.0.0.1:8502
