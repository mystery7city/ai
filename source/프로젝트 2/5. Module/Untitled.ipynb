# %%
from pinecone import Pinecone
from dotenv import load_dotenv
import os

# .env 로드
load_dotenv()

# API Key 불러오기
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")

# Pinecone 클라이언트 생성
pc = Pinecone(api_key=PINECONE_API_KEY)

# 인덱스 목록 조회
indexes = pc.list_indexes()

print("📦 Pinecone Index List")
print("-" * 30)
for idx in indexes:
    print(f"- {idx.name}")
# Out:
# 📦 Pinecone Index List
# ------------------------------
# - case-index-final
# - law-index-final
# - rule-index-final
# - law-index-2

# %%
# %cd "C:\Users\darks\Desktop\자료들\AI자료\ai\source\프로젝트 2\5. Module"
# Out:
# C:\Users\darks\Desktop\자료들\AI자료\ai\source\프로젝트 2\5. Module
# C:\Users\darks\anaconda3\envs\tfenv\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !dir

# %%
# !where python
# !where streamlit
# Out:
# C:\Users\darks\anaconda3\python.exe
# C:\Users\darks\AppData\Local\Microsoft\WindowsApps\python.exe
# C:\Users\darks\anaconda3\Scripts\streamlit.cmd
# C:\Users\darks\anaconda3\Scripts\streamlit.exe

# %%
# %pip install -U streamlit python-dotenv langchain-core langchain-openai langchain-upstage langchain-pinecone
# %pip install -U pinecone-client cohere rank-bm25 kiwipiepy

# %%
!"C:\Users\darks\anaconda3\envs\tfenv\python.exe" -m streamlit run web_chatbot.py --server.port 8502 --server.headless true

# %%
# !streamlit run web_chatbot.py --server.port 8502
# Out:
# ^C
